# %% [markdown]
# !pip install pandas
# !pip install numpy
# !pip install matplotlib
# !pip install Jinja2
# !pip install openpyxl

# %% [markdown]
# !pip install gspread oauth2client

# %%
numero = 12

supuesto_ganador = 'Gerardo Abraham Ayala Siqueiros'

inscritos_quiniela = [ 
    'Gerardo Abraham Ayala Siqueiros',
    'Marisela Chacón Molina',
    'Arelí Olivas Alcántar',
    'Maribel Baeza Adame',
    'Santos Vazquez Garza',
    'Manuel Alejandro Escobar Aguilera',
    'José Carlos Salgado Gómez',
    'Alberto Vargas Ortiz',
    'Raúl Humberto García Robledo',
    'Alejandro Barragán Huerta',
    'Kenia Estefanía Cruz García',
    'Jaime Antonio García Morales',
    'Jerónimo Reyes Ibarra',
    'Guiorguio Guitto Sánchez Muñoz',
    'Neima Dorely Meza Jáquez',
    'Ezequiel Chávez Gutierrez',
    'Jaime Jesús Irigoyen Hernández',
    'Judith Fernández Franco',
    'Magaly Teresa Ochoa Lugo',
    'Ana Alejandra Donati Lugo',
    'Andrea Bustamante Yapur',
    "José Roberto González Hernández",
    "Ilse Lozano Rodríguez",
    'Erick Benavides Correa',
    'Cynthia Jaqueline Peralta Sosa',
    'Luis Mendoza Armendáriz',
    'José Eduardo López Acosta',
    'Derek Manuel Calderón Rubio', 
    'Luis Alberto López Mónge'   
    ]
inscritos_acumulado = [ 
    'Gerardo Abraham Ayala Siqueiros',
    'Arelí Olivas Alcántar',
    'Maribel Baeza Adame',
    'Santos Vazquez Garza',
    'Manuel Alejandro Escobar Aguilera',
    'José Carlos Salgado Gómez',
    'Alberto Vargas Ortiz',
    'Raúl Humberto García Robledo',
    'Alejandro Barragán Huerta',
    'Kenia Estefanía Cruz García',
    'Jerónimo Reyes Ibarra',
    'Guiorguio Guitto Sánchez Muñoz',
    'Ezequiel Chávez Gutierrez',
    'Jaime Jesús Irigoyen Hernández',
    'Judith Fernández Franco',
    'Ana Alejandra Donati Lugo',
    'Andrea Bustamante Yapur',
    "Ilse Lozano Rodríguez",
    'Luis Mendoza Armendáriz',
    'José Eduardo López Acosta',
    'Luis Alberto López Mónge'
    
    ]

bajas = []

conteo = 0
total_quiniela = len(inscritos_quiniela)
total_acumulado = len(inscritos_acumulado)

print(f'En total, por toda la tempora se invertiran {50 *18}\n')
print(f'Se han inscrito a la quiniela {total_quiniela} personas.\nPor semana el ganador se llevará {total_quiniela * 50}. \nLos inscritos son:\n')
for i in inscritos_quiniela:
    conteo += 1
    print(f'{conteo}. {i}')
conteo = 0    

print(f'\nAl acumulado se han inscrito {total_acumulado} personas. \nLa bolsa acumulada es de {total_acumulado * 250}. \nLos inscritos son:\n')
for i in inscritos_acumulado:
    conteo += 1
    print(f'{conteo}. {i}')
conteo = 0

print('\nLos que se anotaron en quiniela, pero no en el acumulado son:\n')
for i in inscritos_quiniela:
    if i not in inscritos_acumulado:
        conteo += 1
        print(f'{conteo}. {i}')
# Out:
# En total, por toda la tempora se invertiran 900
#
# Se han inscrito a la quiniela 29 personas.
# Por semana el ganador se llevará 1450.
# Los inscritos son:
#
# 1. Gerardo Abraham Ayala Siqueiros
# 2. Marisela Chacón Molina
# 3. Arelí Olivas Alcántar
# 4. Maribel Baeza Adame
# 5. Santos Vazquez Garza
# 6. Manuel Alejandro Escobar Aguilera
# 7. José Carlos Salgado Gómez
# 8. Alberto Vargas Ortiz
# 9. Raúl Humberto García Robledo
# 10. Alejandro Barragán Huerta
# 11. Kenia Estefanía Cruz García
# 12. Jaime Antonio García Morales
# 13. Jerónimo Reyes Ibarra
# 14. Guiorguio Guitto Sánchez Muñoz
# 15. Neima Dorely Meza Jáquez
# 16. Ezequiel Chávez Gutierrez
# 17. Jaime Jesús Irigoyen Hernández
# 18. Judith Fernández Franco
# 19. Magaly Teresa Ochoa Lugo
# 20. Ana Alejandra Donati Lugo
# 21. Andrea Bustamante Yapur
# 22. José Roberto González Hernández
# 23. Ilse Lozano Rodríguez
# 24. Erick Benavides Correa
# 25. Cynthia Jaqueline Peralta Sosa
# 26. Luis Mendoza Armendáriz
# 27. José Eduardo López Acosta
# 28. Derek Manuel Calderón Rubio
# 29. Luis Alberto López Mónge
#
# Al acumulado se han inscrito 21 personas.
# La bolsa acumulada es de 5250.
# Los inscritos son:
#
# 1. Gerardo Abraham Ayala Siqueiros
# 2. Arelí Olivas Alcántar
# 3. Maribel Baeza Adame
# 4. Santos Vazquez Garza
# 5. Manuel Alejandro Escobar Aguilera
# 6. José Carlos Salgado Gómez
# 7. Alberto Vargas Ortiz
# 8. Raúl Humberto García Robledo
# 9. Alejandro Barragán Huerta
# 10. Kenia Estefanía Cruz García
# 11. Jerónimo Reyes Ibarra
# 12. Guiorguio Guitto Sánchez Muñoz
# 13. Ezequiel Chávez Gutierrez
# 14. Jaime Jesús Irigoyen Hernández
# 15. Judith Fernández Franco
# 16. Ana Alejandra Donati Lugo
# 17. Andrea Bustamante Yapur
# 18. Ilse Lozano Rodríguez
# 19. Luis Mendoza Armendáriz
# 20. José Eduardo López Acosta
# 21. Luis Alberto López Mónge
#
# Los que se anotaron en quiniela, pero no en el acumulado son:
#
# 1. Marisela Chacón Molina
# 2. Jaime Antonio García Morales
# 3. Neima Dorely Meza Jáquez
# 4. Magaly Teresa Ochoa Lugo
# 5. José Roberto González Hernández
# 6. Erick Benavides Correa
# 7. Cynthia Jaqueline Peralta Sosa
# 8. Derek Manuel Calderón Rubio

# %%
import pandas as pd
import os
import warnings



archivo = f'Semana {numero} NFL 2025.xlsx'

fecha_inicio = pd.to_datetime('2025-09-01')


warnings.filterwarnings("ignore")
respuestas = pd.read_excel(archivo)

respuestas['fecha'] = respuestas['Completion time'].dt.date
respuestas['semana'] = (respuestas['Completion time'] - fecha_inicio).dt.days // 7 + 1

columnas = ['semana', 'fecha']
columnas_viejas = [col for col in respuestas.columns if col not in columnas]

respuestas = respuestas[columnas + columnas_viejas]
respuestas = respuestas.rename(columns={'Name':'Participante'})

correos = respuestas['Email'].unique()

# %%
quiniela_semana_actual = respuestas[respuestas['semana'] == numero]
quiniela_semana_actual = quiniela_semana_actual.drop(columns=['Start time', 
                                                              'Language',
                                                              'Completion time', 
                                                              'Email', 
                                                              'semana', 
                                                              'fecha',
                                                              'Id'])
faltaron = []
for i in inscritos_quiniela:
    if i not in quiniela_semana_actual['Participante'].values:
        faltaron.append(i)


nombre_quiniela_semanal = f'Quiniela Semana {numero} NFL 2025.xlsx'
excel_quiniela_semanal = quiniela_semana_actual.to_excel(nombre_quiniela_semanal, 
                                                         index=False,
                                                         sheet_name=f'{numero}',
                                                         header=None)
quiniela_semana_actual.columns = [quiniela_semana_actual.columns[0]] + list(range(1, 
                                                                                  len(quiniela_semana_actual.columns)))

quiniela_semana_actual.columns = list(quiniela_semana_actual.columns[:-1]) + ['Desempate']
quiniela_semana_actual
# Out:
#                          Participante                1  \
# 0        Raúl Humberto García Robledo  Buffalo - Bills
# 1              Marisela Chacón Molina  Buffalo - Bills
# 2                 Maribel Baeza Adame  Buffalo - Bills
# 3                Alberto Vargas Ortiz  Buffalo - Bills
# 4                Santos Vazquez Garza  Buffalo - Bills
# 5           Ana Alejandra Donati Lugo  Buffalo - Bills
# 6             Andrea Bustamante Yapur  Buffalo - Bills
# 7               Arelí Olivas Alcántar  Buffalo - Bills
# 8     Gerardo Abraham Ayala Siqueiros  Buffalo - Bills
# 9            Neima Dorely Meza Jáquez  Buffalo - Bills
# 10          Jose Carlos Salgado Gomez  Buffalo - Bills
# 11  Manuel Alejandro Escobar Aguilera  Buffalo - Bills
# 12    José Roberto González Hernández  Buffalo - Bills
# 13           Luis Alberto Lopez Monge  Buffalo - Bills
# 14            Judith Fernández Franco  Buffalo - Bills
# 15              Ilse Lozano Rodríguez  Buffalo - Bills
# 16              Jerónimo Reyes Ibarra  Buffalo - Bills
# 17           Magaly Teresa Ochoa Lugo  Buffalo - Bills
# 18     Guiorguio Guitto Sánchez Muñoz  Buffalo - Bills
# 19            Luis Mendoza Armendáriz  Buffalo - Bills
# 20       Jaime Antonio García Morales  Buffalo - Bills
# 21          Alejandro Barragán Huerta  Buffalo - Bills
# 22     Jaime Jesús Irigoyen Hernández  Buffalo - Bills
#
#                           2                             3  \
# 0   Chicago - Bears (Local)        New England - Patriots
# 1     Pittsburgh - Steelers        New England - Patriots
# 2     Pittsburgh - Steelers        New England - Patriots
# 3   Chicago - Bears (Local)        New England - Patriots
# 4   Chicago - Bears (Local)        New England - Patriots
# 5     Pittsburgh - Steelers        New England - Patriots
# 6   Chicago - Bears (Local)        New England - Patriots
# 7   Chicago - Bears (Local)        New England - Patriots
# 8   Chicago - Bears (Local)        New England - Patriots
# 9   Chicago - Bears (Local)  Cincinnati - Bengals (Local)
# 10  Chicago - Bears (Local)        New England - Patriots
# 11  Chicago - Bears (Local)        New England - Patriots
# 12  Chicago - Bears (Local)        New England - Patriots
# 13  Chicago - Bears (Local)        New England - Patriots
# 14  Chicago - Bears (Local)        New England - Patriots
# 15  Chicago - Bears (Local)        New England - Patriots
# 16  Chicago - Bears (Local)  Cincinnati - Bengals (Local)
# 17  Chicago - Bears (Local)        New England - Patriots
# 18    Pittsburgh - Steelers        New England - Patriots
# 19  Chicago - Bears (Local)        New England - Patriots
# 20  Chicago - Bears (Local)        New England - Patriots
# 21  Chicago - Bears (Local)        New England - Patriots
# 22    Pittsburgh - Steelers        New England - Patriots
#
#                           4                            5                   6  \
# 0   Detroit - Lions (Local)  Green Bay - Packers (Local)  Seattle - Seahawks
# 1         New York - Giants  Green Bay - Packers (Local)  Seattle - Seahawks
# 2   Detroit - Lions (Local)          Minnesota - Vikings  Seattle - Seahawks
# 3   Detroit - Lions (Local)  Green Bay - Packers (Local)  Seattle - Seahawks
# 4   Detroit - Lions (Local)  Green Bay - Packers (Local)  Seattle - Seahawks
# 5   Detroit - Lions (Local)  Green Bay - Packers (Local)  Seattle - Seahawks
# 6   Detroit - Lions (Local)  Green Bay - Packers (Local)  Seattle - Seahawks
# 7   Detroit - Lions (Local)  Green Bay - Packers (Local)  Seattle - Seahawks
# 8   Detroit - Lions (Local)  Green Bay - Packers (Local)  Seattle - Seahawks
# 9   Detroit - Lions (Local)  Green Bay - Packers (Local)  Seattle - Seahawks
# 10  Detroit - Lions (Local)  Green Bay - Packers (Local)  Seattle - Seahawks
# 11  Detroit - Lions (Local)  Green Bay - Packers (Local)  Seattle - Seahawks
# 12  Detroit - Lions (Local)  Green Bay - Packers (Local)  Seattle - Seahawks
# 13  Detroit - Lions (Local)  Green Bay - Packers (Local)  Seattle - Seahawks
# 14  Detroit - Lions (Local)  Green Bay - Packers (Local)  Seattle - Seahawks
# 15  Detroit - Lions (Local)  Green Bay - Packers (Local)  Seattle - Seahawks
# 16  Detroit - Lions (Local)  Green Bay - Packers (Local)  Seattle - Seahawks
# 17  Detroit - Lions (Local)  Green Bay - Packers (Local)  Seattle - Seahawks
# 18  Detroit - Lions (Local)  Green Bay - Packers (Local)  Seattle - Seahawks
# 19  Detroit - Lions (Local)  Green Bay - Packers (Local)  Seattle - Seahawks
# 20  Detroit - Lions (Local)  Green Bay - Packers (Local)  Seattle - Seahawks
# 21  Detroit - Lions (Local)  Green Bay - Packers (Local)  Seattle - Seahawks
# 22  Detroit - Lions (Local)  Green Bay - Packers (Local)  Seattle - Seahawks
#
#                                7                           8  \
# 0   Kansas City - Chiefs (Local)  Baltimore - Ravens (Local)
# 1           Indianapolis - Colts  Baltimore - Ravens (Local)
# 2   Kansas City - Chiefs (Local)  Baltimore - Ravens (Local)
# 3   Kansas City - Chiefs (Local)  Baltimore - Ravens (Local)
# 4   Kansas City - Chiefs (Local)  Baltimore - Ravens (Local)
# 5           Indianapolis - Colts  Baltimore - Ravens (Local)
# 6   Kansas City - Chiefs (Local)  Baltimore - Ravens (Local)
# 7   Kansas City - Chiefs (Local)  Baltimore - Ravens (Local)
# 8   Kansas City - Chiefs (Local)  Baltimore - Ravens (Local)
# 9   Kansas City - Chiefs (Local)  Baltimore - Ravens (Local)
# 10  Kansas City - Chiefs (Local)  Baltimore - Ravens (Local)
# 11  Kansas City - Chiefs (Local)  Baltimore - Ravens (Local)
# 12  Kansas City - Chiefs (Local)  Baltimore - Ravens (Local)
# 13  Kansas City - Chiefs (Local)  Baltimore - Ravens (Local)
# 14  Kansas City - Chiefs (Local)  Baltimore - Ravens (Local)
# 15  Kansas City - Chiefs (Local)  Baltimore - Ravens (Local)
# 16  Kansas City - Chiefs (Local)  Baltimore - Ravens (Local)
# 17  Kansas City - Chiefs (Local)  Baltimore - Ravens (Local)
# 18          Indianapolis - Colts  Baltimore - Ravens (Local)
# 19  Kansas City - Chiefs (Local)  Baltimore - Ravens (Local)
# 20          Indianapolis - Colts  Baltimore - Ravens (Local)
# 21  Kansas City - Chiefs (Local)  Baltimore - Ravens (Local)
# 22  Kansas City - Chiefs (Local)  Baltimore - Ravens (Local)
#
#                               9                           10  \
# 0   Las Vegas - Raiders (Local)       Jacksonville - Jaguars
# 1   Las Vegas - Raiders (Local)  Arizona - Cardinals (Local)
# 2            Cleveland - Browns       Jacksonville - Jaguars
# 3   Las Vegas - Raiders (Local)       Jacksonville - Jaguars
# 4            Cleveland - Browns  Arizona - Cardinals (Local)
# 5   Las Vegas - Raiders (Local)       Jacksonville - Jaguars
# 6   Las Vegas - Raiders (Local)       Jacksonville - Jaguars
# 7   Las Vegas - Raiders (Local)       Jacksonville - Jaguars
# 8   Las Vegas - Raiders (Local)       Jacksonville - Jaguars
# 9   Las Vegas - Raiders (Local)  Arizona - Cardinals (Local)
# 10  Las Vegas - Raiders (Local)       Jacksonville - Jaguars
# 11  Las Vegas - Raiders (Local)       Jacksonville - Jaguars
# 12  Las Vegas - Raiders (Local)       Jacksonville - Jaguars
# 13  Las Vegas - Raiders (Local)       Jacksonville - Jaguars
# 14  Las Vegas - Raiders (Local)       Jacksonville - Jaguars
# 15  Las Vegas - Raiders (Local)       Jacksonville - Jaguars
# 16  Las Vegas - Raiders (Local)  Arizona - Cardinals (Local)
# 17           Cleveland - Browns       Jacksonville - Jaguars
# 18           Cleveland - Browns  Arizona - Cardinals (Local)
# 19  Las Vegas - Raiders (Local)       Jacksonville - Jaguars
# 20  Las Vegas - Raiders (Local)       Jacksonville - Jaguars
# 21  Las Vegas - Raiders (Local)  Arizona - Cardinals (Local)
# 22           Cleveland - Browns       Jacksonville - Jaguars
#
#                           11                            12  \
# 0      Philadelphia - Eagles  New Orleans - Saints (Local)
# 1   Dallas - Cowboys (Local)  New Orleans - Saints (Local)
# 2      Philadelphia - Eagles             Atlanta - Falcons
# 3      Philadelphia - Eagles             Atlanta - Falcons
# 4   Dallas - Cowboys (Local)             Atlanta - Falcons
# 5      Philadelphia - Eagles             Atlanta - Falcons
# 6      Philadelphia - Eagles  New Orleans - Saints (Local)
# 7      Philadelphia - Eagles  New Orleans - Saints (Local)
# 8      Philadelphia - Eagles             Atlanta - Falcons
# 9      Philadelphia - Eagles             Atlanta - Falcons
# 10     Philadelphia - Eagles  New Orleans - Saints (Local)
# 11     Philadelphia - Eagles  New Orleans - Saints (Local)
# 12     Philadelphia - Eagles             Atlanta - Falcons
# 13     Philadelphia - Eagles  New Orleans - Saints (Local)
# 14     Philadelphia - Eagles             Atlanta - Falcons
# 15     Philadelphia - Eagles  New Orleans - Saints (Local)
# 16     Philadelphia - Eagles  New Orleans - Saints (Local)
# 17     Philadelphia - Eagles             Atlanta - Falcons
# 18     Philadelphia - Eagles  New Orleans - Saints (Local)
# 19  Dallas - Cowboys (Local)             Atlanta - Falcons
# 20     Philadelphia - Eagles  New Orleans - Saints (Local)
# 21  Dallas - Cowboys (Local)             Atlanta - Falcons
# 22  Dallas - Cowboys (Local)  New Orleans - Saints (Local)
#
#                             13                             14  Desempate
# 0   Los Angeles - Rams (Local)  San Francisco - 49ers (Local)         48
# 1   Los Angeles - Rams (Local)  San Francisco - 49ers (Local)         49
# 2       Tampa Bay - Buccaneers            Carolina - Panthers         40
# 3   Los Angeles - Rams (Local)  San Francisco - 49ers (Local)         48
# 4   Los Angeles - Rams (Local)  San Francisco - 49ers (Local)         45
# 5       Tampa Bay - Buccaneers  San Francisco - 49ers (Local)         28
# 6   Los Angeles - Rams (Local)  San Francisco - 49ers (Local)         51
# 7   Los Angeles - Rams (Local)  San Francisco - 49ers (Local)         47
# 8   Los Angeles - Rams (Local)  San Francisco - 49ers (Local)         42
# 9   Los Angeles - Rams (Local)  San Francisco - 49ers (Local)         48
# 10  Los Angeles - Rams (Local)  San Francisco - 49ers (Local)         50
# 11  Los Angeles - Rams (Local)  San Francisco - 49ers (Local)         43
# 12  Los Angeles - Rams (Local)  San Francisco - 49ers (Local)         48
# 13  Los Angeles - Rams (Local)  San Francisco - 49ers (Local)         49
# 14  Los Angeles - Rams (Local)  San Francisco - 49ers (Local)         52
# 15  Los Angeles - Rams (Local)  San Francisco - 49ers (Local)         48
# 16  Los Angeles - Rams (Local)  San Francisco - 49ers (Local)         46
# 17  Los Angeles - Rams (Local)  San Francisco - 49ers (Local)         45
# 18  Los Angeles - Rams (Local)  San Francisco - 49ers (Local)         48
# 19  Los Angeles - Rams (Local)  San Francisco - 49ers (Local)         46
# 20  Los Angeles - Rams (Local)  San Francisco - 49ers (Local)         24
# 21  Los Angeles - Rams (Local)  San Francisco - 49ers (Local)         49
# 22  Los Angeles - Rams (Local)  San Francisco - 49ers (Local)         51

# %%
import pandas as pd
from openpyxl import load_workbook

archivo_existente = 'NFL Quinela 2025.xlsx'
nombre_hoja = f'{numero}'

# Cargar el libro
book = load_workbook(archivo_existente)

# Eliminar la hoja si ya existe
if nombre_hoja in book.sheetnames:
    std = book[nombre_hoja]
    book.remove(std)
    book.save(archivo_existente)

# Escribir la nueva hoja
with pd.ExcelWriter(archivo_existente, engine='openpyxl', mode='a') as writer:
    quiniela_semana_actual.to_excel(writer, index=False, sheet_name=nombre_hoja,header=None)

quinela = pd.read_excel(archivo_existente, 
                        sheet_name = None, 
                        header = None, 
                        index_col=0)


quinela = {sheet: df[~df.index.isin(bajas)] for sheet, 
           df in quinela.items()}

semanas = [int(semana) for semana in quinela.keys()]
semana_numero = numero #int(max(semanas))
semana = str(semana_numero)


quinela_semanal = quinela[semana]

quinela_semanal.index.name = 'Participante'
quiniela_df = pd.DataFrame(quinela_semanal)
quiniela_df
# Out:
#                                                 1                        2   \
# Participante
# Raúl Humberto García Robledo       Buffalo - Bills  Chicago - Bears (Local)
# Marisela Chacón Molina             Buffalo - Bills    Pittsburgh - Steelers
# Maribel Baeza Adame                Buffalo - Bills    Pittsburgh - Steelers
# Alberto Vargas Ortiz               Buffalo - Bills  Chicago - Bears (Local)
# Santos Vazquez Garza               Buffalo - Bills  Chicago - Bears (Local)
# Ana Alejandra Donati Lugo          Buffalo - Bills    Pittsburgh - Steelers
# Andrea Bustamante Yapur            Buffalo - Bills  Chicago - Bears (Local)
# Arelí Olivas Alcántar              Buffalo - Bills  Chicago - Bears (Local)
# Gerardo Abraham Ayala Siqueiros    Buffalo - Bills  Chicago - Bears (Local)
# Neima Dorely Meza Jáquez           Buffalo - Bills  Chicago - Bears (Local)
# Jose Carlos Salgado Gomez          Buffalo - Bills  Chicago - Bears (Local)
# Manuel Alejandro Escobar Aguilera  Buffalo - Bills  Chicago - Bears (Local)
# José Roberto González Hernández    Buffalo - Bills  Chicago - Bears (Local)
# Luis Alberto Lopez Monge           Buffalo - Bills  Chicago - Bears (Local)
# Judith Fernández Franco            Buffalo - Bills  Chicago - Bears (Local)
# Ilse Lozano Rodríguez              Buffalo - Bills  Chicago - Bears (Local)
# Jerónimo Reyes Ibarra              Buffalo - Bills  Chicago - Bears (Local)
# Magaly Teresa Ochoa Lugo           Buffalo - Bills  Chicago - Bears (Local)
# Guiorguio Guitto Sánchez Muñoz     Buffalo - Bills    Pittsburgh - Steelers
# Luis Mendoza Armendáriz            Buffalo - Bills  Chicago - Bears (Local)
# Jaime Antonio García Morales       Buffalo - Bills  Chicago - Bears (Local)
# Alejandro Barragán Huerta          Buffalo - Bills  Chicago - Bears (Local)
# Jaime Jesús Irigoyen Hernández     Buffalo - Bills    Pittsburgh - Steelers
#
#                                                              3   \
# Participante
# Raúl Humberto García Robledo             New England - Patriots
# Marisela Chacón Molina                   New England - Patriots
# Maribel Baeza Adame                      New England - Patriots
# Alberto Vargas Ortiz                     New England - Patriots
# Santos Vazquez Garza                     New England - Patriots
# Ana Alejandra Donati Lugo                New England - Patriots
# Andrea Bustamante Yapur                  New England - Patriots
# Arelí Olivas Alcántar                    New England - Patriots
# Gerardo Abraham Ayala Siqueiros          New England - Patriots
# Neima Dorely Meza Jáquez           Cincinnati - Bengals (Local)
# Jose Carlos Salgado Gomez                New England - Patriots
# Manuel Alejandro Escobar Aguilera        New England - Patriots
# José Roberto González Hernández          New England - Patriots
# Luis Alberto Lopez Monge                 New England - Patriots
# Judith Fernández Franco                  New England - Patriots
# Ilse Lozano Rodríguez                    New England - Patriots
# Jerónimo Reyes Ibarra              Cincinnati - Bengals (Local)
# Magaly Teresa Ochoa Lugo                 New England - Patriots
# Guiorguio Guitto Sánchez Muñoz           New England - Patriots
# Luis Mendoza Armendáriz                  New England - Patriots
# Jaime Antonio García Morales             New England - Patriots
# Alejandro Barragán Huerta                New England - Patriots
# Jaime Jesús Irigoyen Hernández           New England - Patriots
#
#                                                         4   \
# Participante
# Raúl Humberto García Robledo       Detroit - Lions (Local)
# Marisela Chacón Molina                   New York - Giants
# Maribel Baeza Adame                Detroit - Lions (Local)
# Alberto Vargas Ortiz               Detroit - Lions (Local)
# Santos Vazquez Garza               Detroit - Lions (Local)
# Ana Alejandra Donati Lugo          Detroit - Lions (Local)
# Andrea Bustamante Yapur            Detroit - Lions (Local)
# Arelí Olivas Alcántar              Detroit - Lions (Local)
# Gerardo Abraham Ayala Siqueiros    Detroit - Lions (Local)
# Neima Dorely Meza Jáquez           Detroit - Lions (Local)
# Jose Carlos Salgado Gomez          Detroit - Lions (Local)
# Manuel Alejandro Escobar Aguilera  Detroit - Lions (Local)
# José Roberto González Hernández    Detroit - Lions (Local)
# Luis Alberto Lopez Monge           Detroit - Lions (Local)
# Judith Fernández Franco            Detroit - Lions (Local)
# Ilse Lozano Rodríguez              Detroit - Lions (Local)
# Jerónimo Reyes Ibarra              Detroit - Lions (Local)
# Magaly Teresa Ochoa Lugo           Detroit - Lions (Local)
# Guiorguio Guitto Sánchez Muñoz     Detroit - Lions (Local)
# Luis Mendoza Armendáriz            Detroit - Lions (Local)
# Jaime Antonio García Morales       Detroit - Lions (Local)
# Alejandro Barragán Huerta          Detroit - Lions (Local)
# Jaime Jesús Irigoyen Hernández     Detroit - Lions (Local)
#
#                                                             5   \
# Participante
# Raúl Humberto García Robledo       Green Bay - Packers (Local)
# Marisela Chacón Molina             Green Bay - Packers (Local)
# Maribel Baeza Adame                        Minnesota - Vikings
# Alberto Vargas Ortiz               Green Bay - Packers (Local)
# Santos Vazquez Garza               Green Bay - Packers (Local)
# Ana Alejandra Donati Lugo          Green Bay - Packers (Local)
# Andrea Bustamante Yapur            Green Bay - Packers (Local)
# Arelí Olivas Alcántar              Green Bay - Packers (Local)
# Gerardo Abraham Ayala Siqueiros    Green Bay - Packers (Local)
# Neima Dorely Meza Jáquez           Green Bay - Packers (Local)
# Jose Carlos Salgado Gomez          Green Bay - Packers (Local)
# Manuel Alejandro Escobar Aguilera  Green Bay - Packers (Local)
# José Roberto González Hernández    Green Bay - Packers (Local)
# Luis Alberto Lopez Monge           Green Bay - Packers (Local)
# Judith Fernández Franco            Green Bay - Packers (Local)
# Ilse Lozano Rodríguez              Green Bay - Packers (Local)
# Jerónimo Reyes Ibarra              Green Bay - Packers (Local)
# Magaly Teresa Ochoa Lugo           Green Bay - Packers (Local)
# Guiorguio Guitto Sánchez Muñoz     Green Bay - Packers (Local)
# Luis Mendoza Armendáriz            Green Bay - Packers (Local)
# Jaime Antonio García Morales       Green Bay - Packers (Local)
# Alejandro Barragán Huerta          Green Bay - Packers (Local)
# Jaime Jesús Irigoyen Hernández     Green Bay - Packers (Local)
#
#                                                    6   \
# Participante
# Raúl Humberto García Robledo       Seattle - Seahawks
# Marisela Chacón Molina             Seattle - Seahawks
# Maribel Baeza Adame                Seattle - Seahawks
# Alberto Vargas Ortiz               Seattle - Seahawks
# Santos Vazquez Garza               Seattle - Seahawks
# Ana Alejandra Donati Lugo          Seattle - Seahawks
# Andrea Bustamante Yapur            Seattle - Seahawks
# Arelí Olivas Alcántar              Seattle - Seahawks
# Gerardo Abraham Ayala Siqueiros    Seattle - Seahawks
# Neima Dorely Meza Jáquez           Seattle - Seahawks
# Jose Carlos Salgado Gomez          Seattle - Seahawks
# Manuel Alejandro Escobar Aguilera  Seattle - Seahawks
# José Roberto González Hernández    Seattle - Seahawks
# Luis Alberto Lopez Monge           Seattle - Seahawks
# Judith Fernández Franco            Seattle - Seahawks
# Ilse Lozano Rodríguez              Seattle - Seahawks
# Jerónimo Reyes Ibarra              Seattle - Seahawks
# Magaly Teresa Ochoa Lugo           Seattle - Seahawks
# Guiorguio Guitto Sánchez Muñoz     Seattle - Seahawks
# Luis Mendoza Armendáriz            Seattle - Seahawks
# Jaime Antonio García Morales       Seattle - Seahawks
# Alejandro Barragán Huerta          Seattle - Seahawks
# Jaime Jesús Irigoyen Hernández     Seattle - Seahawks
#
#                                                              7   \
# Participante
# Raúl Humberto García Robledo       Kansas City - Chiefs (Local)
# Marisela Chacón Molina                     Indianapolis - Colts
# Maribel Baeza Adame                Kansas City - Chiefs (Local)
# Alberto Vargas Ortiz               Kansas City - Chiefs (Local)
# Santos Vazquez Garza               Kansas City - Chiefs (Local)
# Ana Alejandra Donati Lugo                  Indianapolis - Colts
# Andrea Bustamante Yapur            Kansas City - Chiefs (Local)
# Arelí Olivas Alcántar              Kansas City - Chiefs (Local)
# Gerardo Abraham Ayala Siqueiros    Kansas City - Chiefs (Local)
# Neima Dorely Meza Jáquez           Kansas City - Chiefs (Local)
# Jose Carlos Salgado Gomez          Kansas City - Chiefs (Local)
# Manuel Alejandro Escobar Aguilera  Kansas City - Chiefs (Local)
# José Roberto González Hernández    Kansas City - Chiefs (Local)
# Luis Alberto Lopez Monge           Kansas City - Chiefs (Local)
# Judith Fernández Franco            Kansas City - Chiefs (Local)
# Ilse Lozano Rodríguez              Kansas City - Chiefs (Local)
# Jerónimo Reyes Ibarra              Kansas City - Chiefs (Local)
# Magaly Teresa Ochoa Lugo           Kansas City - Chiefs (Local)
# Guiorguio Guitto Sánchez Muñoz             Indianapolis - Colts
# Luis Mendoza Armendáriz            Kansas City - Chiefs (Local)
# Jaime Antonio García Morales               Indianapolis - Colts
# Alejandro Barragán Huerta          Kansas City - Chiefs (Local)
# Jaime Jesús Irigoyen Hernández     Kansas City - Chiefs (Local)
#
#                                                            8   \
# Participante
# Raúl Humberto García Robledo       Baltimore - Ravens (Local)
# Marisela Chacón Molina             Baltimore - Ravens (Local)
# Maribel Baeza Adame                Baltimore - Ravens (Local)
# Alberto Vargas Ortiz               Baltimore - Ravens (Local)
# Santos Vazquez Garza               Baltimore - Ravens (Local)
# Ana Alejandra Donati Lugo          Baltimore - Ravens (Local)
# Andrea Bustamante Yapur            Baltimore - Ravens (Local)
# Arelí Olivas Alcántar              Baltimore - Ravens (Local)
# Gerardo Abraham Ayala Siqueiros    Baltimore - Ravens (Local)
# Neima Dorely Meza Jáquez           Baltimore - Ravens (Local)
# Jose Carlos Salgado Gomez          Baltimore - Ravens (Local)
# Manuel Alejandro Escobar Aguilera  Baltimore - Ravens (Local)
# José Roberto González Hernández    Baltimore - Ravens (Local)
# Luis Alberto Lopez Monge           Baltimore - Ravens (Local)
# Judith Fernández Franco            Baltimore - Ravens (Local)
# Ilse Lozano Rodríguez              Baltimore - Ravens (Local)
# Jerónimo Reyes Ibarra              Baltimore - Ravens (Local)
# Magaly Teresa Ochoa Lugo           Baltimore - Ravens (Local)
# Guiorguio Guitto Sánchez Muñoz     Baltimore - Ravens (Local)
# Luis Mendoza Armendáriz            Baltimore - Ravens (Local)
# Jaime Antonio García Morales       Baltimore - Ravens (Local)
# Alejandro Barragán Huerta          Baltimore - Ravens (Local)
# Jaime Jesús Irigoyen Hernández     Baltimore - Ravens (Local)
#
#                                                             9   \
# Participante
# Raúl Humberto García Robledo       Las Vegas - Raiders (Local)
# Marisela Chacón Molina             Las Vegas - Raiders (Local)
# Maribel Baeza Adame                         Cleveland - Browns
# Alberto Vargas Ortiz               Las Vegas - Raiders (Local)
# Santos Vazquez Garza                        Cleveland - Browns
# Ana Alejandra Donati Lugo          Las Vegas - Raiders (Local)
# Andrea Bustamante Yapur            Las Vegas - Raiders (Local)
# Arelí Olivas Alcántar              Las Vegas - Raiders (Local)
# Gerardo Abraham Ayala Siqueiros    Las Vegas - Raiders (Local)
# Neima Dorely Meza Jáquez           Las Vegas - Raiders (Local)
# Jose Carlos Salgado Gomez          Las Vegas - Raiders (Local)
# Manuel Alejandro Escobar Aguilera  Las Vegas - Raiders (Local)
# José Roberto González Hernández    Las Vegas - Raiders (Local)
# Luis Alberto Lopez Monge           Las Vegas - Raiders (Local)
# Judith Fernández Franco            Las Vegas - Raiders (Local)
# Ilse Lozano Rodríguez              Las Vegas - Raiders (Local)
# Jerónimo Reyes Ibarra              Las Vegas - Raiders (Local)
# Magaly Teresa Ochoa Lugo                    Cleveland - Browns
# Guiorguio Guitto Sánchez Muñoz              Cleveland - Browns
# Luis Mendoza Armendáriz            Las Vegas - Raiders (Local)
# Jaime Antonio García Morales       Las Vegas - Raiders (Local)
# Alejandro Barragán Huerta          Las Vegas - Raiders (Local)
# Jaime Jesús Irigoyen Hernández              Cleveland - Browns
#
#                                                             10  \
# Participante
# Raúl Humberto García Robledo            Jacksonville - Jaguars
# Marisela Chacón Molina             Arizona - Cardinals (Local)
# Maribel Baeza Adame                     Jacksonville - Jaguars
# Alberto Vargas Ortiz                    Jacksonville - Jaguars
# Santos Vazquez Garza               Arizona - Cardinals (Local)
# Ana Alejandra Donati Lugo               Jacksonville - Jaguars
# Andrea Bustamante Yapur                 Jacksonville - Jaguars
# Arelí Olivas Alcántar                   Jacksonville - Jaguars
# Gerardo Abraham Ayala Siqueiros         Jacksonville - Jaguars
# Neima Dorely Meza Jáquez           Arizona - Cardinals (Local)
# Jose Carlos Salgado Gomez               Jacksonville - Jaguars
# Manuel Alejandro Escobar Aguilera       Jacksonville - Jaguars
# José Roberto González Hernández         Jacksonville - Jaguars
# Luis Alberto Lopez Monge                Jacksonville - Jaguars
# Judith Fernández Franco                 Jacksonville - Jaguars
# Ilse Lozano Rodríguez                   Jacksonville - Jaguars
# Jerónimo Reyes Ibarra              Arizona - Cardinals (Local)
# Magaly Teresa Ochoa Lugo                Jacksonville - Jaguars
# Guiorguio Guitto Sánchez Muñoz     Arizona - Cardinals (Local)
# Luis Mendoza Armendáriz                 Jacksonville - Jaguars
# Jaime Antonio García Morales            Jacksonville - Jaguars
# Alejandro Barragán Huerta          Arizona - Cardinals (Local)
# Jaime Jesús Irigoyen Hernández          Jacksonville - Jaguars
#
#                                                          11  \
# Participante
# Raúl Humberto García Robledo          Philadelphia - Eagles
# Marisela Chacón Molina             Dallas - Cowboys (Local)
# Maribel Baeza Adame                   Philadelphia - Eagles
# Alberto Vargas Ortiz                  Philadelphia - Eagles
# Santos Vazquez Garza               Dallas - Cowboys (Local)
# Ana Alejandra Donati Lugo             Philadelphia - Eagles
# Andrea Bustamante Yapur               Philadelphia - Eagles
# Arelí Olivas Alcántar                 Philadelphia - Eagles
# Gerardo Abraham Ayala Siqueiros       Philadelphia - Eagles
# Neima Dorely Meza Jáquez              Philadelphia - Eagles
# Jose Carlos Salgado Gomez             Philadelphia - Eagles
# Manuel Alejandro Escobar Aguilera     Philadelphia - Eagles
# José Roberto González Hernández       Philadelphia - Eagles
# Luis Alberto Lopez Monge              Philadelphia - Eagles
# Judith Fernández Franco               Philadelphia - Eagles
# Ilse Lozano Rodríguez                 Philadelphia - Eagles
# Jerónimo Reyes Ibarra                 Philadelphia - Eagles
# Magaly Teresa Ochoa Lugo              Philadelphia - Eagles
# Guiorguio Guitto Sánchez Muñoz        Philadelphia - Eagles
# Luis Mendoza Armendáriz            Dallas - Cowboys (Local)
# Jaime Antonio García Morales          Philadelphia - Eagles
# Alejandro Barragán Huerta          Dallas - Cowboys (Local)
# Jaime Jesús Irigoyen Hernández     Dallas - Cowboys (Local)
#
#                                                              12  \
# Participante
# Raúl Humberto García Robledo       New Orleans - Saints (Local)
# Marisela Chacón Molina             New Orleans - Saints (Local)
# Maribel Baeza Adame                           Atlanta - Falcons
# Alberto Vargas Ortiz                          Atlanta - Falcons
# Santos Vazquez Garza                          Atlanta - Falcons
# Ana Alejandra Donati Lugo                     Atlanta - Falcons
# Andrea Bustamante Yapur            New Orleans - Saints (Local)
# Arelí Olivas Alcántar              New Orleans - Saints (Local)
# Gerardo Abraham Ayala Siqueiros               Atlanta - Falcons
# Neima Dorely Meza Jáquez                      Atlanta - Falcons
# Jose Carlos Salgado Gomez          New Orleans - Saints (Local)
# Manuel Alejandro Escobar Aguilera  New Orleans - Saints (Local)
# José Roberto González Hernández               Atlanta - Falcons
# Luis Alberto Lopez Monge           New Orleans - Saints (Local)
# Judith Fernández Franco                       Atlanta - Falcons
# Ilse Lozano Rodríguez              New Orleans - Saints (Local)
# Jerónimo Reyes Ibarra              New Orleans - Saints (Local)
# Magaly Teresa Ochoa Lugo                      Atlanta - Falcons
# Guiorguio Guitto Sánchez Muñoz     New Orleans - Saints (Local)
# Luis Mendoza Armendáriz                       Atlanta - Falcons
# Jaime Antonio García Morales       New Orleans - Saints (Local)
# Alejandro Barragán Huerta                     Atlanta - Falcons
# Jaime Jesús Irigoyen Hernández     New Orleans - Saints (Local)
#
#                                                            13  \
# Participante
# Raúl Humberto García Robledo       Los Angeles - Rams (Local)
# Marisela Chacón Molina             Los Angeles - Rams (Local)
# Maribel Baeza Adame                    Tampa Bay - Buccaneers
# Alberto Vargas Ortiz               Los Angeles - Rams (Local)
# Santos Vazquez Garza               Los Angeles - Rams (Local)
# Ana Alejandra Donati Lugo              Tampa Bay - Buccaneers
# Andrea Bustamante Yapur            Los Angeles - Rams (Local)
# Arelí Olivas Alcántar              Los Angeles - Rams (Local)
# Gerardo Abraham Ayala Siqueiros    Los Angeles - Rams (Local)
# Neima Dorely Meza Jáquez           Los Angeles - Rams (Local)
# Jose Carlos Salgado Gomez          Los Angeles - Rams (Local)
# Manuel Alejandro Escobar Aguilera  Los Angeles - Rams (Local)
# José Roberto González Hernández    Los Angeles - Rams (Local)
# Luis Alberto Lopez Monge           Los Angeles - Rams (Local)
# Judith Fernández Franco            Los Angeles - Rams (Local)
# Ilse Lozano Rodríguez              Los Angeles - Rams (Local)
# Jerónimo Reyes Ibarra              Los Angeles - Rams (Local)
# Magaly Teresa Ochoa Lugo           Los Angeles - Rams (Local)
# Guiorguio Guitto Sánchez Muñoz     Los Angeles - Rams (Local)
# Luis Mendoza Armendáriz            Los Angeles - Rams (Local)
# Jaime Antonio García Morales       Los Angeles - Rams (Local)
# Alejandro Barragán Huerta          Los Angeles - Rams (Local)
# Jaime Jesús Irigoyen Hernández     Los Angeles - Rams (Local)
#
#                                                               14  15
# Participante
# Raúl Humberto García Robledo       San Francisco - 49ers (Local)  48
# Marisela Chacón Molina             San Francisco - 49ers (Local)  49
# Maribel Baeza Adame                          Carolina - Panthers  40
# Alberto Vargas Ortiz               San Francisco - 49ers (Local)  48
# Santos Vazquez Garza               San Francisco - 49ers (Local)  45
# Ana Alejandra Donati Lugo          San Francisco - 49ers (Local)  28
# Andrea Bustamante Yapur            San Francisco - 49ers (Local)  51
# Arelí Olivas Alcántar              San Francisco - 49ers (Local)  47
# Gerardo Abraham Ayala Siqueiros    San Francisco - 49ers (Local)  42
# Neima Dorely Meza Jáquez           San Francisco - 49ers (Local)  48
# Jose Carlos Salgado Gomez          San Francisco - 49ers (Local)  50
# Manuel Alejandro Escobar Aguilera  San Francisco - 49ers (Local)  43
# José Roberto González Hernández    San Francisco - 49ers (Local)  48
# Luis Alberto Lopez Monge           San Francisco - 49ers (Local)  49
# Judith Fernández Franco            San Francisco - 49ers (Local)  52
# Ilse Lozano Rodríguez              San Francisco - 49ers (Local)  48
# Jerónimo Reyes Ibarra              San Francisco - 49ers (Local)  46
# Magaly Teresa Ochoa Lugo           San Francisco - 49ers (Local)  45
# Guiorguio Guitto Sánchez Muñoz     San Francisco - 49ers (Local)  48
# Luis Mendoza Armendáriz            San Francisco - 49ers (Local)  46
# Jaime Antonio García Morales       San Francisco - 49ers (Local)  24
# Alejandro Barragán Huerta          San Francisco - 49ers (Local)  49
# Jaime Jesús Irigoyen Hernández     San Francisco - 49ers (Local)  51

# %%
# Obtener las selecciones del supuesto ganador (el participante está en el índice)
if supuesto_ganador in quiniela_df.index:
	fila = quiniela_df.loc[supuesto_ganador]
	# eliminar la columna de desempate si existe y convertir a lista
	equipos_supuesto_ganador = fila.drop(labels=['Desempate'], errors='ignore').values.tolist()
else:
	equipos_supuesto_ganador = []
	print(f"'{supuesto_ganador}' no está en quiniela_df")

# Crear una Series correcta (evitar asignaciones encadenadas que devuelven int)
equipos_supuesto_ganador = pd.Series(equipos_supuesto_ganador).reset_index(drop=True)
# Índice 1-based para conveniencia
equipos_supuesto_ganador.index = range(1, len(equipos_supuesto_ganador) + 1)
# Usar .name para asignar el número de semana
equipos_supuesto_ganador.name = numero

equipos_supuesto_ganador
# Out:
# 1                   Buffalo - Bills
# 2           Chicago - Bears (Local)
# 3            New England - Patriots
# 4           Detroit - Lions (Local)
# 5       Green Bay - Packers (Local)
# 6                Seattle - Seahawks
# 7      Kansas City - Chiefs (Local)
# 8        Baltimore - Ravens (Local)
# 9       Las Vegas - Raiders (Local)
# 10           Jacksonville - Jaguars
# 11            Philadelphia - Eagles
# 12                Atlanta - Falcons
# 13       Los Angeles - Rams (Local)
# 14    San Francisco - 49ers (Local)
# 15                               42
# Name: 12, dtype: object

# %%
faltaron_df = pd.DataFrame(faltaron, columns=['Participante']).reset_index(drop=True)
faltaron_df.index = range(1, len(faltaron_df) + 1)
faltaron_html = faltaron_df
faltaron_df
# Out:
#                      Participante
# 1       José Carlos Salgado Gómez
# 2     Kenia Estefanía Cruz García
# 3       Ezequiel Chávez Gutierrez
# 4          Erick Benavides Correa
# 5  Cynthia Jaqueline Peralta Sosa
# 6       José Eduardo López Acosta
# 7     Derek Manuel Calderón Rubio
# 8        Luis Alberto López Mónge

# %% [markdown]
# # Extración de resultados directamente de la pagina de ESPN

# %% [markdown]
# equipos_nfl = {
#     'Arizona Cardinals' : 'Arizona - Cardinals',
#     'Atlanta Falcons' : 'Atlanta - Falcons',
#     'Baltimore Ravens' : 'Baltimore - Ravens',
#     'Buffalo Bills' : 'Buffalo - Bills',
#     'Carolina Panthers' : 'Carolina - Panthers',
#     'Chicago Bears' : 'Chicago - Bears',
#     'Cincinnati Bengals' : 'Cincinnati - Bengals',
#     'Cleveland Browns' : 'Cleveland - Browns',
#     'Dallas Cowboys' : 'Dallas - Cowboys',
#     'Denver Broncos' : 'Denver - Broncos',
#     'Detroit Lions' : 'Detroit - Lions',
#     'Green Bay Packers' : 'Green Bay - Packers',
#     'Houston Texans' : 'Houston - Texans',
#     'Indianapolis Colts' : 'Indianapolis - Colts',
#     'Jacksonville Jaguars' : 'Jacksonville - Jaguars',
#     'Kansas City Chiefs' : 'Kansas City - Chiefs',
#     'Las Vegas Raiders' : 'Las Vegas - Raiders',
#     'Los Angeles Chargers' : 'Los Angeles - Chargers',
#     'Los Angeles Rams' : 'Los Angeles - Rams',
#     'Miami Dolphins' : 'Miami - Dolphins',
#     'Minnesota Vikings' : 'Minnesota - Vikings',
#     'New England Patriots' : 'New England - Patriots',
#     'New Orleans Saints' : 'New Orleans - Saints',
#     'New York Giants' : 'New York - Giants',
#     'New York Jets' : 'New York - Jets',
#     'Philadelphia Eagles' : 'Philadelphia - Eagles',
#     'Pittsburgh Steelers' : 'Pittsburgh - Steelers',
#     'San Francisco 49ers' : 'San Francisco - 49ers',
#     'Seattle Seahawks' : 'Seattle - Seahawks',
#     'Tampa Bay Buccaneers' : 'Tampa Bay - Buccaneers',
#     'Tennessee Titans' : 'Tennessee - Titans',
#     'Washington Commanders' : 'Washington - Commanders'
#
# }
#
# estadios_nfl = {
#     'State Farm Stadium Arizona - Cardinals': 'Arizona - Cardinals (Local)',
#     "AT&T Stadium Dallas - Cowboys": "Dallas - Cowboys (Local)",
#     "Mercedes-Benz Stadium Atlanta - Falcons": "Atlanta - Falcons (Local)",
#     "M&T Bank Stadium Baltimore - Ravens": "Baltimore - Ravens (Local)",
#     "Highmark Stadium Buffalo - Bills": "Buffalo - Bills (Local)",
#     "Bank of America Stadium Carolina - Panthers": "Carolina - Panthers (Local)",
#     "Soldier Field Chicago - Bears": "Chicago - Bears (Local)",
#     "Paycor Stadium Cincinnati - Bengals": "Cincinnati - Bengals (Local)",
#     "Cleveland Browns Stadium Cleveland - Browns": "Cleveland - Browns (Local)",
#     "Empower Field at Mile High Denver - Broncos": "Denver - Broncos (Local)",
#     "Ford Field Detroit - Lions": "Detroit - Lions (Local)",
#     "MetLife Stadium New York - Giants": "New York - Giants (Local)",
#     "MetLife Stadium New York - Jets": "New York - Jets (Local)",
#     "Gillette Stadium New England - Patriots": "New England - Patriots (Local)",
#     "Lambeau Field Green Bay - Packers": "Green Bay - Packers (Local)",
#     "NRG Stadium Houston - Texans": "Houston - Texans (Local)",
#     "Lucas Oil Stadium Indianapolis - Colts": "Indianapolis - Colts (Local)",
#     "SoFi Stadium Los Angeles - Rams": "Los Angeles - Rams (Local)",
#     "SoFi Stadium Los Angeles - Chargers": "Los Angeles - Chargers (Local)",
#     "EverBank Stadium Jacksonville - Jaguars": "Jacksonville - Jaguars (Local)",
#     "GEHA Field at Arrowhead Stadium Kansas City - Chiefs": "Kansas City - Chiefs (Local)",
#     "Allegiant Stadium Las Vegas - Raiders": "Las Vegas - Raiders (Local)",
#     "Hard Rock Stadium Miami - Dolphins": "Miami - Dolphins (Local)",
#     "U.S. Bank Stadium Minnesota - Vikings": "Minnesota - Vikings (Local)",
#     "Nissan Stadium Tennessee - Titans": "Tennessee - Titans (Local)",
#     "Caesars Superdome New Orleans - Saints": "New Orleans - Saints (Local)",
#     "Lincoln Financial Field Philadelphia - Eagles": "Philadelphia - Eagles (Local)",
#     "Acrisure Stadium Pittsburgh - Steelers": "Pittsburgh - Steelers (Local)",
#     "Levi's Stadium San Francisco - 49ers": "San Francisco - 49ers (Local)",
#     "Lumen Field Seattle - Seahawks": "Seattle - Seahawks (Local)",
#     "Raymond James Stadium Tampa Bay - Buccaneers": "Tampa Bay - Buccaneers (Local)",
#     "FedExField Washington - Commanders": "Washington - Commanders (Local)",
#     'Northwest Stadium Washington - Commanders': "Washington - Commanders (Local)",
#     'Huntington Bank Field Cleveland - Browns': 'Cleveland - Browns (Local)'
# }
#
#
# import pandas as pd
# import requests
# import os
#
# # Ruta del archivo
# archivo_excel = r'C:\Users\gaas\OneDrive - SERVIFOR, S.C\Personal\Proyectos_personales\NFL\2025\marcador_2025.xlsx'
#
#
#
# tipo_temporada = 2
# temporada_regular = {}
#
# for semana in range(1, 19):
#     url = f"https://site.api.espn.com/apis/site/v2/sports/football/nfl/scoreboard?week={semana}&seasontype={tipo_temporada}"
#     response = requests.get(url)
#     data = response.json()
#
#     partidos = []
#     for event in data.get("events", []):
#         nombre_partido = event.get("name")
#         fecha = event.get("date")
#         competencia = event.get("competitions", [])[0]
#         equipos = [equipo["team"]["name"] for equipo in competencia.get("competitors", [])]
#         equipo_1 = nombre_partido.split(" at ")[0] if " at " in nombre_partido else None
#         equipo_1 = equipos_nfl.get(equipo_1, equipo_1)
#         equipo_2 = nombre_partido.split(" at ")[1] if " at " in nombre_partido else None
#         equipo_2 = equipos_nfl.get(equipo_2, equipo_2)
#         estadio = competencia.get("venue", {}).get("fullName", "Desconocido")
#         puntos_equipo_1 = competencia.get("competitors", [])[1].get("score", 0)
#         puntos_equipo_2 = competencia.get("competitors", [])[0].get("score", 0)
#
#         partidos.append({
#             "Partido": nombre_partido,
#             "Fecha": fecha,
#             "Equipo 1": equipo_1,
#             "Puntos Equipo 1": puntos_equipo_1,
#             "Equipo 2": equipo_2,
#             "Puntos Equipo 2": puntos_equipo_2,
#             "Estadio": estadio,
#         })
#
#     df = pd.DataFrame(partidos)
#     df['combinación'] = df['Estadio'] + " " + df['Equipo 2']
#     df['Local'] = df['combinación'].map(estadios_nfl)
#     df['Local'] = df['Local'].fillna(df['Equipo 2'])
#     df['Ganador'] = df.apply(lambda row: row['Equipo 1'] if int(row['Puntos Equipo 1']) > int(row['Puntos Equipo 2']) else (row['Local'] if int(row['Puntos Equipo 2']) > int(row['Puntos Equipo 1']) else 'Empate'), axis=1)
#
#     temporada_regular[semana] = df
#
# # Guardar todas las semanas en el archivo Excel
# with pd.ExcelWriter(archivo_excel, engine='openpyxl', mode='a', if_sheet_exists='replace') as writer:
#     for semana, df in temporada_regular.items():
#         df.to_excel(writer, sheet_name=str(semana), index=False)
#
#
#
# # Ruta del archivo
# archivo = r'C:\Users\gaas\OneDrive - SERVIFOR, S.C\Personal\Proyectos_personales\NFL\2025\marcador_2025.xlsx'
#
# # Diccionario para almacenar ganadores por semana
# ganadores_por_semana = {}
#
# for semana in range(1, 19):
#     nombre_hoja = str(semana)
#     try:
#         df = pd.read_excel(archivo, sheet_name=nombre_hoja, engine='openpyxl')
#         if 'Ganador' in df.columns:
#             ganadores_por_semana[semana] = df['Ganador'].tolist()
#         else:
#             ganadores_por_semana[semana] = ['Columna "Ganador" no encontrada']
#     except Exception as e:
#         ganadores_por_semana[semana] = ['Hoja no encontrada']
#
# # Crear DataFrame con índice como semana
# df_ganadores_semanales = pd.DataFrame.from_dict(ganadores_por_semana, orient='index')
# df_ganadores_semanales.index.name = 'Semana'
#
# # Mostrar el DataFrame
# df_ganadores_semanales
#
# import pandas as pd
#
# # Ruta del archivo
# archivo = r'C:\Users\gaas\OneDrive - SERVIFOR, S.C\Personal\Proyectos_personales\NFL\2025\marcador_2025.xlsx'
#
# # Diccionario para almacenar ganadores por semana
# ganadores_por_semana = {}
#
# for semana in range(1, 19):
#     nombre_hoja = str(semana)
#     try:
#         df = pd.read_excel(archivo, sheet_name=nombre_hoja, engine='openpyxl')
#         if 'Ganador' in df.columns:
#             ganadores_por_semana[semana] = df['Ganador'].tolist()
#         else:
#             ganadores_por_semana[semana] = ['Columna "Ganador" no encontrada']
#     except Exception as e:
#         ganadores_por_semana[semana] = ['Hoja no encontrada']
#
# # Crear DataFrame con índice como semana
# df_ganadores_semanales = pd.DataFrame.from_dict(ganadores_por_semana, orient='index')
# df_ganadores_semanales.index.name = 'Semana'
#
# # Mostrar el DataFrame
# df_ganadores_semanales.loc[numero]

# %% [markdown]
# # Usar resultados de la semana actual para comparar con la quiniela

# %%
resultados_partidos = pd.read_excel('NFL Resultados 2025.xlsx',
                                    header=None,
                                    index_col=0)

# Eliminar filas con índice nulo
resultados_partidos = resultados_partidos[resultados_partidos.index.notna()]

# Convertir el índice a entero
resultados_partidos.index = resultados_partidos.index.astype(int)

resultados_partidos.loc[numero]
# Out:
# 1                   Buffalo - Bills
# 2           Chicago - Bears (Local)
# 3            New England - Patriots
# 4           Detroit - Lions (Local)
# 5       Green Bay - Packers (Local)
# 6                Seattle - Seahawks
# 7      Kansas City - Chiefs (Local)
# 8        Baltimore - Ravens (Local)
# 9       Las Vegas - Raiders (Local)
# 10           Jacksonville - Jaguars
# 11            Philadelphia - Eagles
# 12                Atlanta - Falcons
# 13       Los Angeles - Rams (Local)
# 14    San Francisco - 49ers (Local)
# 15                              NaN
# 16                              NaN
# 17                              NaN
# Name: 12, dtype: object

# %% [markdown]
# # Definir aciertos semanales

# %%
def contar_aciertos(quiniela, resultados):
    import pandas as pd

    def limpiar_nombre(equipo):
        if isinstance(equipo, str):
            return equipo.replace("(Local)", "").strip().lower()
        return equipo
    acierto_semanal = pd.DataFrame()

    for semana, quiniela_semana_actual in quiniela.items():
        aciertos_semana = {}

        try:
            semana_int = int(semana)
        except ValueError:
            print(f"Semana '{semana}' no es un número válido.")
            continue

        if semana_int not in resultados.index:
            print(f"Semana {semana_int} no encontrada en resultados")
            continue

        resultado_real = resultados.loc[semana_int]
        resultado_real = resultado_real.apply(limpiar_nombre)

        for participante in quiniela_semana_actual.index:
            seleccion_participante = quiniela_semana_actual.loc[participante]
            seleccion_participante = seleccion_participante.reindex(resultado_real.index)
            seleccion_participante = seleccion_participante.apply(limpiar_nombre)

            aciertos_semana[participante] = (seleccion_participante == resultado_real).sum()

        acierto_semanal[semana_int] = pd.Series(aciertos_semana)

    acierto_semanal.fillna(0, inplace=True)
    acierto_semanal = acierto_semanal.astype(int)
    acierto_semanal['Total Aciertos'] = acierto_semanal.sum(axis=1)

    return acierto_semanal

# %% [markdown]
# # Generación de tabla Preliminar

# %%
# Llamar a la función para obtener los aciertos semanales por participante
aciertos_semanales = contar_aciertos(quinela, resultados_partidos)

# Ordenar el DataFrame por el total de aciertos en orden descendente
aciertos_semanales = aciertos_semanales.sort_values(by='Total Aciertos', 
                                                    ascending=False)

semana_actual = pd.DataFrame(aciertos_semanales[semana_numero].sort_values(ascending=False))
semana_actual.columns = ['Semana %i' % semana_numero]

# Aqui los números que restan es para escojer la columna a mostrar
marcador = quinela_semanal.shape[1] - 1
partidos = quinela_semanal.shape[1] - 2

partido_lunes = quinela_semanal.iloc[:, [partidos, marcador]]
partido_lunes.columns = ['Último juego','Puntos']
preliminar = pd.merge(semana_actual, 
                      partido_lunes, 
                      left_index=True, 
                      right_index=True)

columna_semana_actual = semana_actual.columns[0]

preliminar = preliminar.sort_values(by=[columna_semana_actual, 'Puntos'], ascending=False)

preliminar = pd.DataFrame(preliminar)
preliminar.index.name = 'Participante'

preliminar
# Out:
# Semana 0 no encontrada en resultados
#                                    Semana 12                   Último juego  \
# Participante
# Judith Fernández Franco                   14  San Francisco - 49ers (Local)
# Alberto Vargas Ortiz                      14  San Francisco - 49ers (Local)
# José Roberto González Hernández           14  San Francisco - 49ers (Local)
# Gerardo Abraham Ayala Siqueiros           14  San Francisco - 49ers (Local)
# Andrea Bustamante Yapur                   13  San Francisco - 49ers (Local)
# Ilse Lozano Rodríguez                     13  San Francisco - 49ers (Local)
# Raúl Humberto García Robledo              13  San Francisco - 49ers (Local)
# Arelí Olivas Alcántar                     13  San Francisco - 49ers (Local)
# Luis Mendoza Armendáriz                   13  San Francisco - 49ers (Local)
# Magaly Teresa Ochoa Lugo                  13  San Francisco - 49ers (Local)
# Manuel Alejandro Escobar Aguilera         13  San Francisco - 49ers (Local)
# Alejandro Barragán Huerta                 12  San Francisco - 49ers (Local)
# Neima Dorely Meza Jáquez                  12  San Francisco - 49ers (Local)
# Jaime Antonio García Morales              12  San Francisco - 49ers (Local)
# Jerónimo Reyes Ibarra                     11  San Francisco - 49ers (Local)
# Santos Vazquez Garza                      11  San Francisco - 49ers (Local)
# Ana Alejandra Donati Lugo                 11  San Francisco - 49ers (Local)
# Jaime Jesús Irigoyen Hernández            10  San Francisco - 49ers (Local)
# Guiorguio Guitto Sánchez Muñoz             9  San Francisco - 49ers (Local)
# Maribel Baeza Adame                        9            Carolina - Panthers
# Marisela Chacón Molina                     8  San Francisco - 49ers (Local)
#
#                                    Puntos
# Participante
# Judith Fernández Franco                52
# Alberto Vargas Ortiz                   48
# José Roberto González Hernández        48
# Gerardo Abraham Ayala Siqueiros        42
# Andrea Bustamante Yapur                51
# Ilse Lozano Rodríguez                  48
# Raúl Humberto García Robledo           48
# Arelí Olivas Alcántar                  47
# Luis Mendoza Armendáriz                46
# Magaly Teresa Ochoa Lugo               45
# Manuel Alejandro Escobar Aguilera      43
# Alejandro Barragán Huerta              49
# Neima Dorely Meza Jáquez               48
# Jaime Antonio García Morales           24
# Jerónimo Reyes Ibarra                  46
# Santos Vazquez Garza                   45
# Ana Alejandra Donati Lugo              28
# Jaime Jesús Irigoyen Hernández         51
# Guiorguio Guitto Sánchez Muñoz         48
# Maribel Baeza Adame                    40
# Marisela Chacón Molina                 49

# %% [markdown]
# # Envio de correo con resultados de quiniela semanal

# %%
# Lista de equipos ganadores
equipos_ganadores = resultados_partidos.loc[numero].dropna().tolist()

# Función para aplicar color solo a columnas específicas
def resaltar_ganadores(val):
    if val in equipos_ganadores:
        return 'background-color: #D5F5E3'  # verde claro
    else:
        return 'background-color: #FADBD8'  # rojo claro

# Excluir la última columna
columnas_a_formatear = quiniela_semana_actual.columns[1:-1]

quiniela_semana_actual = quiniela_semana_actual.set_index('Participante')
quiniela_semana_actual.index.name = 'Participante'
# Aplicar estilo solo a esas columnas
quiniela_final = quiniela_semana_actual.style.applymap(resaltar_ganadores, subset=columnas_a_formatear)


from premailer import transform
# ------------------------------
# TABLA PRELIMINAR
# ------------------------------
# Aplica gradiente + estilos de tabla
preliminar_estilada = (
    preliminar.style
    .background_gradient(
        cmap='RdYlGn',  # gradiente
        axis=0
    )
    .set_table_styles(
        [
            {"selector": "th", 
             "props": [
                 ("background-color", "#2E86C1"),
                 ("color", "white"),
                 ("text-align", "center"),
                 ("font-weight", "bold"),
                 ("padding", "8px")
             ]},
            {"selector": "td", 
             "props": [
                 ("text-align", "center"),
                 ("padding", "6px")
             ]},
            {"selector": "table",
             "props": [
                 ("border-collapse", "collapse"),
                 ("margin", "0 auto"),
                 ("font-family", "Arial, sans-serif"),
                 ("font-size", "14px")
             ]}
        ]
    )
)


preliminar_html = preliminar_estilada.to_html()
preliminar_html_inlined = transform(preliminar_html, remove_classes=True, strip_important=False)

# ------------------------------
# TABLA QUINIELA
# ------------------------------

quiniela_estilada = (
    quiniela_semana_actual.style
    .applymap(resaltar_ganadores, subset=columnas_a_formatear)
    .set_table_styles(
        [
            {"selector": "th", 
             "props": [
                 ("background-color", "#2E86C1"),
                 ("color", "white"),
                 ("text-align", "center"),
                 ("font-weight", "bold"),
                 ("padding", "8px")
             ]},
            {"selector": "td", 
             "props": [
                 ("text-align", "center"),
                 ("padding", "6px")
             ]},
            {"selector": "table",
             "props": [
                 ("border-collapse", "collapse"),
                 ("margin", "0 auto"),
                 ("font-family", "Arial, sans-serif"),
                 ("font-size", "14px")
             ]}
        ]
    )
)

quiniela_html = quiniela_estilada.to_html()
quiniela_html_inlined = transform(quiniela_html, remove_classes=True, strip_important=False)

import smtplib
from email.mime.multipart import MIMEMultipart
from email.mime.text import MIMEText
from email.mime.base import MIMEBase
from email import encoders
import pandas as pd

# Configuración del servidor y credenciales
smtp_server = 'smtp.office365.com'
smtp_port = 587
username = 'gaas@citlali.mx'
password = 'nashira1103'


asunto = f"🏈✨📣 Resultado final de Quiniela de la semana {numero}📣✨🏈"
nombre_archivo = f"resultado de la semana {numero}"

# Crear el mensaje
msg = MIMEMultipart()
msg['From'] = username
msg['To'] = username
msg['Subject'] = asunto
# Crear el cuerpo del mensaje con la tabla embebida
# Cuerpo del correo con la tabla en línea
body = f"""
<html>
<head><meta charset="UTF-8"></head>
<body style="font-family: Arial, sans-serif; color: #333;">
<p style="color: #2E86C1;"><strong>👋 ¡¡Hola buen día a todos!!</strong></p>

<p><strong style="color: #117A65;">El {nombre_archivo}</strong> 🏈:</p>

<h3 style="color:#2E86C1;">📊 Puntos finales</h3>
{preliminar_html_inlined}

<h3 style="color:#117A65;">🏆 Quiniela Final</h3>
{quiniela_html_inlined}

<p style="color: #28B463;"><strong>Favor de reportarse con el ganador 🎉 y enviar su comprobante 🧾💵💰 al grupo de WhatsApp</strong></p>

<p style="color: #566573;">Salu✌️,<br>📬 Equipo Citlali ⭐</p>
</body>
</html>
"""

msg.attach(MIMEText(body, 'html', 'utf-8'))


filename = nombre_archivo


part = MIMEBase('application', 'octet-stream')

part.add_header('Content-Disposition', f"attachment; filename= {filename}")



# Enviar el correo
try:
    server = smtplib.SMTP(smtp_server, smtp_port)
    server.starttls()
    server.login(username, password)
    text = msg.as_string()
    server.sendmail(username, [username], text)
    server.quit()
    print("Correo enviado exitosamente")
except Exception as e:
    print(f"Error al enviar el correo: {e}")

# %%
#Puntos de diferencia par desempate
jugador_1 = 53
jugador_2 = 47
valor = 24+26
diferencia_1 = jugador_1 - valor
diferencia_2 = valor - jugador_2
print(f'El partido terminó con un marcador de {valor}')
print(f'Jugador_1 tiene {jugador_1} su diferencia es de {diferencia_1}')
print(f'Jugador_2 tiene {jugador_2} su diferencia es de {diferencia_2}\n')
if diferencia_1 < diferencia_2:
    print(f'El jugador_1 gana con {diferencia_1} puntos de diferencia')
elif diferencia_1 > diferencia_2:
    print(f'El jugador_2 gana con {diferencia_2} puntos de diferencia')
else:
    print(f'El partido termina en empate con {diferencia_1} puntos de diferencia')
