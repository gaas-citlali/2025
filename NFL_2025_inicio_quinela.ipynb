# %%
numero = 15

inscritos_quiniela = [ 
    'Gerardo Abraham Ayala Siqueiros',
    'Marisela Chacón Molina',
    'Arelí Olivas Alcántar',
    'Maribel Baeza Adame',
    'Santos Vazquez Garza',
    'Manuel Alejandro Escobar Aguilera',
    'José Carlos Salgado Gómez',
    'Alberto Vargas Ortiz',
    'Raúl Humberto García Robledo',
    'Alejandro Barragán Huerta',
    'Kenia Estefanía Cruz García',
    'Jaime Antonio García Morales',
    'Jerónimo Reyes Ibarra',
    'Guiorguio Guitto Sánchez Muñoz',
    'Neima Dorely Meza Jáquez',
    'Ezequiel Chávez Gutierrez',
    'Jaime Jesús Irigoyen Hernández',
    'Judith Fernández Franco',
    'Magaly Teresa Ochoa Lugo',
    'Ana Alejandra Donati Lugo',
    'Andrea Bustamante Yapur',
    "José Roberto González Hernández",
    "Ilse Lozano Rodríguez",
    'Erick Benavides Correa',
    'Cynthia Jaqueline Peralta Sosa',
    'Luis Mendoza Armendáriz',
    'José Eduardo López Acosta',
    'Derek Manuel Calderón Rubio', 
    'Luis Alberto López Mónge'   
    ]
inscritos_acumulado = [ 
    'Gerardo Abraham Ayala Siqueiros',
    'Arelí Olivas Alcántar',
    'Maribel Baeza Adame',
    'Santos Vazquez Garza',
    'Manuel Alejandro Escobar Aguilera',
    'José Carlos Salgado Gómez',
    'Alberto Vargas Ortiz',
    'Raúl Humberto García Robledo',
    'Alejandro Barragán Huerta',
    'Kenia Estefanía Cruz García',
    'Jerónimo Reyes Ibarra',
    'Guiorguio Guitto Sánchez Muñoz',
    'Ezequiel Chávez Gutierrez',
    'Jaime Jesús Irigoyen Hernández',
    'Judith Fernández Franco',
    'Ana Alejandra Donati Lugo',
    'Andrea Bustamante Yapur',
    "Ilse Lozano Rodríguez",
    'Luis Mendoza Armendáriz',
    'José Eduardo López Acosta',
    'Luis Alberto López Mónge'
    
    ]

bajas = []

diccionario_correos ={
    'mcm@citlali.mx':'Marisela Chacón Molina',
    'ggsm@citlali.mx':'Guiorguio Guitto Sánchez Muñoz',
    'avo@citlali.mx':'Alberto Vargas Ortiz',
    'jff@citlali.mx':'Judith Fernández Franco',
    'aby@citlali.mx':'Andrea Bustamante Yapur',
    'mba@citlali.mx':'Maribel Baeza Adame',
    'meg@citlali.mx':'Manuel Alejandro Escobar Aguilera',
    'gaas@citlali.mx':'Gerardo Abraham Ayala Siqueiros',
    'aoa@citlali.mx':'Arelí Olivas Alcántar',
    'jela@citlali.mx':'José Eduardo López Acosta',
    'rhgr@citlali.mx':'Raúl Humberto García Robledo',
    'kecg@citlali.mx':'Kenia Estefanía Cruz García',
    'jcsg@citlali.mx':'José Carlos Salgado Gómez',
    'ndmj@citlali.mx':'Neima Dorely Meza Jáquez',
    'jjih@citlali.mx':'Jaime Jesús Irigoyen Hernández',
    'lalm@citlali.mx':'Luis Alberto López Mónge',
    'jrgh@citlali.mx':'José Roberto González Hernández',
    'mtol@citlali.mx':'Magaly Teresa Ochoa Lugo',
    'svg@citlali.mx':'Santos Vazquez Garza',
    'jri@citlali.mx':'Jerónimo Reyes Ibarra',
    'ilr@citlali.mx':'Ilse Lozano Rodríguez',
    'abh@citlali.mx':'Alejandro Barragán Huerta',
    'dmcr@citlali.mx':'Derek Manuel Calderón Rubio',
    'lma@citlali.mx':'Luis Mendoza Armendáriz',
    'jagm@citlali.mx':'Jaime Antonio García Morales',
    'ecg@citlali.mx':'Ezequiel Chávez Gutierrez',
    'aadl@citlali.mx':'Ana Alejandra Donati Lugo',
    'ebc@citlali.mx':'Erick Benavides Correa',
    'cjps@citlali.mx':'Cynthia Jaqueline Peralta Sosa'

}

conteo = 0
total_quiniela = len(inscritos_quiniela)
total_acumulado = len(inscritos_acumulado)

print(f'En total, por toda la tempora se invertiran {50 *18}\n')
print(f'Se han inscrito a la quiniela {total_quiniela} personas.\nPor semana el ganador se llevará {total_quiniela * 50}. \nLos inscritos son:\n')
for i in inscritos_quiniela:
    conteo += 1
    print(f'{conteo}. {i}')
conteo = 0    

print(f'\nAl acumulado se han inscrito {total_acumulado} personas. \nLa bolsa acumulada es de {total_acumulado * 250}. \nLos inscritos son:\n')
for i in inscritos_acumulado:
    conteo += 1
    print(f'{conteo}. {i}')
conteo = 0

print('\nLos que se anotaron en quiniela, pero no en el acumulado son:\n')
for i in inscritos_quiniela:
    if i not in inscritos_acumulado:
        conteo += 1
        print(f'{conteo}. {i}')
# Out:
# En total, por toda la tempora se invertiran 900
#
# Se han inscrito a la quiniela 29 personas.
# Por semana el ganador se llevará 1450.
# Los inscritos son:
#
# 1. Gerardo Abraham Ayala Siqueiros
# 2. Marisela Chacón Molina
# 3. Arelí Olivas Alcántar
# 4. Maribel Baeza Adame
# 5. Santos Vazquez Garza
# 6. Manuel Alejandro Escobar Aguilera
# 7. José Carlos Salgado Gómez
# 8. Alberto Vargas Ortiz
# 9. Raúl Humberto García Robledo
# 10. Alejandro Barragán Huerta
# 11. Kenia Estefanía Cruz García
# 12. Jaime Antonio García Morales
# 13. Jerónimo Reyes Ibarra
# 14. Guiorguio Guitto Sánchez Muñoz
# 15. Neima Dorely Meza Jáquez
# 16. Ezequiel Chávez Gutierrez
# 17. Jaime Jesús Irigoyen Hernández
# 18. Judith Fernández Franco
# 19. Magaly Teresa Ochoa Lugo
# 20. Ana Alejandra Donati Lugo
# 21. Andrea Bustamante Yapur
# 22. José Roberto González Hernández
# 23. Ilse Lozano Rodríguez
# 24. Erick Benavides Correa
# 25. Cynthia Jaqueline Peralta Sosa
# 26. Luis Mendoza Armendáriz
# 27. José Eduardo López Acosta
# 28. Derek Manuel Calderón Rubio
# 29. Luis Alberto López Mónge
#
# Al acumulado se han inscrito 21 personas.
# La bolsa acumulada es de 5250.
# Los inscritos son:
#
# 1. Gerardo Abraham Ayala Siqueiros
# 2. Arelí Olivas Alcántar
# 3. Maribel Baeza Adame
# 4. Santos Vazquez Garza
# 5. Manuel Alejandro Escobar Aguilera
# 6. José Carlos Salgado Gómez
# 7. Alberto Vargas Ortiz
# 8. Raúl Humberto García Robledo
# 9. Alejandro Barragán Huerta
# 10. Kenia Estefanía Cruz García
# 11. Jerónimo Reyes Ibarra
# 12. Guiorguio Guitto Sánchez Muñoz
# 13. Ezequiel Chávez Gutierrez
# 14. Jaime Jesús Irigoyen Hernández
# 15. Judith Fernández Franco
# 16. Ana Alejandra Donati Lugo
# 17. Andrea Bustamante Yapur
# 18. Ilse Lozano Rodríguez
# 19. Luis Mendoza Armendáriz
# 20. José Eduardo López Acosta
# 21. Luis Alberto López Mónge
#
# Los que se anotaron en quiniela, pero no en el acumulado son:
#
# 1. Marisela Chacón Molina
# 2. Jaime Antonio García Morales
# 3. Neima Dorely Meza Jáquez
# 4. Magaly Teresa Ochoa Lugo
# 5. José Roberto González Hernández
# 6. Erick Benavides Correa
# 7. Cynthia Jaqueline Peralta Sosa
# 8. Derek Manuel Calderón Rubio

# %%
import pandas as pd
import os
import warnings


archivo = f'Semana {numero} NFL 2025.xlsx'

fecha_inicio = pd.to_datetime('2025-09-01')

warnings.filterwarnings("ignore")
respuestas = pd.read_excel(archivo)

respuestas['fecha'] = respuestas['Completion time'].dt.date
respuestas['semana'] = (respuestas['Completion time'] - fecha_inicio).dt.days // 7 + 1

columnas = ['semana', 'fecha']
columnas_viejas = [col for col in respuestas.columns if col not in columnas]


respuestas = respuestas[columnas + columnas_viejas]
respuestas = respuestas.rename(columns={'Name':'Participante'})
respuestas['Participante'] = respuestas['Email'].map(diccionario_correos)

correos = respuestas['Email'].unique()

respuestas
# Out:
#     semana       fecha  Id          Start time     Completion time  \
# 0       15  2025-12-09   1 2025-12-09 08:55:24 2025-12-09 08:59:54
# 1       15  2025-12-09   2 2025-12-09 09:27:57 2025-12-09 09:32:18
# 2       15  2025-12-09   3 2025-12-09 09:36:40 2025-12-09 09:38:30
# 3       15  2025-12-09   4 2025-12-09 11:59:02 2025-12-09 12:02:28
# 4       15  2025-12-09   5 2025-12-09 14:18:31 2025-12-09 14:21:45
# 5       15  2025-12-09   6 2025-12-09 09:24:54 2025-12-09 15:13:07
# 6       15  2025-12-09   7 2025-12-09 16:50:54 2025-12-09 16:54:24
# 7       15  2025-12-09   8 2025-12-09 21:27:09 2025-12-09 21:29:54
# 8       15  2025-12-09   9 2025-12-09 22:41:27 2025-12-09 22:56:31
# 9       15  2025-12-10  10 2025-12-10 10:44:03 2025-12-10 10:47:10
# 10      15  2025-12-10  11 2025-12-10 12:23:00 2025-12-10 12:24:20
# 11      15  2025-12-10  12 2025-12-10 14:56:45 2025-12-10 15:00:28
# 12      15  2025-12-10  13 2025-12-10 15:40:42 2025-12-10 15:52:00
# 13      15  2025-12-10  14 2025-12-10 15:28:54 2025-12-10 16:07:28
# 14      15  2025-12-10  15 2025-12-10 16:07:12 2025-12-10 16:10:51
# 15      15  2025-12-10  16 2025-12-10 15:36:42 2025-12-10 16:12:36
# 16      15  2025-12-10  17 2025-12-10 16:10:16 2025-12-10 16:15:47
# 17      15  2025-12-10  18 2025-12-10 15:30:28 2025-12-10 16:37:45
# 18      15  2025-12-10  19 2025-12-10 16:39:53 2025-12-10 16:47:48
# 19      15  2025-12-10  20 2025-12-10 16:26:09 2025-12-10 16:58:33
# 20      15  2025-12-11  21 2025-12-11 00:09:47 2025-12-11 00:12:58
# 21      15  2025-12-11  22 2025-12-11 11:02:41 2025-12-11 11:07:59
# 22      15  2025-12-11  23 2025-12-11 11:07:53 2025-12-11 11:08:47
# 23      15  2025-12-11  24 2025-12-11 11:02:40 2025-12-11 11:19:16
# 24      15  2025-12-11  25 2025-12-11 11:24:55 2025-12-11 11:26:35
# 25      15  2025-12-11  26 2025-12-11 11:25:49 2025-12-11 11:29:33
# 26      15  2025-12-11  27 2025-12-11 13:05:49 2025-12-11 13:08:50
# 27      15  2025-12-11  28 2025-12-11 15:29:46 2025-12-11 15:39:21
#
#               Email                       Participante  Language  \
# 0    mcm@citlali.mx             Marisela Chacón Molina       NaN
# 1    mba@citlali.mx                Maribel Baeza Adame       NaN
# 2    avo@citlali.mx               Alberto Vargas Ortiz       NaN
# 3    meg@citlali.mx  Manuel Alejandro Escobar Aguilera       NaN
# 4    aby@citlali.mx            Andrea Bustamante Yapur       NaN
# 5   aadl@citlali.mx          Ana Alejandra Donati Lugo       NaN
# 6   ggsm@citlali.mx     Guiorguio Guitto Sánchez Muñoz       NaN
# 7    ecg@citlali.mx          Ezequiel Chávez Gutierrez       NaN
# 8   gaas@citlali.mx    Gerardo Abraham Ayala Siqueiros       NaN
# 9   jcsg@citlali.mx          José Carlos Salgado Gómez       NaN
# 10   lma@citlali.mx            Luis Mendoza Armendáriz       NaN
# 11   jff@citlali.mx            Judith Fernández Franco       NaN
# 12   aoa@citlali.mx              Arelí Olivas Alcántar       NaN
# 13  kecg@citlali.mx        Kenia Estefanía Cruz García       NaN
# 14  rhgr@citlali.mx       Raúl Humberto García Robledo       NaN
# 15   ebc@citlali.mx             Erick Benavides Correa       NaN
# 16  jrgh@citlali.mx    José Roberto González Hernández       NaN
# 17  dmcr@citlali.mx        Derek Manuel Calderón Rubio       NaN
# 18  jagm@citlali.mx       Jaime Antonio García Morales       NaN
# 19  ndmj@citlali.mx           Neima Dorely Meza Jáquez       NaN
# 20   ilr@citlali.mx              Ilse Lozano Rodríguez       NaN
# 21   abh@citlali.mx          Alejandro Barragán Huerta       NaN
# 22   svg@citlali.mx               Santos Vazquez Garza       NaN
# 23  lalm@citlali.mx           Luis Alberto López Mónge       NaN
# 24   jri@citlali.mx              Jerónimo Reyes Ibarra       NaN
# 25  jjih@citlali.mx     Jaime Jesús Irigoyen Hernández       NaN
# 26  cjps@citlali.mx     Cynthia Jaqueline Peralta Sosa       NaN
# 27  mtol@citlali.mx           Magaly Teresa Ochoa Lugo       NaN
#
#                             Column                  Column1  ...  \
# 0   Tampa Bay - Buccaneers (Local)  Chicago - Bears (Local)  ...
# 1   Tampa Bay - Buccaneers (Local)  Chicago - Bears (Local)  ...
# 2   Tampa Bay - Buccaneers (Local)  Chicago - Bears (Local)  ...
# 3   Tampa Bay - Buccaneers (Local)  Chicago - Bears (Local)  ...
# 4   Tampa Bay - Buccaneers (Local)  Chicago - Bears (Local)  ...
# 5   Tampa Bay - Buccaneers (Local)  Chicago - Bears (Local)  ...
# 6                Atlanta - Falcons  Chicago - Bears (Local)  ...
# 7   Tampa Bay - Buccaneers (Local)  Chicago - Bears (Local)  ...
# 8   Tampa Bay - Buccaneers (Local)  Chicago - Bears (Local)  ...
# 9   Tampa Bay - Buccaneers (Local)  Chicago - Bears (Local)  ...
# 10  Tampa Bay - Buccaneers (Local)  Chicago - Bears (Local)  ...
# 11  Tampa Bay - Buccaneers (Local)  Chicago - Bears (Local)  ...
# 12  Tampa Bay - Buccaneers (Local)  Chicago - Bears (Local)  ...
# 13  Tampa Bay - Buccaneers (Local)  Chicago - Bears (Local)  ...
# 14  Tampa Bay - Buccaneers (Local)  Chicago - Bears (Local)  ...
# 15               Atlanta - Falcons       Cleveland - Browns  ...
# 16  Tampa Bay - Buccaneers (Local)  Chicago - Bears (Local)  ...
# 17  Tampa Bay - Buccaneers (Local)  Chicago - Bears (Local)  ...
# 18  Tampa Bay - Buccaneers (Local)  Chicago - Bears (Local)  ...
# 19  Tampa Bay - Buccaneers (Local)  Chicago - Bears (Local)  ...
# 20  Tampa Bay - Buccaneers (Local)  Chicago - Bears (Local)  ...
# 21  Tampa Bay - Buccaneers (Local)  Chicago - Bears (Local)  ...
# 22  Tampa Bay - Buccaneers (Local)  Chicago - Bears (Local)  ...
# 23  Tampa Bay - Buccaneers (Local)  Chicago - Bears (Local)  ...
# 24  Tampa Bay - Buccaneers (Local)  Chicago - Bears (Local)  ...
# 25  Tampa Bay - Buccaneers (Local)  Chicago - Bears (Local)  ...
# 26  Tampa Bay - Buccaneers (Local)  Chicago - Bears (Local)  ...
# 27  Tampa Bay - Buccaneers (Local)  Chicago - Bears (Local)  ...
#
#                            Column7                   Column8  \
# 0   Jacksonville - Jaguars (Local)  Houston - Texans (Local)
# 1   Jacksonville - Jaguars (Local)  Houston - Texans (Local)
# 2   Jacksonville - Jaguars (Local)  Houston - Texans (Local)
# 3   Jacksonville - Jaguars (Local)  Houston - Texans (Local)
# 4   Jacksonville - Jaguars (Local)  Houston - Texans (Local)
# 5   Jacksonville - Jaguars (Local)  Houston - Texans (Local)
# 6   Jacksonville - Jaguars (Local)  Houston - Texans (Local)
# 7   Jacksonville - Jaguars (Local)  Houston - Texans (Local)
# 8   Jacksonville - Jaguars (Local)  Houston - Texans (Local)
# 9   Jacksonville - Jaguars (Local)  Houston - Texans (Local)
# 10  Jacksonville - Jaguars (Local)  Houston - Texans (Local)
# 11  Jacksonville - Jaguars (Local)  Houston - Texans (Local)
# 12  Jacksonville - Jaguars (Local)  Houston - Texans (Local)
# 13  Jacksonville - Jaguars (Local)  Houston - Texans (Local)
# 14  Jacksonville - Jaguars (Local)  Houston - Texans (Local)
# 15  Jacksonville - Jaguars (Local)       Arizona - Cardinals
# 16  Jacksonville - Jaguars (Local)  Houston - Texans (Local)
# 17  Jacksonville - Jaguars (Local)  Houston - Texans (Local)
# 18  Jacksonville - Jaguars (Local)  Houston - Texans (Local)
# 19  Jacksonville - Jaguars (Local)  Houston - Texans (Local)
# 20  Jacksonville - Jaguars (Local)  Houston - Texans (Local)
# 21  Jacksonville - Jaguars (Local)  Houston - Texans (Local)
# 22  Jacksonville - Jaguars (Local)  Houston - Texans (Local)
# 23  Jacksonville - Jaguars (Local)  Houston - Texans (Local)
# 24  Jacksonville - Jaguars (Local)  Houston - Texans (Local)
# 25  Jacksonville - Jaguars (Local)  Houston - Texans (Local)
# 26  Jacksonville - Jaguars (Local)  Houston - Texans (Local)
# 27  Jacksonville - Jaguars (Local)  Houston - Texans (Local)
#
#                      Column9                    Column10  \
# 0        Green Bay - Packers  Los Angeles - Rams (Local)
# 1   Denver - Broncos (Local)  Los Angeles - Rams (Local)
# 2   Denver - Broncos (Local)  Los Angeles - Rams (Local)
# 3   Denver - Broncos (Local)             Detroit - Lions
# 4        Green Bay - Packers  Los Angeles - Rams (Local)
# 5   Denver - Broncos (Local)  Los Angeles - Rams (Local)
# 6        Green Bay - Packers             Detroit - Lions
# 7   Denver - Broncos (Local)  Los Angeles - Rams (Local)
# 8   Denver - Broncos (Local)  Los Angeles - Rams (Local)
# 9        Green Bay - Packers             Detroit - Lions
# 10       Green Bay - Packers  Los Angeles - Rams (Local)
# 11  Denver - Broncos (Local)  Los Angeles - Rams (Local)
# 12       Green Bay - Packers  Los Angeles - Rams (Local)
# 13       Green Bay - Packers  Los Angeles - Rams (Local)
# 14       Green Bay - Packers  Los Angeles - Rams (Local)
# 15       Green Bay - Packers             Detroit - Lions
# 16       Green Bay - Packers             Detroit - Lions
# 17  Denver - Broncos (Local)  Los Angeles - Rams (Local)
# 18  Denver - Broncos (Local)  Los Angeles - Rams (Local)
# 19       Green Bay - Packers             Detroit - Lions
# 20       Green Bay - Packers  Los Angeles - Rams (Local)
# 21       Green Bay - Packers  Los Angeles - Rams (Local)
# 22  Denver - Broncos (Local)  Los Angeles - Rams (Local)
# 23       Green Bay - Packers  Los Angeles - Rams (Local)
# 24       Green Bay - Packers  Los Angeles - Rams (Local)
# 25  Denver - Broncos (Local)  Los Angeles - Rams (Local)
# 26  Denver - Broncos (Local)  Los Angeles - Rams (Local)
# 27  Denver - Broncos (Local)  Los Angeles - Rams (Local)
#
#                         Column11                       Column12  \
# 0            Carolina - Panthers  San Francisco - 49ers (Local)
# 1   New Orleans - Saints (Local)  San Francisco - 49ers (Local)
# 2            Carolina - Panthers  San Francisco - 49ers (Local)
# 3            Carolina - Panthers  San Francisco - 49ers (Local)
# 4            Carolina - Panthers  San Francisco - 49ers (Local)
# 5   New Orleans - Saints (Local)  San Francisco - 49ers (Local)
# 6   New Orleans - Saints (Local)  San Francisco - 49ers (Local)
# 7            Carolina - Panthers  San Francisco - 49ers (Local)
# 8            Carolina - Panthers  San Francisco - 49ers (Local)
# 9            Carolina - Panthers  San Francisco - 49ers (Local)
# 10           Carolina - Panthers  San Francisco - 49ers (Local)
# 11           Carolina - Panthers  San Francisco - 49ers (Local)
# 12           Carolina - Panthers  San Francisco - 49ers (Local)
# 13           Carolina - Panthers  San Francisco - 49ers (Local)
# 14           Carolina - Panthers  San Francisco - 49ers (Local)
# 15  New Orleans - Saints (Local)  San Francisco - 49ers (Local)
# 16           Carolina - Panthers  San Francisco - 49ers (Local)
# 17           Carolina - Panthers  San Francisco - 49ers (Local)
# 18  New Orleans - Saints (Local)  San Francisco - 49ers (Local)
# 19           Carolina - Panthers  San Francisco - 49ers (Local)
# 20           Carolina - Panthers  San Francisco - 49ers (Local)
# 21           Carolina - Panthers  San Francisco - 49ers (Local)
# 22           Carolina - Panthers  San Francisco - 49ers (Local)
# 23           Carolina - Panthers  San Francisco - 49ers (Local)
# 24           Carolina - Panthers  San Francisco - 49ers (Local)
# 25           Carolina - Panthers  San Francisco - 49ers (Local)
# 26           Carolina - Panthers  San Francisco - 49ers (Local)
# 27           Carolina - Panthers  San Francisco - 49ers (Local)
#
#                       Column13                  Column14  \
# 0         Indianapolis - Colts  Dallas - Cowboys (Local)
# 1   Seattle - Seahawks (Local)       Minnesota - Vikings
# 2   Seattle - Seahawks (Local)  Dallas - Cowboys (Local)
# 3   Seattle - Seahawks (Local)  Dallas - Cowboys (Local)
# 4   Seattle - Seahawks (Local)  Dallas - Cowboys (Local)
# 5   Seattle - Seahawks (Local)  Dallas - Cowboys (Local)
# 6   Seattle - Seahawks (Local)  Dallas - Cowboys (Local)
# 7   Seattle - Seahawks (Local)  Dallas - Cowboys (Local)
# 8   Seattle - Seahawks (Local)  Dallas - Cowboys (Local)
# 9   Seattle - Seahawks (Local)  Dallas - Cowboys (Local)
# 10  Seattle - Seahawks (Local)  Dallas - Cowboys (Local)
# 11  Seattle - Seahawks (Local)  Dallas - Cowboys (Local)
# 12  Seattle - Seahawks (Local)  Dallas - Cowboys (Local)
# 13  Seattle - Seahawks (Local)  Dallas - Cowboys (Local)
# 14  Seattle - Seahawks (Local)  Dallas - Cowboys (Local)
# 15  Seattle - Seahawks (Local)  Dallas - Cowboys (Local)
# 16  Seattle - Seahawks (Local)  Dallas - Cowboys (Local)
# 17  Seattle - Seahawks (Local)  Dallas - Cowboys (Local)
# 18  Seattle - Seahawks (Local)  Dallas - Cowboys (Local)
# 19  Seattle - Seahawks (Local)  Dallas - Cowboys (Local)
# 20  Seattle - Seahawks (Local)  Dallas - Cowboys (Local)
# 21  Seattle - Seahawks (Local)  Dallas - Cowboys (Local)
# 22  Seattle - Seahawks (Local)  Dallas - Cowboys (Local)
# 23  Seattle - Seahawks (Local)  Dallas - Cowboys (Local)
# 24  Seattle - Seahawks (Local)  Dallas - Cowboys (Local)
# 25  Seattle - Seahawks (Local)  Dallas - Cowboys (Local)
# 26  Seattle - Seahawks (Local)  Dallas - Cowboys (Local)
# 27  Seattle - Seahawks (Local)  Dallas - Cowboys (Local)
#
#                          Column15  \
# 0   Pittsburgh - Steelers (Local)
# 1   Pittsburgh - Steelers (Local)
# 2   Pittsburgh - Steelers (Local)
# 3                Miami - Dolphins
# 4   Pittsburgh - Steelers (Local)
# 5   Pittsburgh - Steelers (Local)
# 6   Pittsburgh - Steelers (Local)
# 7   Pittsburgh - Steelers (Local)
# 8   Pittsburgh - Steelers (Local)
# 9   Pittsburgh - Steelers (Local)
# 10  Pittsburgh - Steelers (Local)
# 11  Pittsburgh - Steelers (Local)
# 12  Pittsburgh - Steelers (Local)
# 13  Pittsburgh - Steelers (Local)
# 14  Pittsburgh - Steelers (Local)
# 15  Pittsburgh - Steelers (Local)
# 16  Pittsburgh - Steelers (Local)
# 17  Pittsburgh - Steelers (Local)
# 18               Miami - Dolphins
# 19  Pittsburgh - Steelers (Local)
# 20  Pittsburgh - Steelers (Local)
# 21  Pittsburgh - Steelers (Local)
# 22  Pittsburgh - Steelers (Local)
# 23  Pittsburgh - Steelers (Local)
# 24  Pittsburgh - Steelers (Local)
# 25  Pittsburgh - Steelers (Local)
# 26  Pittsburgh - Steelers (Local)
# 27  Pittsburgh - Steelers (Local)
#
#    Puntos totales del juego entre Miami y Pittsburgh para desempate:
# 0                                                  49
# 1                                                  44
# 2                                                  42
# 3                                                  49
# 4                                                  43
# 5                                                  32
# 6                                                  45
# 7                                                  41
# 8                                                  35
# 9                                                  42
# 10                                                 42
# 11                                                 51
# 12                                                 47
# 13                                                 46
# 14                                                 41
# 15                                                 48
# 16                                                 44
# 17                                                 42
# 18                                                 48
# 19                                                 41
# 20                                                 42
# 21                                                 43
# 22                                                 42
# 23                                                 42
# 24                                                 46
# 25                                                 40
# 26                                                 40
# 27                                                 44
#
# [28 rows x 25 columns]

# %%
quiniela_semana_actual = respuestas[respuestas['semana'] == numero]
quiniela_semana_actual = quiniela_semana_actual.drop(columns=['Start time', 
                                                              'Language',
                                                              'Completion time', 
                                                              'Email', 
                                                              'semana', 
                                                              'fecha',
                                                              'Id'])

quiniela_semana_actual.columns = [quiniela_semana_actual.columns[0]] + list(range(1, 
                                                                                  len(quiniela_semana_actual.columns)))

quiniela_semana_actual.columns = list(quiniela_semana_actual.columns[:-1]) + ['Desempate']
faltaron = []
for i in inscritos_quiniela:
    if i not in quiniela_semana_actual['Participante'].values:
        faltaron.append(i)


nombre_quiniela_semanal = f'Quiniela Semana {numero} NFL 2025.xlsx'
excel_quiniela_semanal = quiniela_semana_actual.to_excel(nombre_quiniela_semanal, 
                                                         index=False,
                                                         sheet_name=f'{numero}',
                                                         header=None)

quiniela_semana_actual
# Out:
#                          Participante                               1  \
# 0              Marisela Chacón Molina  Tampa Bay - Buccaneers (Local)
# 1                 Maribel Baeza Adame  Tampa Bay - Buccaneers (Local)
# 2                Alberto Vargas Ortiz  Tampa Bay - Buccaneers (Local)
# 3   Manuel Alejandro Escobar Aguilera  Tampa Bay - Buccaneers (Local)
# 4             Andrea Bustamante Yapur  Tampa Bay - Buccaneers (Local)
# 5           Ana Alejandra Donati Lugo  Tampa Bay - Buccaneers (Local)
# 6      Guiorguio Guitto Sánchez Muñoz               Atlanta - Falcons
# 7           Ezequiel Chávez Gutierrez  Tampa Bay - Buccaneers (Local)
# 8     Gerardo Abraham Ayala Siqueiros  Tampa Bay - Buccaneers (Local)
# 9           José Carlos Salgado Gómez  Tampa Bay - Buccaneers (Local)
# 10            Luis Mendoza Armendáriz  Tampa Bay - Buccaneers (Local)
# 11            Judith Fernández Franco  Tampa Bay - Buccaneers (Local)
# 12              Arelí Olivas Alcántar  Tampa Bay - Buccaneers (Local)
# 13        Kenia Estefanía Cruz García  Tampa Bay - Buccaneers (Local)
# 14       Raúl Humberto García Robledo  Tampa Bay - Buccaneers (Local)
# 15             Erick Benavides Correa               Atlanta - Falcons
# 16    José Roberto González Hernández  Tampa Bay - Buccaneers (Local)
# 17        Derek Manuel Calderón Rubio  Tampa Bay - Buccaneers (Local)
# 18       Jaime Antonio García Morales  Tampa Bay - Buccaneers (Local)
# 19           Neima Dorely Meza Jáquez  Tampa Bay - Buccaneers (Local)
# 20              Ilse Lozano Rodríguez  Tampa Bay - Buccaneers (Local)
# 21          Alejandro Barragán Huerta  Tampa Bay - Buccaneers (Local)
# 22               Santos Vazquez Garza  Tampa Bay - Buccaneers (Local)
# 23           Luis Alberto López Mónge  Tampa Bay - Buccaneers (Local)
# 24              Jerónimo Reyes Ibarra  Tampa Bay - Buccaneers (Local)
# 25     Jaime Jesús Irigoyen Hernández  Tampa Bay - Buccaneers (Local)
# 26     Cynthia Jaqueline Peralta Sosa  Tampa Bay - Buccaneers (Local)
# 27           Magaly Teresa Ochoa Lugo  Tampa Bay - Buccaneers (Local)
#
#                           2                             3  \
# 0   Chicago - Bears (Local)            Baltimore - Ravens
# 1   Chicago - Bears (Local)            Baltimore - Ravens
# 2   Chicago - Bears (Local)            Baltimore - Ravens
# 3   Chicago - Bears (Local)  Cincinnati - Bengals (Local)
# 4   Chicago - Bears (Local)            Baltimore - Ravens
# 5   Chicago - Bears (Local)  Cincinnati - Bengals (Local)
# 6   Chicago - Bears (Local)  Cincinnati - Bengals (Local)
# 7   Chicago - Bears (Local)  Cincinnati - Bengals (Local)
# 8   Chicago - Bears (Local)            Baltimore - Ravens
# 9   Chicago - Bears (Local)  Cincinnati - Bengals (Local)
# 10  Chicago - Bears (Local)            Baltimore - Ravens
# 11  Chicago - Bears (Local)            Baltimore - Ravens
# 12  Chicago - Bears (Local)            Baltimore - Ravens
# 13  Chicago - Bears (Local)  Cincinnati - Bengals (Local)
# 14  Chicago - Bears (Local)            Baltimore - Ravens
# 15       Cleveland - Browns            Baltimore - Ravens
# 16  Chicago - Bears (Local)  Cincinnati - Bengals (Local)
# 17  Chicago - Bears (Local)  Cincinnati - Bengals (Local)
# 18  Chicago - Bears (Local)            Baltimore - Ravens
# 19  Chicago - Bears (Local)            Baltimore - Ravens
# 20  Chicago - Bears (Local)  Cincinnati - Bengals (Local)
# 21  Chicago - Bears (Local)            Baltimore - Ravens
# 22  Chicago - Bears (Local)            Baltimore - Ravens
# 23  Chicago - Bears (Local)  Cincinnati - Bengals (Local)
# 24  Chicago - Bears (Local)  Cincinnati - Bengals (Local)
# 25  Chicago - Bears (Local)            Baltimore - Ravens
# 26  Chicago - Bears (Local)  Cincinnati - Bengals (Local)
# 27  Chicago - Bears (Local)  Cincinnati - Bengals (Local)
#
#                                4                               5  \
# 0         Los Angeles - Chargers                 Buffalo - Bills
# 1         Los Angeles - Chargers                 Buffalo - Bills
# 2   Kansas City - Chiefs (Local)  New England - Patriots (Local)
# 3   Kansas City - Chiefs (Local)  New England - Patriots (Local)
# 4         Los Angeles - Chargers  New England - Patriots (Local)
# 5   Kansas City - Chiefs (Local)  New England - Patriots (Local)
# 6   Kansas City - Chiefs (Local)                 Buffalo - Bills
# 7   Kansas City - Chiefs (Local)  New England - Patriots (Local)
# 8   Kansas City - Chiefs (Local)  New England - Patriots (Local)
# 9         Los Angeles - Chargers                 Buffalo - Bills
# 10  Kansas City - Chiefs (Local)  New England - Patriots (Local)
# 11  Kansas City - Chiefs (Local)                 Buffalo - Bills
# 12  Kansas City - Chiefs (Local)  New England - Patriots (Local)
# 13        Los Angeles - Chargers  New England - Patriots (Local)
# 14  Kansas City - Chiefs (Local)                 Buffalo - Bills
# 15  Kansas City - Chiefs (Local)  New England - Patriots (Local)
# 16        Los Angeles - Chargers  New England - Patriots (Local)
# 17        Los Angeles - Chargers  New England - Patriots (Local)
# 18  Kansas City - Chiefs (Local)  New England - Patriots (Local)
# 19  Kansas City - Chiefs (Local)  New England - Patriots (Local)
# 20  Kansas City - Chiefs (Local)  New England - Patriots (Local)
# 21  Kansas City - Chiefs (Local)                 Buffalo - Bills
# 22  Kansas City - Chiefs (Local)  New England - Patriots (Local)
# 23  Kansas City - Chiefs (Local)                 Buffalo - Bills
# 24        Los Angeles - Chargers                 Buffalo - Bills
# 25  Kansas City - Chiefs (Local)  New England - Patriots (Local)
# 26  Kansas City - Chiefs (Local)  New England - Patriots (Local)
# 27  Kansas City - Chiefs (Local)  New England - Patriots (Local)
#
#                             6                              7  \
# 0     Washington - Commanders  Philadelphia - Eagles (Local)
# 1   New York - Giants (Local)  Philadelphia - Eagles (Local)
# 2   New York - Giants (Local)  Philadelphia - Eagles (Local)
# 3   New York - Giants (Local)  Philadelphia - Eagles (Local)
# 4   New York - Giants (Local)  Philadelphia - Eagles (Local)
# 5   New York - Giants (Local)  Philadelphia - Eagles (Local)
# 6   New York - Giants (Local)  Philadelphia - Eagles (Local)
# 7   New York - Giants (Local)  Philadelphia - Eagles (Local)
# 8   New York - Giants (Local)  Philadelphia - Eagles (Local)
# 9   New York - Giants (Local)  Philadelphia - Eagles (Local)
# 10  New York - Giants (Local)  Philadelphia - Eagles (Local)
# 11    Washington - Commanders  Philadelphia - Eagles (Local)
# 12  New York - Giants (Local)  Philadelphia - Eagles (Local)
# 13  New York - Giants (Local)  Philadelphia - Eagles (Local)
# 14  New York - Giants (Local)  Philadelphia - Eagles (Local)
# 15  New York - Giants (Local)  Philadelphia - Eagles (Local)
# 16  New York - Giants (Local)  Philadelphia - Eagles (Local)
# 17  New York - Giants (Local)  Philadelphia - Eagles (Local)
# 18  New York - Giants (Local)  Philadelphia - Eagles (Local)
# 19    Washington - Commanders  Philadelphia - Eagles (Local)
# 20  New York - Giants (Local)  Philadelphia - Eagles (Local)
# 21    Washington - Commanders  Philadelphia - Eagles (Local)
# 22  New York - Giants (Local)  Philadelphia - Eagles (Local)
# 23  New York - Giants (Local)  Philadelphia - Eagles (Local)
# 24  New York - Giants (Local)  Philadelphia - Eagles (Local)
# 25  New York - Giants (Local)  Philadelphia - Eagles (Local)
# 26  New York - Giants (Local)  Philadelphia - Eagles (Local)
# 27  New York - Giants (Local)  Philadelphia - Eagles (Local)
#
#                                  8                         9  \
# 0   Jacksonville - Jaguars (Local)  Houston - Texans (Local)
# 1   Jacksonville - Jaguars (Local)  Houston - Texans (Local)
# 2   Jacksonville - Jaguars (Local)  Houston - Texans (Local)
# 3   Jacksonville - Jaguars (Local)  Houston - Texans (Local)
# 4   Jacksonville - Jaguars (Local)  Houston - Texans (Local)
# 5   Jacksonville - Jaguars (Local)  Houston - Texans (Local)
# 6   Jacksonville - Jaguars (Local)  Houston - Texans (Local)
# 7   Jacksonville - Jaguars (Local)  Houston - Texans (Local)
# 8   Jacksonville - Jaguars (Local)  Houston - Texans (Local)
# 9   Jacksonville - Jaguars (Local)  Houston - Texans (Local)
# 10  Jacksonville - Jaguars (Local)  Houston - Texans (Local)
# 11  Jacksonville - Jaguars (Local)  Houston - Texans (Local)
# 12  Jacksonville - Jaguars (Local)  Houston - Texans (Local)
# 13  Jacksonville - Jaguars (Local)  Houston - Texans (Local)
# 14  Jacksonville - Jaguars (Local)  Houston - Texans (Local)
# 15  Jacksonville - Jaguars (Local)       Arizona - Cardinals
# 16  Jacksonville - Jaguars (Local)  Houston - Texans (Local)
# 17  Jacksonville - Jaguars (Local)  Houston - Texans (Local)
# 18  Jacksonville - Jaguars (Local)  Houston - Texans (Local)
# 19  Jacksonville - Jaguars (Local)  Houston - Texans (Local)
# 20  Jacksonville - Jaguars (Local)  Houston - Texans (Local)
# 21  Jacksonville - Jaguars (Local)  Houston - Texans (Local)
# 22  Jacksonville - Jaguars (Local)  Houston - Texans (Local)
# 23  Jacksonville - Jaguars (Local)  Houston - Texans (Local)
# 24  Jacksonville - Jaguars (Local)  Houston - Texans (Local)
# 25  Jacksonville - Jaguars (Local)  Houston - Texans (Local)
# 26  Jacksonville - Jaguars (Local)  Houston - Texans (Local)
# 27  Jacksonville - Jaguars (Local)  Houston - Texans (Local)
#
#                           10                          11  \
# 0        Green Bay - Packers  Los Angeles - Rams (Local)
# 1   Denver - Broncos (Local)  Los Angeles - Rams (Local)
# 2   Denver - Broncos (Local)  Los Angeles - Rams (Local)
# 3   Denver - Broncos (Local)             Detroit - Lions
# 4        Green Bay - Packers  Los Angeles - Rams (Local)
# 5   Denver - Broncos (Local)  Los Angeles - Rams (Local)
# 6        Green Bay - Packers             Detroit - Lions
# 7   Denver - Broncos (Local)  Los Angeles - Rams (Local)
# 8   Denver - Broncos (Local)  Los Angeles - Rams (Local)
# 9        Green Bay - Packers             Detroit - Lions
# 10       Green Bay - Packers  Los Angeles - Rams (Local)
# 11  Denver - Broncos (Local)  Los Angeles - Rams (Local)
# 12       Green Bay - Packers  Los Angeles - Rams (Local)
# 13       Green Bay - Packers  Los Angeles - Rams (Local)
# 14       Green Bay - Packers  Los Angeles - Rams (Local)
# 15       Green Bay - Packers             Detroit - Lions
# 16       Green Bay - Packers             Detroit - Lions
# 17  Denver - Broncos (Local)  Los Angeles - Rams (Local)
# 18  Denver - Broncos (Local)  Los Angeles - Rams (Local)
# 19       Green Bay - Packers             Detroit - Lions
# 20       Green Bay - Packers  Los Angeles - Rams (Local)
# 21       Green Bay - Packers  Los Angeles - Rams (Local)
# 22  Denver - Broncos (Local)  Los Angeles - Rams (Local)
# 23       Green Bay - Packers  Los Angeles - Rams (Local)
# 24       Green Bay - Packers  Los Angeles - Rams (Local)
# 25  Denver - Broncos (Local)  Los Angeles - Rams (Local)
# 26  Denver - Broncos (Local)  Los Angeles - Rams (Local)
# 27  Denver - Broncos (Local)  Los Angeles - Rams (Local)
#
#                               12                             13  \
# 0            Carolina - Panthers  San Francisco - 49ers (Local)
# 1   New Orleans - Saints (Local)  San Francisco - 49ers (Local)
# 2            Carolina - Panthers  San Francisco - 49ers (Local)
# 3            Carolina - Panthers  San Francisco - 49ers (Local)
# 4            Carolina - Panthers  San Francisco - 49ers (Local)
# 5   New Orleans - Saints (Local)  San Francisco - 49ers (Local)
# 6   New Orleans - Saints (Local)  San Francisco - 49ers (Local)
# 7            Carolina - Panthers  San Francisco - 49ers (Local)
# 8            Carolina - Panthers  San Francisco - 49ers (Local)
# 9            Carolina - Panthers  San Francisco - 49ers (Local)
# 10           Carolina - Panthers  San Francisco - 49ers (Local)
# 11           Carolina - Panthers  San Francisco - 49ers (Local)
# 12           Carolina - Panthers  San Francisco - 49ers (Local)
# 13           Carolina - Panthers  San Francisco - 49ers (Local)
# 14           Carolina - Panthers  San Francisco - 49ers (Local)
# 15  New Orleans - Saints (Local)  San Francisco - 49ers (Local)
# 16           Carolina - Panthers  San Francisco - 49ers (Local)
# 17           Carolina - Panthers  San Francisco - 49ers (Local)
# 18  New Orleans - Saints (Local)  San Francisco - 49ers (Local)
# 19           Carolina - Panthers  San Francisco - 49ers (Local)
# 20           Carolina - Panthers  San Francisco - 49ers (Local)
# 21           Carolina - Panthers  San Francisco - 49ers (Local)
# 22           Carolina - Panthers  San Francisco - 49ers (Local)
# 23           Carolina - Panthers  San Francisco - 49ers (Local)
# 24           Carolina - Panthers  San Francisco - 49ers (Local)
# 25           Carolina - Panthers  San Francisco - 49ers (Local)
# 26           Carolina - Panthers  San Francisco - 49ers (Local)
# 27           Carolina - Panthers  San Francisco - 49ers (Local)
#
#                             14                        15  \
# 0         Indianapolis - Colts  Dallas - Cowboys (Local)
# 1   Seattle - Seahawks (Local)       Minnesota - Vikings
# 2   Seattle - Seahawks (Local)  Dallas - Cowboys (Local)
# 3   Seattle - Seahawks (Local)  Dallas - Cowboys (Local)
# 4   Seattle - Seahawks (Local)  Dallas - Cowboys (Local)
# 5   Seattle - Seahawks (Local)  Dallas - Cowboys (Local)
# 6   Seattle - Seahawks (Local)  Dallas - Cowboys (Local)
# 7   Seattle - Seahawks (Local)  Dallas - Cowboys (Local)
# 8   Seattle - Seahawks (Local)  Dallas - Cowboys (Local)
# 9   Seattle - Seahawks (Local)  Dallas - Cowboys (Local)
# 10  Seattle - Seahawks (Local)  Dallas - Cowboys (Local)
# 11  Seattle - Seahawks (Local)  Dallas - Cowboys (Local)
# 12  Seattle - Seahawks (Local)  Dallas - Cowboys (Local)
# 13  Seattle - Seahawks (Local)  Dallas - Cowboys (Local)
# 14  Seattle - Seahawks (Local)  Dallas - Cowboys (Local)
# 15  Seattle - Seahawks (Local)  Dallas - Cowboys (Local)
# 16  Seattle - Seahawks (Local)  Dallas - Cowboys (Local)
# 17  Seattle - Seahawks (Local)  Dallas - Cowboys (Local)
# 18  Seattle - Seahawks (Local)  Dallas - Cowboys (Local)
# 19  Seattle - Seahawks (Local)  Dallas - Cowboys (Local)
# 20  Seattle - Seahawks (Local)  Dallas - Cowboys (Local)
# 21  Seattle - Seahawks (Local)  Dallas - Cowboys (Local)
# 22  Seattle - Seahawks (Local)  Dallas - Cowboys (Local)
# 23  Seattle - Seahawks (Local)  Dallas - Cowboys (Local)
# 24  Seattle - Seahawks (Local)  Dallas - Cowboys (Local)
# 25  Seattle - Seahawks (Local)  Dallas - Cowboys (Local)
# 26  Seattle - Seahawks (Local)  Dallas - Cowboys (Local)
# 27  Seattle - Seahawks (Local)  Dallas - Cowboys (Local)
#
#                                16  Desempate
# 0   Pittsburgh - Steelers (Local)         49
# 1   Pittsburgh - Steelers (Local)         44
# 2   Pittsburgh - Steelers (Local)         42
# 3                Miami - Dolphins         49
# 4   Pittsburgh - Steelers (Local)         43
# 5   Pittsburgh - Steelers (Local)         32
# 6   Pittsburgh - Steelers (Local)         45
# 7   Pittsburgh - Steelers (Local)         41
# 8   Pittsburgh - Steelers (Local)         35
# 9   Pittsburgh - Steelers (Local)         42
# 10  Pittsburgh - Steelers (Local)         42
# 11  Pittsburgh - Steelers (Local)         51
# 12  Pittsburgh - Steelers (Local)         47
# 13  Pittsburgh - Steelers (Local)         46
# 14  Pittsburgh - Steelers (Local)         41
# 15  Pittsburgh - Steelers (Local)         48
# 16  Pittsburgh - Steelers (Local)         44
# 17  Pittsburgh - Steelers (Local)         42
# 18               Miami - Dolphins         48
# 19  Pittsburgh - Steelers (Local)         41
# 20  Pittsburgh - Steelers (Local)         42
# 21  Pittsburgh - Steelers (Local)         43
# 22  Pittsburgh - Steelers (Local)         42
# 23  Pittsburgh - Steelers (Local)         42
# 24  Pittsburgh - Steelers (Local)         46
# 25  Pittsburgh - Steelers (Local)         40
# 26  Pittsburgh - Steelers (Local)         40
# 27  Pittsburgh - Steelers (Local)         44

# %%
import pandas as pd
from openpyxl import load_workbook

archivo_existente = 'NFL Quinela 2025.xlsx'
nombre_hoja = f'{numero}'

# Cargar el libro
book = load_workbook(archivo_existente)

# Eliminar la hoja si ya existe
if nombre_hoja in book.sheetnames:
    std = book[nombre_hoja]
    book.remove(std)
    book.save(archivo_existente)

# Escribir la nueva hoja
with pd.ExcelWriter(archivo_existente, engine='openpyxl', mode='a') as writer:
    quiniela_semana_actual.to_excel(writer, index=False, sheet_name=nombre_hoja,header=None)

quinela = pd.read_excel(archivo_existente, 
                        sheet_name = None, 
                        header = None, 
                        index_col=0)


quinela = {sheet: df[~df.index.isin(bajas)] for sheet, 
           df in quinela.items()}

semanas = [int(semana) for semana in quinela.keys()]
semana_numero = max(semanas)
semana = str(semana_numero)


quinela_semanal = quinela[semana]

#quinela_semanal.index.name = 'Participante'
#quinela_semanal = list(quinela_semanal.columns[:-1]) + ['Desempate']
quiniela_df = pd.DataFrame(quinela_semanal)
quiniela_df
# Out:
#                                                                1   \
# 0
# Marisela Chacón Molina             Tampa Bay - Buccaneers (Local)
# Maribel Baeza Adame                Tampa Bay - Buccaneers (Local)
# Alberto Vargas Ortiz               Tampa Bay - Buccaneers (Local)
# Manuel Alejandro Escobar Aguilera  Tampa Bay - Buccaneers (Local)
# Andrea Bustamante Yapur            Tampa Bay - Buccaneers (Local)
# Ana Alejandra Donati Lugo          Tampa Bay - Buccaneers (Local)
# Guiorguio Guitto Sánchez Muñoz                  Atlanta - Falcons
# Ezequiel Chávez Gutierrez          Tampa Bay - Buccaneers (Local)
# Gerardo Abraham Ayala Siqueiros    Tampa Bay - Buccaneers (Local)
# José Carlos Salgado Gómez          Tampa Bay - Buccaneers (Local)
# Luis Mendoza Armendáriz            Tampa Bay - Buccaneers (Local)
# Judith Fernández Franco            Tampa Bay - Buccaneers (Local)
# Arelí Olivas Alcántar              Tampa Bay - Buccaneers (Local)
# Kenia Estefanía Cruz García        Tampa Bay - Buccaneers (Local)
# Raúl Humberto García Robledo       Tampa Bay - Buccaneers (Local)
# Erick Benavides Correa                          Atlanta - Falcons
# José Roberto González Hernández    Tampa Bay - Buccaneers (Local)
# Derek Manuel Calderón Rubio        Tampa Bay - Buccaneers (Local)
# Jaime Antonio García Morales       Tampa Bay - Buccaneers (Local)
# Neima Dorely Meza Jáquez           Tampa Bay - Buccaneers (Local)
# Ilse Lozano Rodríguez              Tampa Bay - Buccaneers (Local)
# Alejandro Barragán Huerta          Tampa Bay - Buccaneers (Local)
# Santos Vazquez Garza               Tampa Bay - Buccaneers (Local)
# Luis Alberto López Mónge           Tampa Bay - Buccaneers (Local)
# Jerónimo Reyes Ibarra              Tampa Bay - Buccaneers (Local)
# Jaime Jesús Irigoyen Hernández     Tampa Bay - Buccaneers (Local)
# Cynthia Jaqueline Peralta Sosa     Tampa Bay - Buccaneers (Local)
# Magaly Teresa Ochoa Lugo           Tampa Bay - Buccaneers (Local)
#
#                                                         2   \
# 0
# Marisela Chacón Molina             Chicago - Bears (Local)
# Maribel Baeza Adame                Chicago - Bears (Local)
# Alberto Vargas Ortiz               Chicago - Bears (Local)
# Manuel Alejandro Escobar Aguilera  Chicago - Bears (Local)
# Andrea Bustamante Yapur            Chicago - Bears (Local)
# Ana Alejandra Donati Lugo          Chicago - Bears (Local)
# Guiorguio Guitto Sánchez Muñoz     Chicago - Bears (Local)
# Ezequiel Chávez Gutierrez          Chicago - Bears (Local)
# Gerardo Abraham Ayala Siqueiros    Chicago - Bears (Local)
# José Carlos Salgado Gómez          Chicago - Bears (Local)
# Luis Mendoza Armendáriz            Chicago - Bears (Local)
# Judith Fernández Franco            Chicago - Bears (Local)
# Arelí Olivas Alcántar              Chicago - Bears (Local)
# Kenia Estefanía Cruz García        Chicago - Bears (Local)
# Raúl Humberto García Robledo       Chicago - Bears (Local)
# Erick Benavides Correa                  Cleveland - Browns
# José Roberto González Hernández    Chicago - Bears (Local)
# Derek Manuel Calderón Rubio        Chicago - Bears (Local)
# Jaime Antonio García Morales       Chicago - Bears (Local)
# Neima Dorely Meza Jáquez           Chicago - Bears (Local)
# Ilse Lozano Rodríguez              Chicago - Bears (Local)
# Alejandro Barragán Huerta          Chicago - Bears (Local)
# Santos Vazquez Garza               Chicago - Bears (Local)
# Luis Alberto López Mónge           Chicago - Bears (Local)
# Jerónimo Reyes Ibarra              Chicago - Bears (Local)
# Jaime Jesús Irigoyen Hernández     Chicago - Bears (Local)
# Cynthia Jaqueline Peralta Sosa     Chicago - Bears (Local)
# Magaly Teresa Ochoa Lugo           Chicago - Bears (Local)
#
#                                                              3   \
# 0
# Marisela Chacón Molina                       Baltimore - Ravens
# Maribel Baeza Adame                          Baltimore - Ravens
# Alberto Vargas Ortiz                         Baltimore - Ravens
# Manuel Alejandro Escobar Aguilera  Cincinnati - Bengals (Local)
# Andrea Bustamante Yapur                      Baltimore - Ravens
# Ana Alejandra Donati Lugo          Cincinnati - Bengals (Local)
# Guiorguio Guitto Sánchez Muñoz     Cincinnati - Bengals (Local)
# Ezequiel Chávez Gutierrez          Cincinnati - Bengals (Local)
# Gerardo Abraham Ayala Siqueiros              Baltimore - Ravens
# José Carlos Salgado Gómez          Cincinnati - Bengals (Local)
# Luis Mendoza Armendáriz                      Baltimore - Ravens
# Judith Fernández Franco                      Baltimore - Ravens
# Arelí Olivas Alcántar                        Baltimore - Ravens
# Kenia Estefanía Cruz García        Cincinnati - Bengals (Local)
# Raúl Humberto García Robledo                 Baltimore - Ravens
# Erick Benavides Correa                       Baltimore - Ravens
# José Roberto González Hernández    Cincinnati - Bengals (Local)
# Derek Manuel Calderón Rubio        Cincinnati - Bengals (Local)
# Jaime Antonio García Morales                 Baltimore - Ravens
# Neima Dorely Meza Jáquez                     Baltimore - Ravens
# Ilse Lozano Rodríguez              Cincinnati - Bengals (Local)
# Alejandro Barragán Huerta                    Baltimore - Ravens
# Santos Vazquez Garza                         Baltimore - Ravens
# Luis Alberto López Mónge           Cincinnati - Bengals (Local)
# Jerónimo Reyes Ibarra              Cincinnati - Bengals (Local)
# Jaime Jesús Irigoyen Hernández               Baltimore - Ravens
# Cynthia Jaqueline Peralta Sosa     Cincinnati - Bengals (Local)
# Magaly Teresa Ochoa Lugo           Cincinnati - Bengals (Local)
#
#                                                              4   \
# 0
# Marisela Chacón Molina                   Los Angeles - Chargers
# Maribel Baeza Adame                      Los Angeles - Chargers
# Alberto Vargas Ortiz               Kansas City - Chiefs (Local)
# Manuel Alejandro Escobar Aguilera  Kansas City - Chiefs (Local)
# Andrea Bustamante Yapur                  Los Angeles - Chargers
# Ana Alejandra Donati Lugo          Kansas City - Chiefs (Local)
# Guiorguio Guitto Sánchez Muñoz     Kansas City - Chiefs (Local)
# Ezequiel Chávez Gutierrez          Kansas City - Chiefs (Local)
# Gerardo Abraham Ayala Siqueiros    Kansas City - Chiefs (Local)
# José Carlos Salgado Gómez                Los Angeles - Chargers
# Luis Mendoza Armendáriz            Kansas City - Chiefs (Local)
# Judith Fernández Franco            Kansas City - Chiefs (Local)
# Arelí Olivas Alcántar              Kansas City - Chiefs (Local)
# Kenia Estefanía Cruz García              Los Angeles - Chargers
# Raúl Humberto García Robledo       Kansas City - Chiefs (Local)
# Erick Benavides Correa             Kansas City - Chiefs (Local)
# José Roberto González Hernández          Los Angeles - Chargers
# Derek Manuel Calderón Rubio              Los Angeles - Chargers
# Jaime Antonio García Morales       Kansas City - Chiefs (Local)
# Neima Dorely Meza Jáquez           Kansas City - Chiefs (Local)
# Ilse Lozano Rodríguez              Kansas City - Chiefs (Local)
# Alejandro Barragán Huerta          Kansas City - Chiefs (Local)
# Santos Vazquez Garza               Kansas City - Chiefs (Local)
# Luis Alberto López Mónge           Kansas City - Chiefs (Local)
# Jerónimo Reyes Ibarra                    Los Angeles - Chargers
# Jaime Jesús Irigoyen Hernández     Kansas City - Chiefs (Local)
# Cynthia Jaqueline Peralta Sosa     Kansas City - Chiefs (Local)
# Magaly Teresa Ochoa Lugo           Kansas City - Chiefs (Local)
#
#                                                                5   \
# 0
# Marisela Chacón Molina                            Buffalo - Bills
# Maribel Baeza Adame                               Buffalo - Bills
# Alberto Vargas Ortiz               New England - Patriots (Local)
# Manuel Alejandro Escobar Aguilera  New England - Patriots (Local)
# Andrea Bustamante Yapur            New England - Patriots (Local)
# Ana Alejandra Donati Lugo          New England - Patriots (Local)
# Guiorguio Guitto Sánchez Muñoz                    Buffalo - Bills
# Ezequiel Chávez Gutierrez          New England - Patriots (Local)
# Gerardo Abraham Ayala Siqueiros    New England - Patriots (Local)
# José Carlos Salgado Gómez                         Buffalo - Bills
# Luis Mendoza Armendáriz            New England - Patriots (Local)
# Judith Fernández Franco                           Buffalo - Bills
# Arelí Olivas Alcántar              New England - Patriots (Local)
# Kenia Estefanía Cruz García        New England - Patriots (Local)
# Raúl Humberto García Robledo                      Buffalo - Bills
# Erick Benavides Correa             New England - Patriots (Local)
# José Roberto González Hernández    New England - Patriots (Local)
# Derek Manuel Calderón Rubio        New England - Patriots (Local)
# Jaime Antonio García Morales       New England - Patriots (Local)
# Neima Dorely Meza Jáquez           New England - Patriots (Local)
# Ilse Lozano Rodríguez              New England - Patriots (Local)
# Alejandro Barragán Huerta                         Buffalo - Bills
# Santos Vazquez Garza               New England - Patriots (Local)
# Luis Alberto López Mónge                          Buffalo - Bills
# Jerónimo Reyes Ibarra                             Buffalo - Bills
# Jaime Jesús Irigoyen Hernández     New England - Patriots (Local)
# Cynthia Jaqueline Peralta Sosa     New England - Patriots (Local)
# Magaly Teresa Ochoa Lugo           New England - Patriots (Local)
#
#                                                           6   \
# 0
# Marisela Chacón Molina               Washington - Commanders
# Maribel Baeza Adame                New York - Giants (Local)
# Alberto Vargas Ortiz               New York - Giants (Local)
# Manuel Alejandro Escobar Aguilera  New York - Giants (Local)
# Andrea Bustamante Yapur            New York - Giants (Local)
# Ana Alejandra Donati Lugo          New York - Giants (Local)
# Guiorguio Guitto Sánchez Muñoz     New York - Giants (Local)
# Ezequiel Chávez Gutierrez          New York - Giants (Local)
# Gerardo Abraham Ayala Siqueiros    New York - Giants (Local)
# José Carlos Salgado Gómez          New York - Giants (Local)
# Luis Mendoza Armendáriz            New York - Giants (Local)
# Judith Fernández Franco              Washington - Commanders
# Arelí Olivas Alcántar              New York - Giants (Local)
# Kenia Estefanía Cruz García        New York - Giants (Local)
# Raúl Humberto García Robledo       New York - Giants (Local)
# Erick Benavides Correa             New York - Giants (Local)
# José Roberto González Hernández    New York - Giants (Local)
# Derek Manuel Calderón Rubio        New York - Giants (Local)
# Jaime Antonio García Morales       New York - Giants (Local)
# Neima Dorely Meza Jáquez             Washington - Commanders
# Ilse Lozano Rodríguez              New York - Giants (Local)
# Alejandro Barragán Huerta            Washington - Commanders
# Santos Vazquez Garza               New York - Giants (Local)
# Luis Alberto López Mónge           New York - Giants (Local)
# Jerónimo Reyes Ibarra              New York - Giants (Local)
# Jaime Jesús Irigoyen Hernández     New York - Giants (Local)
# Cynthia Jaqueline Peralta Sosa     New York - Giants (Local)
# Magaly Teresa Ochoa Lugo           New York - Giants (Local)
#
#                                                               7   \
# 0
# Marisela Chacón Molina             Philadelphia - Eagles (Local)
# Maribel Baeza Adame                Philadelphia - Eagles (Local)
# Alberto Vargas Ortiz               Philadelphia - Eagles (Local)
# Manuel Alejandro Escobar Aguilera  Philadelphia - Eagles (Local)
# Andrea Bustamante Yapur            Philadelphia - Eagles (Local)
# Ana Alejandra Donati Lugo          Philadelphia - Eagles (Local)
# Guiorguio Guitto Sánchez Muñoz     Philadelphia - Eagles (Local)
# Ezequiel Chávez Gutierrez          Philadelphia - Eagles (Local)
# Gerardo Abraham Ayala Siqueiros    Philadelphia - Eagles (Local)
# José Carlos Salgado Gómez          Philadelphia - Eagles (Local)
# Luis Mendoza Armendáriz            Philadelphia - Eagles (Local)
# Judith Fernández Franco            Philadelphia - Eagles (Local)
# Arelí Olivas Alcántar              Philadelphia - Eagles (Local)
# Kenia Estefanía Cruz García        Philadelphia - Eagles (Local)
# Raúl Humberto García Robledo       Philadelphia - Eagles (Local)
# Erick Benavides Correa             Philadelphia - Eagles (Local)
# José Roberto González Hernández    Philadelphia - Eagles (Local)
# Derek Manuel Calderón Rubio        Philadelphia - Eagles (Local)
# Jaime Antonio García Morales       Philadelphia - Eagles (Local)
# Neima Dorely Meza Jáquez           Philadelphia - Eagles (Local)
# Ilse Lozano Rodríguez              Philadelphia - Eagles (Local)
# Alejandro Barragán Huerta          Philadelphia - Eagles (Local)
# Santos Vazquez Garza               Philadelphia - Eagles (Local)
# Luis Alberto López Mónge           Philadelphia - Eagles (Local)
# Jerónimo Reyes Ibarra              Philadelphia - Eagles (Local)
# Jaime Jesús Irigoyen Hernández     Philadelphia - Eagles (Local)
# Cynthia Jaqueline Peralta Sosa     Philadelphia - Eagles (Local)
# Magaly Teresa Ochoa Lugo           Philadelphia - Eagles (Local)
#
#                                                                8   \
# 0
# Marisela Chacón Molina             Jacksonville - Jaguars (Local)
# Maribel Baeza Adame                Jacksonville - Jaguars (Local)
# Alberto Vargas Ortiz               Jacksonville - Jaguars (Local)
# Manuel Alejandro Escobar Aguilera  Jacksonville - Jaguars (Local)
# Andrea Bustamante Yapur            Jacksonville - Jaguars (Local)
# Ana Alejandra Donati Lugo          Jacksonville - Jaguars (Local)
# Guiorguio Guitto Sánchez Muñoz     Jacksonville - Jaguars (Local)
# Ezequiel Chávez Gutierrez          Jacksonville - Jaguars (Local)
# Gerardo Abraham Ayala Siqueiros    Jacksonville - Jaguars (Local)
# José Carlos Salgado Gómez          Jacksonville - Jaguars (Local)
# Luis Mendoza Armendáriz            Jacksonville - Jaguars (Local)
# Judith Fernández Franco            Jacksonville - Jaguars (Local)
# Arelí Olivas Alcántar              Jacksonville - Jaguars (Local)
# Kenia Estefanía Cruz García        Jacksonville - Jaguars (Local)
# Raúl Humberto García Robledo       Jacksonville - Jaguars (Local)
# Erick Benavides Correa             Jacksonville - Jaguars (Local)
# José Roberto González Hernández    Jacksonville - Jaguars (Local)
# Derek Manuel Calderón Rubio        Jacksonville - Jaguars (Local)
# Jaime Antonio García Morales       Jacksonville - Jaguars (Local)
# Neima Dorely Meza Jáquez           Jacksonville - Jaguars (Local)
# Ilse Lozano Rodríguez              Jacksonville - Jaguars (Local)
# Alejandro Barragán Huerta          Jacksonville - Jaguars (Local)
# Santos Vazquez Garza               Jacksonville - Jaguars (Local)
# Luis Alberto López Mónge           Jacksonville - Jaguars (Local)
# Jerónimo Reyes Ibarra              Jacksonville - Jaguars (Local)
# Jaime Jesús Irigoyen Hernández     Jacksonville - Jaguars (Local)
# Cynthia Jaqueline Peralta Sosa     Jacksonville - Jaguars (Local)
# Magaly Teresa Ochoa Lugo           Jacksonville - Jaguars (Local)
#
#                                                          9   \
# 0
# Marisela Chacón Molina             Houston - Texans (Local)
# Maribel Baeza Adame                Houston - Texans (Local)
# Alberto Vargas Ortiz               Houston - Texans (Local)
# Manuel Alejandro Escobar Aguilera  Houston - Texans (Local)
# Andrea Bustamante Yapur            Houston - Texans (Local)
# Ana Alejandra Donati Lugo          Houston - Texans (Local)
# Guiorguio Guitto Sánchez Muñoz     Houston - Texans (Local)
# Ezequiel Chávez Gutierrez          Houston - Texans (Local)
# Gerardo Abraham Ayala Siqueiros    Houston - Texans (Local)
# José Carlos Salgado Gómez          Houston - Texans (Local)
# Luis Mendoza Armendáriz            Houston - Texans (Local)
# Judith Fernández Franco            Houston - Texans (Local)
# Arelí Olivas Alcántar              Houston - Texans (Local)
# Kenia Estefanía Cruz García        Houston - Texans (Local)
# Raúl Humberto García Robledo       Houston - Texans (Local)
# Erick Benavides Correa                  Arizona - Cardinals
# José Roberto González Hernández    Houston - Texans (Local)
# Derek Manuel Calderón Rubio        Houston - Texans (Local)
# Jaime Antonio García Morales       Houston - Texans (Local)
# Neima Dorely Meza Jáquez           Houston - Texans (Local)
# Ilse Lozano Rodríguez              Houston - Texans (Local)
# Alejandro Barragán Huerta          Houston - Texans (Local)
# Santos Vazquez Garza               Houston - Texans (Local)
# Luis Alberto López Mónge           Houston - Texans (Local)
# Jerónimo Reyes Ibarra              Houston - Texans (Local)
# Jaime Jesús Irigoyen Hernández     Houston - Texans (Local)
# Cynthia Jaqueline Peralta Sosa     Houston - Texans (Local)
# Magaly Teresa Ochoa Lugo           Houston - Texans (Local)
#
#                                                          10  \
# 0
# Marisela Chacón Molina                  Green Bay - Packers
# Maribel Baeza Adame                Denver - Broncos (Local)
# Alberto Vargas Ortiz               Denver - Broncos (Local)
# Manuel Alejandro Escobar Aguilera  Denver - Broncos (Local)
# Andrea Bustamante Yapur                 Green Bay - Packers
# Ana Alejandra Donati Lugo          Denver - Broncos (Local)
# Guiorguio Guitto Sánchez Muñoz          Green Bay - Packers
# Ezequiel Chávez Gutierrez          Denver - Broncos (Local)
# Gerardo Abraham Ayala Siqueiros    Denver - Broncos (Local)
# José Carlos Salgado Gómez               Green Bay - Packers
# Luis Mendoza Armendáriz                 Green Bay - Packers
# Judith Fernández Franco            Denver - Broncos (Local)
# Arelí Olivas Alcántar                   Green Bay - Packers
# Kenia Estefanía Cruz García             Green Bay - Packers
# Raúl Humberto García Robledo            Green Bay - Packers
# Erick Benavides Correa                  Green Bay - Packers
# José Roberto González Hernández         Green Bay - Packers
# Derek Manuel Calderón Rubio        Denver - Broncos (Local)
# Jaime Antonio García Morales       Denver - Broncos (Local)
# Neima Dorely Meza Jáquez                Green Bay - Packers
# Ilse Lozano Rodríguez                   Green Bay - Packers
# Alejandro Barragán Huerta               Green Bay - Packers
# Santos Vazquez Garza               Denver - Broncos (Local)
# Luis Alberto López Mónge                Green Bay - Packers
# Jerónimo Reyes Ibarra                   Green Bay - Packers
# Jaime Jesús Irigoyen Hernández     Denver - Broncos (Local)
# Cynthia Jaqueline Peralta Sosa     Denver - Broncos (Local)
# Magaly Teresa Ochoa Lugo           Denver - Broncos (Local)
#
#                                                            11  \
# 0
# Marisela Chacón Molina             Los Angeles - Rams (Local)
# Maribel Baeza Adame                Los Angeles - Rams (Local)
# Alberto Vargas Ortiz               Los Angeles - Rams (Local)
# Manuel Alejandro Escobar Aguilera             Detroit - Lions
# Andrea Bustamante Yapur            Los Angeles - Rams (Local)
# Ana Alejandra Donati Lugo          Los Angeles - Rams (Local)
# Guiorguio Guitto Sánchez Muñoz                Detroit - Lions
# Ezequiel Chávez Gutierrez          Los Angeles - Rams (Local)
# Gerardo Abraham Ayala Siqueiros    Los Angeles - Rams (Local)
# José Carlos Salgado Gómez                     Detroit - Lions
# Luis Mendoza Armendáriz            Los Angeles - Rams (Local)
# Judith Fernández Franco            Los Angeles - Rams (Local)
# Arelí Olivas Alcántar              Los Angeles - Rams (Local)
# Kenia Estefanía Cruz García        Los Angeles - Rams (Local)
# Raúl Humberto García Robledo       Los Angeles - Rams (Local)
# Erick Benavides Correa                        Detroit - Lions
# José Roberto González Hernández               Detroit - Lions
# Derek Manuel Calderón Rubio        Los Angeles - Rams (Local)
# Jaime Antonio García Morales       Los Angeles - Rams (Local)
# Neima Dorely Meza Jáquez                      Detroit - Lions
# Ilse Lozano Rodríguez              Los Angeles - Rams (Local)
# Alejandro Barragán Huerta          Los Angeles - Rams (Local)
# Santos Vazquez Garza               Los Angeles - Rams (Local)
# Luis Alberto López Mónge           Los Angeles - Rams (Local)
# Jerónimo Reyes Ibarra              Los Angeles - Rams (Local)
# Jaime Jesús Irigoyen Hernández     Los Angeles - Rams (Local)
# Cynthia Jaqueline Peralta Sosa     Los Angeles - Rams (Local)
# Magaly Teresa Ochoa Lugo           Los Angeles - Rams (Local)
#
#                                                              12  \
# 0
# Marisela Chacón Molina                      Carolina - Panthers
# Maribel Baeza Adame                New Orleans - Saints (Local)
# Alberto Vargas Ortiz                        Carolina - Panthers
# Manuel Alejandro Escobar Aguilera           Carolina - Panthers
# Andrea Bustamante Yapur                     Carolina - Panthers
# Ana Alejandra Donati Lugo          New Orleans - Saints (Local)
# Guiorguio Guitto Sánchez Muñoz     New Orleans - Saints (Local)
# Ezequiel Chávez Gutierrez                   Carolina - Panthers
# Gerardo Abraham Ayala Siqueiros             Carolina - Panthers
# José Carlos Salgado Gómez                   Carolina - Panthers
# Luis Mendoza Armendáriz                     Carolina - Panthers
# Judith Fernández Franco                     Carolina - Panthers
# Arelí Olivas Alcántar                       Carolina - Panthers
# Kenia Estefanía Cruz García                 Carolina - Panthers
# Raúl Humberto García Robledo                Carolina - Panthers
# Erick Benavides Correa             New Orleans - Saints (Local)
# José Roberto González Hernández             Carolina - Panthers
# Derek Manuel Calderón Rubio                 Carolina - Panthers
# Jaime Antonio García Morales       New Orleans - Saints (Local)
# Neima Dorely Meza Jáquez                    Carolina - Panthers
# Ilse Lozano Rodríguez                       Carolina - Panthers
# Alejandro Barragán Huerta                   Carolina - Panthers
# Santos Vazquez Garza                        Carolina - Panthers
# Luis Alberto López Mónge                    Carolina - Panthers
# Jerónimo Reyes Ibarra                       Carolina - Panthers
# Jaime Jesús Irigoyen Hernández              Carolina - Panthers
# Cynthia Jaqueline Peralta Sosa              Carolina - Panthers
# Magaly Teresa Ochoa Lugo                    Carolina - Panthers
#
#                                                               13  \
# 0
# Marisela Chacón Molina             San Francisco - 49ers (Local)
# Maribel Baeza Adame                San Francisco - 49ers (Local)
# Alberto Vargas Ortiz               San Francisco - 49ers (Local)
# Manuel Alejandro Escobar Aguilera  San Francisco - 49ers (Local)
# Andrea Bustamante Yapur            San Francisco - 49ers (Local)
# Ana Alejandra Donati Lugo          San Francisco - 49ers (Local)
# Guiorguio Guitto Sánchez Muñoz     San Francisco - 49ers (Local)
# Ezequiel Chávez Gutierrez          San Francisco - 49ers (Local)
# Gerardo Abraham Ayala Siqueiros    San Francisco - 49ers (Local)
# José Carlos Salgado Gómez          San Francisco - 49ers (Local)
# Luis Mendoza Armendáriz            San Francisco - 49ers (Local)
# Judith Fernández Franco            San Francisco - 49ers (Local)
# Arelí Olivas Alcántar              San Francisco - 49ers (Local)
# Kenia Estefanía Cruz García        San Francisco - 49ers (Local)
# Raúl Humberto García Robledo       San Francisco - 49ers (Local)
# Erick Benavides Correa             San Francisco - 49ers (Local)
# José Roberto González Hernández    San Francisco - 49ers (Local)
# Derek Manuel Calderón Rubio        San Francisco - 49ers (Local)
# Jaime Antonio García Morales       San Francisco - 49ers (Local)
# Neima Dorely Meza Jáquez           San Francisco - 49ers (Local)
# Ilse Lozano Rodríguez              San Francisco - 49ers (Local)
# Alejandro Barragán Huerta          San Francisco - 49ers (Local)
# Santos Vazquez Garza               San Francisco - 49ers (Local)
# Luis Alberto López Mónge           San Francisco - 49ers (Local)
# Jerónimo Reyes Ibarra              San Francisco - 49ers (Local)
# Jaime Jesús Irigoyen Hernández     San Francisco - 49ers (Local)
# Cynthia Jaqueline Peralta Sosa     San Francisco - 49ers (Local)
# Magaly Teresa Ochoa Lugo           San Francisco - 49ers (Local)
#
#                                                            14  \
# 0
# Marisela Chacón Molina                   Indianapolis - Colts
# Maribel Baeza Adame                Seattle - Seahawks (Local)
# Alberto Vargas Ortiz               Seattle - Seahawks (Local)
# Manuel Alejandro Escobar Aguilera  Seattle - Seahawks (Local)
# Andrea Bustamante Yapur            Seattle - Seahawks (Local)
# Ana Alejandra Donati Lugo          Seattle - Seahawks (Local)
# Guiorguio Guitto Sánchez Muñoz     Seattle - Seahawks (Local)
# Ezequiel Chávez Gutierrez          Seattle - Seahawks (Local)
# Gerardo Abraham Ayala Siqueiros    Seattle - Seahawks (Local)
# José Carlos Salgado Gómez          Seattle - Seahawks (Local)
# Luis Mendoza Armendáriz            Seattle - Seahawks (Local)
# Judith Fernández Franco            Seattle - Seahawks (Local)
# Arelí Olivas Alcántar              Seattle - Seahawks (Local)
# Kenia Estefanía Cruz García        Seattle - Seahawks (Local)
# Raúl Humberto García Robledo       Seattle - Seahawks (Local)
# Erick Benavides Correa             Seattle - Seahawks (Local)
# José Roberto González Hernández    Seattle - Seahawks (Local)
# Derek Manuel Calderón Rubio        Seattle - Seahawks (Local)
# Jaime Antonio García Morales       Seattle - Seahawks (Local)
# Neima Dorely Meza Jáquez           Seattle - Seahawks (Local)
# Ilse Lozano Rodríguez              Seattle - Seahawks (Local)
# Alejandro Barragán Huerta          Seattle - Seahawks (Local)
# Santos Vazquez Garza               Seattle - Seahawks (Local)
# Luis Alberto López Mónge           Seattle - Seahawks (Local)
# Jerónimo Reyes Ibarra              Seattle - Seahawks (Local)
# Jaime Jesús Irigoyen Hernández     Seattle - Seahawks (Local)
# Cynthia Jaqueline Peralta Sosa     Seattle - Seahawks (Local)
# Magaly Teresa Ochoa Lugo           Seattle - Seahawks (Local)
#
#                                                          15  \
# 0
# Marisela Chacón Molina             Dallas - Cowboys (Local)
# Maribel Baeza Adame                     Minnesota - Vikings
# Alberto Vargas Ortiz               Dallas - Cowboys (Local)
# Manuel Alejandro Escobar Aguilera  Dallas - Cowboys (Local)
# Andrea Bustamante Yapur            Dallas - Cowboys (Local)
# Ana Alejandra Donati Lugo          Dallas - Cowboys (Local)
# Guiorguio Guitto Sánchez Muñoz     Dallas - Cowboys (Local)
# Ezequiel Chávez Gutierrez          Dallas - Cowboys (Local)
# Gerardo Abraham Ayala Siqueiros    Dallas - Cowboys (Local)
# José Carlos Salgado Gómez          Dallas - Cowboys (Local)
# Luis Mendoza Armendáriz            Dallas - Cowboys (Local)
# Judith Fernández Franco            Dallas - Cowboys (Local)
# Arelí Olivas Alcántar              Dallas - Cowboys (Local)
# Kenia Estefanía Cruz García        Dallas - Cowboys (Local)
# Raúl Humberto García Robledo       Dallas - Cowboys (Local)
# Erick Benavides Correa             Dallas - Cowboys (Local)
# José Roberto González Hernández    Dallas - Cowboys (Local)
# Derek Manuel Calderón Rubio        Dallas - Cowboys (Local)
# Jaime Antonio García Morales       Dallas - Cowboys (Local)
# Neima Dorely Meza Jáquez           Dallas - Cowboys (Local)
# Ilse Lozano Rodríguez              Dallas - Cowboys (Local)
# Alejandro Barragán Huerta          Dallas - Cowboys (Local)
# Santos Vazquez Garza               Dallas - Cowboys (Local)
# Luis Alberto López Mónge           Dallas - Cowboys (Local)
# Jerónimo Reyes Ibarra              Dallas - Cowboys (Local)
# Jaime Jesús Irigoyen Hernández     Dallas - Cowboys (Local)
# Cynthia Jaqueline Peralta Sosa     Dallas - Cowboys (Local)
# Magaly Teresa Ochoa Lugo           Dallas - Cowboys (Local)
#
#                                                               16  17
# 0
# Marisela Chacón Molina             Pittsburgh - Steelers (Local)  49
# Maribel Baeza Adame                Pittsburgh - Steelers (Local)  44
# Alberto Vargas Ortiz               Pittsburgh - Steelers (Local)  42
# Manuel Alejandro Escobar Aguilera               Miami - Dolphins  49
# Andrea Bustamante Yapur            Pittsburgh - Steelers (Local)  43
# Ana Alejandra Donati Lugo          Pittsburgh - Steelers (Local)  32
# Guiorguio Guitto Sánchez Muñoz     Pittsburgh - Steelers (Local)  45
# Ezequiel Chávez Gutierrez          Pittsburgh - Steelers (Local)  41
# Gerardo Abraham Ayala Siqueiros    Pittsburgh - Steelers (Local)  35
# José Carlos Salgado Gómez          Pittsburgh - Steelers (Local)  42
# Luis Mendoza Armendáriz            Pittsburgh - Steelers (Local)  42
# Judith Fernández Franco            Pittsburgh - Steelers (Local)  51
# Arelí Olivas Alcántar              Pittsburgh - Steelers (Local)  47
# Kenia Estefanía Cruz García        Pittsburgh - Steelers (Local)  46
# Raúl Humberto García Robledo       Pittsburgh - Steelers (Local)  41
# Erick Benavides Correa             Pittsburgh - Steelers (Local)  48
# José Roberto González Hernández    Pittsburgh - Steelers (Local)  44
# Derek Manuel Calderón Rubio        Pittsburgh - Steelers (Local)  42
# Jaime Antonio García Morales                    Miami - Dolphins  48
# Neima Dorely Meza Jáquez           Pittsburgh - Steelers (Local)  41
# Ilse Lozano Rodríguez              Pittsburgh - Steelers (Local)  42
# Alejandro Barragán Huerta          Pittsburgh - Steelers (Local)  43
# Santos Vazquez Garza               Pittsburgh - Steelers (Local)  42
# Luis Alberto López Mónge           Pittsburgh - Steelers (Local)  42
# Jerónimo Reyes Ibarra              Pittsburgh - Steelers (Local)  46
# Jaime Jesús Irigoyen Hernández     Pittsburgh - Steelers (Local)  40
# Cynthia Jaqueline Peralta Sosa     Pittsburgh - Steelers (Local)  40
# Magaly Teresa Ochoa Lugo           Pittsburgh - Steelers (Local)  44

# %%
faltaron_df = pd.DataFrame(faltaron, columns=['Participante']).reset_index(drop=True)
faltaron_df.index = range(1, len(faltaron_df) + 1)
faltaron_html = faltaron_df
faltaron_df
# Out:
#                 Participante
# 1  José Eduardo López Acosta

# %%
from premailer import transform
# ------------------------------
# TABLA Quiniela inicial
# ------------------------------


# Aplica gradiente + estilos de tabla
quiniela_df_estilizada = (
    quiniela_df.style
    .background_gradient(
        cmap='RdYlGn',  # gradiente
        axis=0
    )
    .set_table_styles(
        [
            {"selector": "th", 
             "props": [
                 ("background-color", "#2E86C1"),
                 ("color", "white"),
                 ("text-align", "center"),
                 ("font-weight", "bold"),
                 ("padding", "8px"),
                 ("border-top", "2px solid #1B4F72")  # línea superior en encabezados
             ]},
            {"selector": "td", 
             "props": [
                 ("text-align", "center"),
                 ("padding", "6px"), 
                 ("border-top", "1px solid #ABB2B9")  # línea superior en celdas
             ]},
            {"selector": "table",
             "props": [
                 ("border-collapse", "collapse"),
                 ("margin", "0 auto"),
                 ("font-family", "Arial, sans-serif"),
                 ("font-size", "14px")
             ]}
        ]
    )
)

# ------------------------------
# TABLA Faltantes
# ------------------------------
faltantes_estilizado = (
    faltaron_df.style
    .set_table_styles(
        [
            {"selector": "th", 
             "props": [
                 ("background-color", "#2E86C1"),
                 ("color", "white"),
                 ("text-align", "center"),
                 ("font-weight", "bold"),
                 ("padding", "8px"),
                 ("border-top", "2px solid #1B4F72")  # línea superior en encabezados
             ]},
            {"selector": "td", 
             "props": [
                 ("text-align", "center"),
                 ("padding", "6px"),
                    
             ]},
            {"selector": "table",
             "props": [
                 ("border-collapse", "collapse"),
                 ("margin", "0 auto"),
                 ("font-family", "Arial, sans-serif"),
                 ("font-size", "14px")
             ]}
        ]
    )
)


quiniela_df_estilizada_html = quiniela_df_estilizada.to_html()
quiniela_df_estilizada_html_inlined = transform(quiniela_df_estilizada_html, remove_classes=True, strip_important=False)

faltaron_html_estilizado = faltantes_estilizado.to_html()
faltantes_estilizado_html_inlined = transform(faltaron_html_estilizado, remove_classes=True, strip_important=False)

import smtplib
from email.mime.multipart import MIMEMultipart
from email.mime.text import MIMEText
from email.mime.base import MIMEBase
from email.mime.application import MIMEApplication
from email import encoders
import pandas as pd

# Configuración del servidor y credenciales
smtp_server = 'smtp.office365.com'
smtp_port = 587
username = 'gaas@citlali.mx'
password = 'Nashir@1103'


asunto = f"🏈✨📣Quiniela de la semana {numero}📣✨🏈"
nombre_archivo = f"quiniela de la semana {numero}"

# Crear el mensaje
msg = MIMEMultipart()
msg['From'] = username
msg['To'] = username
msg['Subject'] = asunto
# Crear el cuerpo del mensaje con la tabla embebida
# Cuerpo del correo con la tabla en línea
body = f"""
<html>
<head><meta charset="UTF-8"></head>
<body style="font-family: Arial, sans-serif; color: #333;">
<p style="color: #2E86C1;"><strong>👋 ¡¡Hola buen día a todos!!</strong></p>

<p><strong style="color: #117A65;">Les comparto como quedo la {nombre_archivo}:</strong> 🏈</p>

<h3 style="color:#2E86C1;">📊 </h3>
{quiniela_df_estilizada_html_inlined}

<p style="color: #117A65;"><strong>😠 Los que no llenaron la quiniela son:⚠️</strong></p>
{faltantes_estilizado_html_inlined}

<p style="color: #28B463;"><strong>¡¡¡Muchas suerte para todos!!!🍀</strong></p>

<p style="color: #566573;">Salu✌️<br></p>
</body>
</html>
"""

msg.attach(MIMEText(body, 'html', 'utf-8'))

# Adjuntar el archivo Excel
with open(nombre_quiniela_semanal, 'rb') as file:
    excel_attachment = MIMEApplication(file.read(), _subtype='xlsx')
    excel_attachment.add_header(
        'Content-Disposition',
        'attachment',
        filename=nombre_quiniela_semanal
    )
    msg.attach(excel_attachment)



filename = nombre_archivo


#part = MIMEBase('application', 'octet-stream')

#part.add_header('Content-Disposition', f"attachment; filename= {filename}")



# Enviar el correo
try:
    server = smtplib.SMTP(smtp_server, smtp_port)
    server.starttls()
    server.login(username, password)
    text = msg.as_string()
    server.sendmail(username, [username], text)
    server.quit()
    print("Correo enviado exitosamente")
except Exception as e:
    print(f"Error al enviar el correo: {e}")
# Out:
# Correo enviado exitosamente
