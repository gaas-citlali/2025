# %% [markdown]
# !pip install pandas
# !pip install numpy
# !pip install matplotlib
# !pip install Jinja2
# !pip install openpyxl

# %% [markdown]
# !pip install gspread oauth2client

# %%
numero = 13

inscritos_quiniela = [ 
    'Gerardo Abraham Ayala Siqueiros',
    'Marisela Chacón Molina',
    'Arelí Olivas Alcántar',
    'Maribel Baeza Adame',
    'Santos Vazquez Garza',
    'Manuel Alejandro Escobar Aguilera',
    'José Carlos Salgado Gómez',
    'Alberto Vargas Ortiz',
    'Raúl Humberto García Robledo',
    'Alejandro Barragán Huerta',
    'Kenia Estefanía Cruz García',
    'Jaime Antonio García Morales',
    'Jerónimo Reyes Ibarra',
    'Guiorguio Guitto Sánchez Muñoz',
    'Neima Dorely Meza Jáquez',
    'Ezequiel Chávez Gutierrez',
    'Jaime Jesús Irigoyen Hernández',
    'Judith Fernández Franco',
    'Magaly Teresa Ochoa Lugo',
    'Ana Alejandra Donati Lugo',
    'Andrea Bustamante Yapur',
    "José Roberto González Hernández",
    "Ilse Lozano Rodríguez",
    'Erick Benavides Correa',
    'Cynthia Jaqueline Peralta Sosa',
    'Luis Mendoza Armendáriz',
    'José Eduardo López Acosta',
    'Derek Manuel Calderón Rubio', 
    'Luis Alberto López Mónge'   
    ]

inscritos_acumulado = [ 
    'Gerardo Abraham Ayala Siqueiros',
    'Arelí Olivas Alcántar',
    'Maribel Baeza Adame',
    'Santos Vazquez Garza',
    'Manuel Alejandro Escobar Aguilera',
    'José Carlos Salgado Gómez',
    'Alberto Vargas Ortiz',
    'Raúl Humberto García Robledo',
    'Alejandro Barragán Huerta',
    'Kenia Estefanía Cruz García',
    'Jerónimo Reyes Ibarra',
    'Guiorguio Guitto Sánchez Muñoz',
    'Ezequiel Chávez Gutierrez',
    'Jaime Jesús Irigoyen Hernández',
    'Judith Fernández Franco',
    'Ana Alejandra Donati Lugo',
    'Andrea Bustamante Yapur',
    "Ilse Lozano Rodríguez",
    'Luis Mendoza Armendáriz',
    'José Eduardo López Acosta',
    'Luis Alberto López Mónge'
    
    ]

bajas = []

diccionario_correos ={
    'mcm@citlali.mx':'Marisela Chacón Molina',
    'ggsm@citlali.mx':'Guiorguio Guitto Sánchez Muñoz',
    'avo@citlali.mx':'Alberto Vargas Ortiz',
    'jff@citlali.mx':'Judith Fernández Franco',
    'aby@citlali.mx':'Andrea Bustamante Yapur',
    'mba@citlali.mx':'Maribel Baeza Adame',
    'meg@citlali.mx':'Manuel Alejandro Escobar Aguilera',
    'gaas@citlali.mx':'Gerardo Abraham Ayala Siqueiros',
    'aoa@citlali.mx':'Arelí Olivas Alcántar',
    'jela@citlali.mx':'José Eduardo López Acosta',
    'rhgr@citlali.mx':'Raúl Humberto García Robledo',
    'kecg@citlali.mx':'Kenia Estefanía Cruz García',
    'jcsg@citlali.mx':'José Carlos Salgado Gómez',
    'ndmj@citlali.mx':'Neima Dorely Meza Jáquez',
    'jjih@citlali.mx':'Jaime Jesús Irigoyen Hernández',
    'lalm@citlali.mx':'Luis Alberto López Mónge',
    'jrgh@citlali.mx':'José Roberto González Hernández',
    'mtol@citlali.mx':'Magaly Teresa Ochoa Lugo',
    'svg@citlali.mx':'Santos Vazquez Garza',
    'jri@citlali.mx':'Jerónimo Reyes Ibarra',
    'ilr@citlali.mx':'Ilse Lozano Rodríguez',
    'abh@citlali.mx':'Alejandro Barragán Huerta',
    'dmcr@citlali.mx':'Derek Manuel Calderón Rubio',
    'lma@citlali.mx':'Luis Mendoza Armendáriz',
    'jagm@citlali.mx':'Jaime Antonio García Morales',
    'ecg@citlali.mx':'Ezequiel Chávez Gutierrez',
    'aadl@citlali.mx':'Ana Alejandra Donati Lugo',
    'ebc@citlali.mx':'Erick Benavides Correa',
    'cjps@citlali.mx':'Cynthia Jaqueline Peralta Sosa'

}


conteo = 0
total_quiniela = len(inscritos_quiniela)
total_acumulado = len(inscritos_acumulado)

print(f'En total, por toda la tempora se invertiran {50 *18}\n')
print(f'Se han inscrito a la quiniela {total_quiniela} personas.\nPor semana el ganador se llevará {total_quiniela * 50}. \nLos inscritos son:\n')
for i in inscritos_quiniela:
    conteo += 1
    print(f'{conteo}. {i}')
conteo = 0    

print(f'\nAl acumulado se han inscrito {total_acumulado} personas. \nLa bolsa acumulada es de {total_acumulado * 250}. \nLos inscritos son:\n')
for i in inscritos_acumulado:
    conteo += 1
    print(f'{conteo}. {i}')
conteo = 0

print('\nLos que se anotaron en quiniela, pero no en el acumulado son:\n')
for i in inscritos_quiniela:
    if i not in inscritos_acumulado:
        conteo += 1
        print(f'{conteo}. {i}')
# Out:
# En total, por toda la tempora se invertiran 900
#
# Se han inscrito a la quiniela 29 personas.
# Por semana el ganador se llevará 1450.
# Los inscritos son:
#
# 1. Gerardo Abraham Ayala Siqueiros
# 2. Marisela Chacón Molina
# 3. Arelí Olivas Alcántar
# 4. Maribel Baeza Adame
# 5. Santos Vazquez Garza
# 6. Manuel Alejandro Escobar Aguilera
# 7. José Carlos Salgado Gómez
# 8. Alberto Vargas Ortiz
# 9. Raúl Humberto García Robledo
# 10. Alejandro Barragán Huerta
# 11. Kenia Estefanía Cruz García
# 12. Jaime Antonio García Morales
# 13. Jerónimo Reyes Ibarra
# 14. Guiorguio Guitto Sánchez Muñoz
# 15. Neima Dorely Meza Jáquez
# 16. Ezequiel Chávez Gutierrez
# 17. Jaime Jesús Irigoyen Hernández
# 18. Judith Fernández Franco
# 19. Magaly Teresa Ochoa Lugo
# 20. Ana Alejandra Donati Lugo
# 21. Andrea Bustamante Yapur
# 22. José Roberto González Hernández
# 23. Ilse Lozano Rodríguez
# 24. Erick Benavides Correa
# 25. Cynthia Jaqueline Peralta Sosa
# 26. Luis Mendoza Armendáriz
# 27. José Eduardo López Acosta
# 28. Derek Manuel Calderón Rubio
# 29. Luis Alberto López Mónge
#
# Al acumulado se han inscrito 21 personas.
# La bolsa acumulada es de 5250.
# Los inscritos son:
#
# 1. Gerardo Abraham Ayala Siqueiros
# 2. Arelí Olivas Alcántar
# 3. Maribel Baeza Adame
# 4. Santos Vazquez Garza
# 5. Manuel Alejandro Escobar Aguilera
# 6. José Carlos Salgado Gómez
# 7. Alberto Vargas Ortiz
# 8. Raúl Humberto García Robledo
# 9. Alejandro Barragán Huerta
# 10. Kenia Estefanía Cruz García
# 11. Jerónimo Reyes Ibarra
# 12. Guiorguio Guitto Sánchez Muñoz
# 13. Ezequiel Chávez Gutierrez
# 14. Jaime Jesús Irigoyen Hernández
# 15. Judith Fernández Franco
# 16. Ana Alejandra Donati Lugo
# 17. Andrea Bustamante Yapur
# 18. Ilse Lozano Rodríguez
# 19. Luis Mendoza Armendáriz
# 20. José Eduardo López Acosta
# 21. Luis Alberto López Mónge
#
# Los que se anotaron en quiniela, pero no en el acumulado son:
#
# 1. Marisela Chacón Molina
# 2. Jaime Antonio García Morales
# 3. Neima Dorely Meza Jáquez
# 4. Magaly Teresa Ochoa Lugo
# 5. José Roberto González Hernández
# 6. Erick Benavides Correa
# 7. Cynthia Jaqueline Peralta Sosa
# 8. Derek Manuel Calderón Rubio

# %%
import pandas as pd
import os
import warnings


archivo = f'Semana {numero} NFL 2025.xlsx'

fecha_inicio = pd.to_datetime('2025-09-01')

warnings.filterwarnings("ignore")
respuestas = pd.read_excel(archivo)

respuestas['fecha'] = respuestas['Completion time'].dt.date
respuestas['semana'] = (respuestas['Completion time'] - fecha_inicio).dt.days // 7 + 1

columnas = ['semana', 'fecha']
columnas_viejas = [col for col in respuestas.columns if col not in columnas]

respuestas = respuestas[columnas + columnas_viejas]
respuestas = respuestas.rename(columns={'Name':'Participante'})
respuestas['Participante'] = respuestas['Email'].map(diccionario_correos)

correos = respuestas['Email'].unique()

# %%
quiniela_semana_actual = respuestas[respuestas['semana'] == numero]
quiniela_semana_actual = quiniela_semana_actual.drop(columns=['Start time', 
                                                              'Language',
                                                              'Completion time', 
                                                              'Email', 
                                                              'semana', 
                                                              'fecha',
                                                              'Id'])
faltaron = []
for i in inscritos_quiniela:
    if i not in quiniela_semana_actual['Participante'].values:
        faltaron.append(i)


nombre_quiniela_semanal = f'Quiniela Semana {numero} NFL 2025.xlsx'
excel_quiniela_semanal = quiniela_semana_actual.to_excel(nombre_quiniela_semanal, 
                                                         index=False,
                                                         sheet_name=f'{numero}',
                                                         header=None)
quiniela_semana_actual.columns = [quiniela_semana_actual.columns[0]] + list(range(1, 
                                                                                  len(quiniela_semana_actual.columns)))

quiniela_semana_actual.columns = list(quiniela_semana_actual.columns[:-1]) + ['Desempate']
quiniela_semana_actual
# Out:
#                          Participante                        1  \
# 0             Judith Fernández Franco      Green Bay - Packers
# 1      Guiorguio Guitto Sánchez Muñoz  Detroit - Lions (Local)
# 2            Neima Dorely Meza Jáquez      Green Bay - Packers
# 3         Kenia Estefanía Cruz García      Green Bay - Packers
# 4        Jaime Antonio García Morales  Detroit - Lions (Local)
# 5               Arelí Olivas Alcántar  Detroit - Lions (Local)
# 6                Alberto Vargas Ortiz  Detroit - Lions (Local)
# 7                Santos Vazquez Garza      Green Bay - Packers
# 8     José Roberto González Hernández  Detroit - Lions (Local)
# 9             Andrea Bustamante Yapur  Detroit - Lions (Local)
# 10    Gerardo Abraham Ayala Siqueiros      Green Bay - Packers
# 11       Raúl Humberto García Robledo  Detroit - Lions (Local)
# 12                Maribel Baeza Adame  Detroit - Lions (Local)
# 13          Alejandro Barragán Huerta  Detroit - Lions (Local)
# 14            Luis Mendoza Armendáriz  Detroit - Lions (Local)
# 15           Magaly Teresa Ochoa Lugo  Detroit - Lions (Local)
# 16             Marisela Chacón Molina      Green Bay - Packers
# 17  Manuel Alejandro Escobar Aguilera  Detroit - Lions (Local)
# 18     Jaime Jesús Irigoyen Hernández  Detroit - Lions (Local)
# 19          Ana Alejandra Donati Lugo  Detroit - Lions (Local)
# 20          José Carlos Salgado Gómez  Detroit - Lions (Local)
# 21           Luis Alberto López Mónge      Green Bay - Packers
# 22             Erick Benavides Correa      Green Bay - Packers
# 23     Cynthia Jaqueline Peralta Sosa  Detroit - Lions (Local)
# 24              Ilse Lozano Rodríguez  Detroit - Lions (Local)
# 25          Ezequiel Chávez Gutierrez  Detroit - Lions (Local)
# 26        Derek Manuel Calderón Rubio  Detroit - Lions (Local)
# 27          José Eduardo López Acosta  Detroit - Lions (Local)
# 28              Jerónimo Reyes Ibarra  Detroit - Lions (Local)
#
#                            2                           3  \
# 0       Kansas City - Chiefs  Baltimore - Ravens (Local)
# 1   Dallas - Cowboys (Local)        Cincinnati - Bengals
# 2       Kansas City - Chiefs  Baltimore - Ravens (Local)
# 3   Dallas - Cowboys (Local)  Baltimore - Ravens (Local)
# 4   Dallas - Cowboys (Local)  Baltimore - Ravens (Local)
# 5       Kansas City - Chiefs  Baltimore - Ravens (Local)
# 6       Kansas City - Chiefs  Baltimore - Ravens (Local)
# 7       Kansas City - Chiefs        Cincinnati - Bengals
# 8       Kansas City - Chiefs  Baltimore - Ravens (Local)
# 9       Kansas City - Chiefs  Baltimore - Ravens (Local)
# 10      Kansas City - Chiefs  Baltimore - Ravens (Local)
# 11      Kansas City - Chiefs  Baltimore - Ravens (Local)
# 12      Kansas City - Chiefs  Baltimore - Ravens (Local)
# 13      Kansas City - Chiefs  Baltimore - Ravens (Local)
# 14  Dallas - Cowboys (Local)  Baltimore - Ravens (Local)
# 15      Kansas City - Chiefs  Baltimore - Ravens (Local)
# 16  Dallas - Cowboys (Local)  Baltimore - Ravens (Local)
# 17  Dallas - Cowboys (Local)  Baltimore - Ravens (Local)
# 18      Kansas City - Chiefs  Baltimore - Ravens (Local)
# 19  Dallas - Cowboys (Local)  Baltimore - Ravens (Local)
# 20      Kansas City - Chiefs  Baltimore - Ravens (Local)
# 21  Dallas - Cowboys (Local)  Baltimore - Ravens (Local)
# 22  Dallas - Cowboys (Local)  Baltimore - Ravens (Local)
# 23      Kansas City - Chiefs  Baltimore - Ravens (Local)
# 24      Kansas City - Chiefs  Baltimore - Ravens (Local)
# 25      Kansas City - Chiefs  Baltimore - Ravens (Local)
# 26  Dallas - Cowboys (Local)  Baltimore - Ravens (Local)
# 27      Kansas City - Chiefs  Baltimore - Ravens (Local)
# 19  Tennessee - Titans (Local)  Indianapolis - Colts (Local)
# 20      Jacksonville - Jaguars  Indianapolis - Colts (Local)
# 21      Jacksonville - Jaguars  Indianapolis - Colts (Local)
# 22  Tennessee - Titans (Local)  Indianapolis - Colts (Local)
# 23      Jacksonville - Jaguars  Indianapolis - Colts (Local)
# 24      Jacksonville - Jaguars  Indianapolis - Colts (Local)
# 25      Jacksonville - Jaguars  Indianapolis - Colts (Local)
# 26      Jacksonville - Jaguars  Indianapolis - Colts (Local)
# 27      Jacksonville - Jaguars  Indianapolis - Colts (Local)
# 28      Jacksonville - Jaguars  Indianapolis - Colts (Local)
#
#                            8                        9  \
# 0   Miami - Dolphins (Local)        Atlanta - Falcons
# 1   Miami - Dolphins (Local)  New York - Jets (Local)
# 2   Miami - Dolphins (Local)  New York - Jets (Local)
# 3   Miami - Dolphins (Local)        Atlanta - Falcons
# 4   Miami - Dolphins (Local)        Atlanta - Falcons
# 5   Miami - Dolphins (Local)        Atlanta - Falcons
# 6   Miami - Dolphins (Local)        Atlanta - Falcons
# 7   Miami - Dolphins (Local)        Atlanta - Falcons
# 8   Miami - Dolphins (Local)        Atlanta - Falcons
# 9   Miami - Dolphins (Local)        Atlanta - Falcons
# 10  Miami - Dolphins (Local)        Atlanta - Falcons
# 11  Miami - Dolphins (Local)        Atlanta - Falcons
# 12  Miami - Dolphins (Local)        Atlanta - Falcons
# 13  Miami - Dolphins (Local)  New York - Jets (Local)
# 14  Miami - Dolphins (Local)        Atlanta - Falcons
# 15  Miami - Dolphins (Local)        Atlanta - Falcons
# 16  Miami - Dolphins (Local)        Atlanta - Falcons
# 17  Miami - Dolphins (Local)        Atlanta - Falcons
# 18  Miami - Dolphins (Local)        Atlanta - Falcons
# 19  Miami - Dolphins (Local)  New York - Jets (Local)
# 20  Miami - Dolphins (Local)        Atlanta - Falcons
# 21  Miami - Dolphins (Local)        Atlanta - Falcons
# 22  Miami - Dolphins (Local)  New York - Jets (Local)
# 23  Miami - Dolphins (Local)        Atlanta - Falcons
# 24  Miami - Dolphins (Local)        Atlanta - Falcons
# 25  Miami - Dolphins (Local)        Atlanta - Falcons
# 26  Miami - Dolphins (Local)        Atlanta - Falcons
# 27  Miami - Dolphins (Local)        Atlanta - Falcons
# 28  Miami - Dolphins (Local)  New York - Jets (Local)
#
#                                 10                           11  \
# 0   Tampa Bay - Buccaneers (Local)           Los Angeles - Rams
# 1   Tampa Bay - Buccaneers (Local)           Los Angeles - Rams
# 2   Tampa Bay - Buccaneers (Local)  Carolina - Panthers (Local)
# 3   Tampa Bay - Buccaneers (Local)           Los Angeles - Rams
# 4   Tampa Bay - Buccaneers (Local)           Los Angeles - Rams
# 5   Tampa Bay - Buccaneers (Local)           Los Angeles - Rams
# 6   Tampa Bay - Buccaneers (Local)           Los Angeles - Rams
# 7   Tampa Bay - Buccaneers (Local)           Los Angeles - Rams
# 8   Tampa Bay - Buccaneers (Local)           Los Angeles - Rams
# 9   Tampa Bay - Buccaneers (Local)           Los Angeles - Rams
# 10  Tampa Bay - Buccaneers (Local)           Los Angeles - Rams
# 11  Tampa Bay - Buccaneers (Local)           Los Angeles - Rams
# 12  Tampa Bay - Buccaneers (Local)           Los Angeles - Rams
# 13  Tampa Bay - Buccaneers (Local)           Los Angeles - Rams
# 14  Tampa Bay - Buccaneers (Local)           Los Angeles - Rams
# 15  Tampa Bay - Buccaneers (Local)           Los Angeles - Rams
# 16             Arizona - Cardinals           Los Angeles - Rams
# 17  Tampa Bay - Buccaneers (Local)           Los Angeles - Rams
# 18  Tampa Bay - Buccaneers (Local)           Los Angeles - Rams
# 19             Arizona - Cardinals           Los Angeles - Rams
# 20  Tampa Bay - Buccaneers (Local)           Los Angeles - Rams
# 21  Tampa Bay - Buccaneers (Local)           Los Angeles - Rams
# 22  Tampa Bay - Buccaneers (Local)           Los Angeles - Rams
# 23  Tampa Bay - Buccaneers (Local)           Los Angeles - Rams
# 24  Tampa Bay - Buccaneers (Local)           Los Angeles - Rams
# 25  Tampa Bay - Buccaneers (Local)           Los Angeles - Rams
# 26  Tampa Bay - Buccaneers (Local)           Los Angeles - Rams
# 27  Tampa Bay - Buccaneers (Local)           Los Angeles - Rams
# 28             Arizona - Cardinals           Los Angeles - Rams
#
#                             12                             13  \
# 0   Seattle - Seahawks (Local)                Buffalo - Bills
# 1   Seattle - Seahawks (Local)  Pittsburgh - Steelers (Local)
# 2   Seattle - Seahawks (Local)                Buffalo - Bills
# 3          Minnesota - Vikings  Pittsburgh - Steelers (Local)
# 4   Seattle - Seahawks (Local)                Buffalo - Bills
# 5   Seattle - Seahawks (Local)                Buffalo - Bills
# 6   Seattle - Seahawks (Local)                Buffalo - Bills
# 7   Seattle - Seahawks (Local)                Buffalo - Bills
# 8   Seattle - Seahawks (Local)                Buffalo - Bills
# 9   Seattle - Seahawks (Local)                Buffalo - Bills
# 10  Seattle - Seahawks (Local)                Buffalo - Bills
# 11  Seattle - Seahawks (Local)                Buffalo - Bills
# 12  Seattle - Seahawks (Local)                Buffalo - Bills
# 13  Seattle - Seahawks (Local)                Buffalo - Bills
# 14  Seattle - Seahawks (Local)                Buffalo - Bills
# 15  Seattle - Seahawks (Local)                Buffalo - Bills
# 16  Seattle - Seahawks (Local)  Pittsburgh - Steelers (Local)
# 17  Seattle - Seahawks (Local)                Buffalo - Bills
# 18  Seattle - Seahawks (Local)                Buffalo - Bills
# 19  Seattle - Seahawks (Local)                Buffalo - Bills
# 20  Seattle - Seahawks (Local)                Buffalo - Bills
# 21  Seattle - Seahawks (Local)  Pittsburgh - Steelers (Local)
# 22  Seattle - Seahawks (Local)  Pittsburgh - Steelers (Local)
# 23  Seattle - Seahawks (Local)                Buffalo - Bills
# 24  Seattle - Seahawks (Local)                Buffalo - Bills
# 25  Seattle - Seahawks (Local)                Buffalo - Bills
# 26  Seattle - Seahawks (Local)  Pittsburgh - Steelers (Local)
# 27  Seattle - Seahawks (Local)                Buffalo - Bills
# 28  Seattle - Seahawks (Local)                Buffalo - Bills
#
#                                 14                               15  \
# 0   Los Angeles - Chargers (Local)                 Denver - Broncos
# 1   Los Angeles - Chargers (Local)                 Denver - Broncos
# 2   Los Angeles - Chargers (Local)                 Denver - Broncos
# 3   Los Angeles - Chargers (Local)                 Denver - Broncos
# 4   Los Angeles - Chargers (Local)                 Denver - Broncos
# 5   Los Angeles - Chargers (Local)                 Denver - Broncos
# 6   Los Angeles - Chargers (Local)                 Denver - Broncos
# 7   Los Angeles - Chargers (Local)                 Denver - Broncos
# 8   Los Angeles - Chargers (Local)                 Denver - Broncos
# 9   Los Angeles - Chargers (Local)                 Denver - Broncos
# 10  Los Angeles - Chargers (Local)                 Denver - Broncos
# 11  Los Angeles - Chargers (Local)                 Denver - Broncos
# 12  Los Angeles - Chargers (Local)                 Denver - Broncos
# 13  Los Angeles - Chargers (Local)                 Denver - Broncos
# 14  Los Angeles - Chargers (Local)                 Denver - Broncos
# 15  Los Angeles - Chargers (Local)                 Denver - Broncos
# 16  Los Angeles - Chargers (Local)  Washington - Commanders (Local)
# 17  Los Angeles - Chargers (Local)                 Denver - Broncos
# 18  Los Angeles - Chargers (Local)                 Denver - Broncos
# 19  Los Angeles - Chargers (Local)                 Denver - Broncos
# 20  Los Angeles - Chargers (Local)                 Denver - Broncos
# 21  Los Angeles - Chargers (Local)                 Denver - Broncos
# 22  Los Angeles - Chargers (Local)                 Denver - Broncos
# 23  Los Angeles - Chargers (Local)                 Denver - Broncos
# 24  Los Angeles - Chargers (Local)                 Denver - Broncos
# 25  Los Angeles - Chargers (Local)                 Denver - Broncos
# 26  Los Angeles - Chargers (Local)                 Denver - Broncos
# 27  Los Angeles - Chargers (Local)                 Denver - Broncos
# 28  Los Angeles - Chargers (Local)                 Denver - Broncos
#
#                                 16  Desempate
# 0   New England - Patriots (Local)         52
# 1   New England - Patriots (Local)         52
# 2   New England - Patriots (Local)         41
# 3   New England - Patriots (Local)         49
# 4   New England - Patriots (Local)         35
# 5   New England - Patriots (Local)         53
# 6   New England - Patriots (Local)         47
# 7   New England - Patriots (Local)         45
# 8   New England - Patriots (Local)         42
# 9   New England - Patriots (Local)         43
# 10  New England - Patriots (Local)         36
# 11  New England - Patriots (Local)         46
# 12  New England - Patriots (Local)         40
# 13  New England - Patriots (Local)         39
# 14  New England - Patriots (Local)         43
# 15  New England - Patriots (Local)         48
# 16  New England - Patriots (Local)         49
# 17  New England - Patriots (Local)         39
# 18  New England - Patriots (Local)         40
# 19  New England - Patriots (Local)         48
# 20  New England - Patriots (Local)         45
# 21  New England - Patriots (Local)         47
# 22  New England - Patriots (Local)         46
# 23               New York - Giants         58
# 24  New England - Patriots (Local)         44
# 25  New England - Patriots (Local)         45
# 26  New England - Patriots (Local)         41
# 27  New England - Patriots (Local)         49
# 28               New York - Giants         46

# %%
import pandas as pd
from openpyxl import load_workbook

archivo_existente = 'NFL Quinela 2025.xlsx'
nombre_hoja = f'{numero}'

# Cargar el libro
book = load_workbook(archivo_existente)

# Eliminar la hoja si ya existe
if nombre_hoja in book.sheetnames:
    std = book[nombre_hoja]
    book.remove(std)
    book.save(archivo_existente)

# Escribir la nueva hoja
with pd.ExcelWriter(archivo_existente, engine='openpyxl', mode='a') as writer:
    quiniela_semana_actual.to_excel(writer, index=False, sheet_name=nombre_hoja,header=None)

quinela = pd.read_excel(archivo_existente, 
                        sheet_name = None, 
                        header = None, 
                        index_col=0)


quinela = {sheet: df[~df.index.isin(bajas)] for sheet, 
           df in quinela.items()}

semanas = [int(semana) for semana in quinela.keys()]
semana_numero = numero #int(max(semanas))
semana = str(semana_numero)


quinela_semanal = quinela[semana]

quinela_semanal.index.name = 'Participante'
quiniela_df = pd.DataFrame(quinela_semanal)
quiniela_df
# Out:
#                                                         1   \
# Participante
# Judith Fernández Franco                Green Bay - Packers
# Guiorguio Guitto Sánchez Muñoz     Detroit - Lions (Local)
# Neima Dorely Meza Jáquez               Green Bay - Packers
# Kenia Estefanía Cruz García            Green Bay - Packers
# Jaime Antonio García Morales       Detroit - Lions (Local)
# Arelí Olivas Alcántar              Detroit - Lions (Local)
# Alberto Vargas Ortiz               Detroit - Lions (Local)
# Santos Vazquez Garza                   Green Bay - Packers
# José Roberto González Hernández    Detroit - Lions (Local)
# Andrea Bustamante Yapur            Detroit - Lions (Local)
# Gerardo Abraham Ayala Siqueiros        Green Bay - Packers
# Raúl Humberto García Robledo       Detroit - Lions (Local)
# Maribel Baeza Adame                Detroit - Lions (Local)
# Alejandro Barragán Huerta          Detroit - Lions (Local)
# Luis Mendoza Armendáriz            Detroit - Lions (Local)
# Magaly Teresa Ochoa Lugo           Detroit - Lions (Local)
# Marisela Chacón Molina                 Green Bay - Packers
# Manuel Alejandro Escobar Aguilera  Detroit - Lions (Local)
# Jaime Jesús Irigoyen Hernández     Detroit - Lions (Local)
# Ana Alejandra Donati Lugo          Detroit - Lions (Local)
# José Carlos Salgado Gómez          Detroit - Lions (Local)
# Luis Alberto López Mónge               Green Bay - Packers
# Erick Benavides Correa                 Green Bay - Packers
# Cynthia Jaqueline Peralta Sosa     Detroit - Lions (Local)
# Ilse Lozano Rodríguez              Detroit - Lions (Local)
# Ezequiel Chávez Gutierrez          Detroit - Lions (Local)
# Derek Manuel Calderón Rubio        Detroit - Lions (Local)
# José Eduardo López Acosta          Detroit - Lions (Local)
# Jerónimo Reyes Ibarra              Detroit - Lions (Local)
#
#                                                          2   \
# Participante
# Judith Fernández Franco                Kansas City - Chiefs
# Guiorguio Guitto Sánchez Muñoz     Dallas - Cowboys (Local)
# Neima Dorely Meza Jáquez               Kansas City - Chiefs
# Kenia Estefanía Cruz García        Dallas - Cowboys (Local)
# Jaime Antonio García Morales       Dallas - Cowboys (Local)
# Arelí Olivas Alcántar                  Kansas City - Chiefs
# Alberto Vargas Ortiz                   Kansas City - Chiefs
# Santos Vazquez Garza                   Kansas City - Chiefs
# José Roberto González Hernández        Kansas City - Chiefs
# Andrea Bustamante Yapur                Kansas City - Chiefs
# Gerardo Abraham Ayala Siqueiros        Kansas City - Chiefs
# Raúl Humberto García Robledo           Kansas City - Chiefs
# Maribel Baeza Adame                    Kansas City - Chiefs
# Alejandro Barragán Huerta              Kansas City - Chiefs
# Luis Mendoza Armendáriz            Dallas - Cowboys (Local)
# Magaly Teresa Ochoa Lugo               Kansas City - Chiefs
# Marisela Chacón Molina             Dallas - Cowboys (Local)
# Manuel Alejandro Escobar Aguilera  Dallas - Cowboys (Local)
# Jaime Jesús Irigoyen Hernández         Kansas City - Chiefs
# Ana Alejandra Donati Lugo          Dallas - Cowboys (Local)
# José Carlos Salgado Gómez              Kansas City - Chiefs
# Luis Alberto López Mónge           Dallas - Cowboys (Local)
# Erick Benavides Correa             Dallas - Cowboys (Local)
# Cynthia Jaqueline Peralta Sosa         Kansas City - Chiefs
# Ilse Lozano Rodríguez                  Kansas City - Chiefs
# Ezequiel Chávez Gutierrez              Kansas City - Chiefs
# Derek Manuel Calderón Rubio        Dallas - Cowboys (Local)
# José Eduardo López Acosta              Kansas City - Chiefs
# Jerónimo Reyes Ibarra              Dallas - Cowboys (Local)
#
#                                                            3   \
# Participante
# Judith Fernández Franco            Baltimore - Ravens (Local)
# Guiorguio Guitto Sánchez Muñoz           Cincinnati - Bengals
# Neima Dorely Meza Jáquez           Baltimore - Ravens (Local)
# Kenia Estefanía Cruz García        Baltimore - Ravens (Local)
# Jaime Antonio García Morales       Baltimore - Ravens (Local)
# Arelí Olivas Alcántar              Baltimore - Ravens (Local)
# Alberto Vargas Ortiz               Baltimore - Ravens (Local)
# Santos Vazquez Garza                     Cincinnati - Bengals
# José Roberto González Hernández    Baltimore - Ravens (Local)
# Andrea Bustamante Yapur            Baltimore - Ravens (Local)
# Gerardo Abraham Ayala Siqueiros    Baltimore - Ravens (Local)
# Raúl Humberto García Robledo       Baltimore - Ravens (Local)
# Maribel Baeza Adame                Baltimore - Ravens (Local)
# Alejandro Barragán Huerta          Baltimore - Ravens (Local)
# Luis Mendoza Armendáriz            Baltimore - Ravens (Local)
# Magaly Teresa Ochoa Lugo           Baltimore - Ravens (Local)
# Marisela Chacón Molina             Baltimore - Ravens (Local)
# Manuel Alejandro Escobar Aguilera  Baltimore - Ravens (Local)
# Jaime Jesús Irigoyen Hernández     Baltimore - Ravens (Local)
# Ana Alejandra Donati Lugo          Baltimore - Ravens (Local)
# José Carlos Salgado Gómez          Baltimore - Ravens (Local)
# Luis Alberto López Mónge           Baltimore - Ravens (Local)
# Erick Benavides Correa             Baltimore - Ravens (Local)
# Cynthia Jaqueline Peralta Sosa     Baltimore - Ravens (Local)
# Ilse Lozano Rodríguez              Baltimore - Ravens (Local)
# Ezequiel Chávez Gutierrez          Baltimore - Ravens (Local)
# Derek Manuel Calderón Rubio        Baltimore - Ravens (Local)
# José Eduardo López Acosta          Baltimore - Ravens (Local)
# Jerónimo Reyes Ibarra              Baltimore - Ravens (Local)
#
#                                                               4   \
# Participante
# Judith Fernández Franco            Philadelphia - Eagles (Local)
# Guiorguio Guitto Sánchez Muñoz     Philadelphia - Eagles (Local)
# Neima Dorely Meza Jáquez           Philadelphia - Eagles (Local)
# Ana Alejandra Donati Lugo          Indianapolis - Colts (Local)
# José Carlos Salgado Gómez          Indianapolis - Colts (Local)
# Luis Alberto López Mónge           Indianapolis - Colts (Local)
# Erick Benavides Correa             Indianapolis - Colts (Local)
# Cynthia Jaqueline Peralta Sosa     Indianapolis - Colts (Local)
# Ilse Lozano Rodríguez              Indianapolis - Colts (Local)
# Ezequiel Chávez Gutierrez          Indianapolis - Colts (Local)
# Derek Manuel Calderón Rubio        Indianapolis - Colts (Local)
# José Eduardo López Acosta          Indianapolis - Colts (Local)
# Jerónimo Reyes Ibarra              Indianapolis - Colts (Local)
#
#                                                          8   \
# Participante
# Judith Fernández Franco            Miami - Dolphins (Local)
# Guiorguio Guitto Sánchez Muñoz     Miami - Dolphins (Local)
# Neima Dorely Meza Jáquez           Miami - Dolphins (Local)
# Kenia Estefanía Cruz García        Miami - Dolphins (Local)
# Jaime Antonio García Morales       Miami - Dolphins (Local)
# Arelí Olivas Alcántar              Miami - Dolphins (Local)
# Alberto Vargas Ortiz               Miami - Dolphins (Local)
# Santos Vazquez Garza               Miami - Dolphins (Local)
# José Roberto González Hernández    Miami - Dolphins (Local)
# Andrea Bustamante Yapur            Miami - Dolphins (Local)
# Gerardo Abraham Ayala Siqueiros    Miami - Dolphins (Local)
# Raúl Humberto García Robledo       Miami - Dolphins (Local)
# Maribel Baeza Adame                Miami - Dolphins (Local)
# Alejandro Barragán Huerta          Miami - Dolphins (Local)
# Luis Mendoza Armendáriz            Miami - Dolphins (Local)
# Magaly Teresa Ochoa Lugo           Miami - Dolphins (Local)
# Marisela Chacón Molina             Miami - Dolphins (Local)
# Manuel Alejandro Escobar Aguilera  Miami - Dolphins (Local)
# Jaime Jesús Irigoyen Hernández     Miami - Dolphins (Local)
# Ana Alejandra Donati Lugo          Miami - Dolphins (Local)
# José Carlos Salgado Gómez          Miami - Dolphins (Local)
# Luis Alberto López Mónge           Miami - Dolphins (Local)
# Erick Benavides Correa             Miami - Dolphins (Local)
# Cynthia Jaqueline Peralta Sosa     Miami - Dolphins (Local)
# Ilse Lozano Rodríguez              Miami - Dolphins (Local)
# Ezequiel Chávez Gutierrez          Miami - Dolphins (Local)
# Derek Manuel Calderón Rubio        Miami - Dolphins (Local)
# José Eduardo López Acosta          Miami - Dolphins (Local)
# Jerónimo Reyes Ibarra              Miami - Dolphins (Local)
#
#                                                         9   \
# Participante
# Judith Fernández Franco                  Atlanta - Falcons
# Guiorguio Guitto Sánchez Muñoz     New York - Jets (Local)
# Neima Dorely Meza Jáquez           New York - Jets (Local)
# Kenia Estefanía Cruz García              Atlanta - Falcons
# Jaime Antonio García Morales             Atlanta - Falcons
# Arelí Olivas Alcántar                    Atlanta - Falcons
# Alberto Vargas Ortiz                     Atlanta - Falcons
# Santos Vazquez Garza                     Atlanta - Falcons
# José Roberto González Hernández          Atlanta - Falcons
# Andrea Bustamante Yapur                  Atlanta - Falcons
# Gerardo Abraham Ayala Siqueiros          Atlanta - Falcons
# Raúl Humberto García Robledo       New England - Patriots (Local)  46
# Maribel Baeza Adame                New England - Patriots (Local)  40
# Alejandro Barragán Huerta          New England - Patriots (Local)  39
# Luis Mendoza Armendáriz            New England - Patriots (Local)  43
# Magaly Teresa Ochoa Lugo           New England - Patriots (Local)  48
# Marisela Chacón Molina             New England - Patriots (Local)  49
# Manuel Alejandro Escobar Aguilera  New England - Patriots (Local)  39
# Jaime Jesús Irigoyen Hernández     New England - Patriots (Local)  40
# Ana Alejandra Donati Lugo          New England - Patriots (Local)  48
# José Carlos Salgado Gómez          New England - Patriots (Local)  45
# Luis Alberto López Mónge           New England - Patriots (Local)  47
# Erick Benavides Correa             New England - Patriots (Local)  46
# Cynthia Jaqueline Peralta Sosa                  New York - Giants  58
# Ilse Lozano Rodríguez              New England - Patriots (Local)  44
# Ezequiel Chávez Gutierrez          New England - Patriots (Local)  45
# Derek Manuel Calderón Rubio        New England - Patriots (Local)  41
# José Eduardo López Acosta          New England - Patriots (Local)  49
# Jerónimo Reyes Ibarra                           New York - Giants  46

# %%
faltaron_df = pd.DataFrame(faltaron, columns=['Participante']).reset_index(drop=True)
faltaron_df.index = range(1, len(faltaron_df) + 1)
faltaron_html = faltaron_df
faltaron_df
# Out:
# Empty DataFrame
# Columns: [Participante]
# Index: []

# %% [markdown]
# # Extración de resultados directamente de la pagina de ESPN

# %% [markdown]
# equipos_nfl = {
#     'Arizona Cardinals' : 'Arizona - Cardinals',
#     'Atlanta Falcons' : 'Atlanta - Falcons',
#     'Baltimore Ravens' : 'Baltimore - Ravens',
#     'Buffalo Bills' : 'Buffalo - Bills',
#     'Carolina Panthers' : 'Carolina - Panthers',
#     'Chicago Bears' : 'Chicago - Bears',
#     'Cincinnati Bengals' : 'Cincinnati - Bengals',
#     'Cleveland Browns' : 'Cleveland - Browns',
#     'Dallas Cowboys' : 'Dallas - Cowboys',
#     'Denver Broncos' : 'Denver - Broncos',
#     'Detroit Lions' : 'Detroit - Lions',
#     'Green Bay Packers' : 'Green Bay - Packers',
#     'Houston Texans' : 'Houston - Texans',
#     'Indianapolis Colts' : 'Indianapolis - Colts',
#     'Jacksonville Jaguars' : 'Jacksonville - Jaguars',
#     'Kansas City Chiefs' : 'Kansas City - Chiefs',
#     'Las Vegas Raiders' : 'Las Vegas - Raiders',
#     'Los Angeles Chargers' : 'Los Angeles - Chargers',
#     'Los Angeles Rams' : 'Los Angeles - Rams',
#     'Miami Dolphins' : 'Miami - Dolphins',
#     'Minnesota Vikings' : 'Minnesota - Vikings',
#     'New England Patriots' : 'New England - Patriots',
#     'New Orleans Saints' : 'New Orleans - Saints',
#     'New York Giants' : 'New York - Giants',
#     'New York Jets' : 'New York - Jets',
#     'Philadelphia Eagles' : 'Philadelphia - Eagles',
#     'Pittsburgh Steelers' : 'Pittsburgh - Steelers',
#     'San Francisco 49ers' : 'San Francisco - 49ers',
#     'Seattle Seahawks' : 'Seattle - Seahawks',
#     'Tampa Bay Buccaneers' : 'Tampa Bay - Buccaneers',
#     'Tennessee Titans' : 'Tennessee - Titans',
#     'Washington Commanders' : 'Washington - Commanders'
#
# }
#
# estadios_nfl = {
#     'State Farm Stadium Arizona - Cardinals': 'Arizona - Cardinals (Local)',
#     "AT&T Stadium Dallas - Cowboys": "Dallas - Cowboys (Local)",
#     "Mercedes-Benz Stadium Atlanta - Falcons": "Atlanta - Falcons (Local)",
#     "M&T Bank Stadium Baltimore - Ravens": "Baltimore - Ravens (Local)",
#     "Highmark Stadium Buffalo - Bills": "Buffalo - Bills (Local)",
#     "Bank of America Stadium Carolina - Panthers": "Carolina - Panthers (Local)",
#     "Soldier Field Chicago - Bears": "Chicago - Bears (Local)",
#     "Paycor Stadium Cincinnati - Bengals": "Cincinnati - Bengals (Local)",
#     "Cleveland Browns Stadium Cleveland - Browns": "Cleveland - Browns (Local)",
#     "Empower Field at Mile High Denver - Broncos": "Denver - Broncos (Local)",
#     "Ford Field Detroit - Lions": "Detroit - Lions (Local)",
#     "MetLife Stadium New York - Giants": "New York - Giants (Local)",
#     "MetLife Stadium New York - Jets": "New York - Jets (Local)",
#     "Gillette Stadium New England - Patriots": "New England - Patriots (Local)",
#     "Lambeau Field Green Bay - Packers": "Green Bay - Packers (Local)",
#     "NRG Stadium Houston - Texans": "Houston - Texans (Local)",
#     "Lucas Oil Stadium Indianapolis - Colts": "Indianapolis - Colts (Local)",
#     "SoFi Stadium Los Angeles - Rams": "Los Angeles - Rams (Local)",
#     "SoFi Stadium Los Angeles - Chargers": "Los Angeles - Chargers (Local)",
#     "EverBank Stadium Jacksonville - Jaguars": "Jacksonville - Jaguars (Local)",
#     "GEHA Field at Arrowhead Stadium Kansas City - Chiefs": "Kansas City - Chiefs (Local)",
#     "Allegiant Stadium Las Vegas - Raiders": "Las Vegas - Raiders (Local)",
#     "Hard Rock Stadium Miami - Dolphins": "Miami - Dolphins (Local)",
#     "U.S. Bank Stadium Minnesota - Vikings": "Minnesota - Vikings (Local)",
#     "Nissan Stadium Tennessee - Titans": "Tennessee - Titans (Local)",
#     "Caesars Superdome New Orleans - Saints": "New Orleans - Saints (Local)",
#     "Lincoln Financial Field Philadelphia - Eagles": "Philadelphia - Eagles (Local)",
#     "Acrisure Stadium Pittsburgh - Steelers": "Pittsburgh - Steelers (Local)",
#     "Levi's Stadium San Francisco - 49ers": "San Francisco - 49ers (Local)",
#     "Lumen Field Seattle - Seahawks": "Seattle - Seahawks (Local)",
#     "Raymond James Stadium Tampa Bay - Buccaneers": "Tampa Bay - Buccaneers (Local)",
#     "FedExField Washington - Commanders": "Washington - Commanders (Local)",
#     'Northwest Stadium Washington - Commanders': "Washington - Commanders (Local)",
#     'Huntington Bank Field Cleveland - Browns': 'Cleveland - Browns (Local)'
# }
#
#
# import pandas as pd
# import requests
# import os
#
# # Ruta del archivo
# archivo_excel = r'C:\Users\gaas\OneDrive - SERVIFOR, S.C\Personal\Proyectos_personales\NFL\2025\marcador_2025.xlsx'
#
#
#
# tipo_temporada = 2
# temporada_regular = {}
#
# for semana in range(1, 19):
#     url = f"https://site.api.espn.com/apis/site/v2/sports/football/nfl/scoreboard?week={semana}&seasontype={tipo_temporada}"
#     response = requests.get(url)
#     data = response.json()
#
#     partidos = []
#     for event in data.get("events", []):
#         nombre_partido = event.get("name")
#         fecha = event.get("date")
#         competencia = event.get("competitions", [])[0]
#         equipos = [equipo["team"]["name"] for equipo in competencia.get("competitors", [])]
#         equipo_1 = nombre_partido.split(" at ")[0] if " at " in nombre_partido else None
#         equipo_1 = equipos_nfl.get(equipo_1, equipo_1)
#         equipo_2 = nombre_partido.split(" at ")[1] if " at " in nombre_partido else None
#         equipo_2 = equipos_nfl.get(equipo_2, equipo_2)
#         estadio = competencia.get("venue", {}).get("fullName", "Desconocido")
#         puntos_equipo_1 = competencia.get("competitors", [])[1].get("score", 0)
#         puntos_equipo_2 = competencia.get("competitors", [])[0].get("score", 0)
#
#         partidos.append({
#             "Partido": nombre_partido,
#             "Fecha": fecha,
#             "Equipo 1": equipo_1,
#             "Puntos Equipo 1": puntos_equipo_1,
#             "Equipo 2": equipo_2,
#             "Puntos Equipo 2": puntos_equipo_2,
#             "Estadio": estadio,
#         })
#
#     df = pd.DataFrame(partidos)
#     df['combinación'] = df['Estadio'] + " " + df['Equipo 2']
#     df['Local'] = df['combinación'].map(estadios_nfl)
#     df['Local'] = df['Local'].fillna(df['Equipo 2'])
#     df['Ganador'] = df.apply(lambda row: row['Equipo 1'] if int(row['Puntos Equipo 1']) > int(row['Puntos Equipo 2']) else (row['Local'] if int(row['Puntos Equipo 2']) > int(row['Puntos Equipo 1']) else 'Empate'), axis=1)
#
#     temporada_regular[semana] = df
#
# # Guardar todas las semanas en el archivo Excel
# with pd.ExcelWriter(archivo_excel, engine='openpyxl', mode='a', if_sheet_exists='replace') as writer:
#     for semana, df in temporada_regular.items():
#         df.to_excel(writer, sheet_name=str(semana), index=False)
#
#
#
# # Ruta del archivo
# archivo = r'C:\Users\gaas\OneDrive - SERVIFOR, S.C\Personal\Proyectos_personales\NFL\2025\marcador_2025.xlsx'
#
# # Diccionario para almacenar ganadores por semana
# ganadores_por_semana = {}
#
# for semana in range(1, 19):
#     nombre_hoja = str(semana)
#     try:
#         df = pd.read_excel(archivo, sheet_name=nombre_hoja, engine='openpyxl')
#         if 'Ganador' in df.columns:
#             ganadores_por_semana[semana] = df['Ganador'].tolist()
#         else:
#             ganadores_por_semana[semana] = ['Columna "Ganador" no encontrada']
#     except Exception as e:
#         ganadores_por_semana[semana] = ['Hoja no encontrada']
#
# # Crear DataFrame con índice como semana
# df_ganadores_semanales = pd.DataFrame.from_dict(ganadores_por_semana, orient='index')
# df_ganadores_semanales.index.name = 'Semana'
#
# # Mostrar el DataFrame
# df_ganadores_semanales
#
# import pandas as pd
#
# # Ruta del archivo
# archivo = r'C:\Users\gaas\OneDrive - SERVIFOR, S.C\Personal\Proyectos_personales\NFL\2025\marcador_2025.xlsx'
#
# # Diccionario para almacenar ganadores por semana
# ganadores_por_semana = {}
#
# for semana in range(1, 19):
#     nombre_hoja = str(semana)
#     try:
#         df = pd.read_excel(archivo, sheet_name=nombre_hoja, engine='openpyxl')
#         if 'Ganador' in df.columns:
#             ganadores_por_semana[semana] = df['Ganador'].tolist()
#         else:
#             ganadores_por_semana[semana] = ['Columna "Ganador" no encontrada']
#     except Exception as e:
#         ganadores_por_semana[semana] = ['Hoja no encontrada']
#
# # Crear DataFrame con índice como semana
# df_ganadores_semanales = pd.DataFrame.from_dict(ganadores_por_semana, orient='index')
# df_ganadores_semanales.index.name = 'Semana'
#
# # Mostrar el DataFrame
# df_ganadores_semanales.loc[numero]

# %% [markdown]
# # Usar resultados de la semana actual para comparar con la quiniela

# %%
#ruta_carpeta_nfl = os.chdir(r'C:\Users\gaas\OneDrive - SERVIFOR, S.C\Personal\Proyectos_personales\NFL')
#ruta_carpeta_nfl
#onedrive_casa

# Leer el archivo sin encabezado y usando la primera columna como índice
resultados_partidos = pd.read_excel('NFL Resultados 2025.xlsx',
                                    header=None,
                                    index_col=0)

# Eliminar filas con índice nulo
resultados_partidos = resultados_partidos[resultados_partidos.index.notna()]

# Convertir el índice a entero
resultados_partidos.index = resultados_partidos.index.astype(int)

resultados_partidos.loc[numero]

#resultados_partidos = df_ganadores_semanales
#resultados_partidos.loc[numero]
# Out:
# 1                Green Bay - Packers
# 2           Dallas - Cowboys (Local)
# 3               Cincinnati - Bengals
# 4                    Chicago - Bears
# 5              San Francisco - 49ers
# 6             Jacksonville - Jaguars
# 7                   Houston - Texans
# 8           Miami - Dolphins (Local)
# 9            New York - Jets (Local)
# 10    Tampa Bay - Buccaneers (Local)
# 11       Carolina - Panthers (Local)
# 12        Seattle - Seahawks (Local)
# 13                   Buffalo - Bills
# 14    Los Angeles - Chargers (Local)
# 15                  Denver - Broncos
# 16    New England - Patriots (Local)
# 17                               NaN
# Name: 13, dtype: object

# %% [markdown]
# # Definir aciertos semanales

# %%
def contar_aciertos(quiniela, resultados):
    import pandas as pd

    def limpiar_nombre(equipo):
        if isinstance(equipo, str):
            return equipo.replace("(Local)", "").strip().lower()
        return equipo
    acierto_semanal = pd.DataFrame()

    for semana, quiniela_semana_actual in quiniela.items():
        aciertos_semana = {}

        try:
            semana_int = int(semana)
        except ValueError:
            print(f"Semana '{semana}' no es un número válido.")
            continue

        if semana_int not in resultados.index:
            print(f"Semana {semana_int} no encontrada en resultados")
            continue

        resultado_real = resultados.loc[semana_int]
        resultado_real = resultado_real.apply(limpiar_nombre)

        for participante in quiniela_semana_actual.index:
            seleccion_participante = quiniela_semana_actual.loc[participante]
            seleccion_participante = seleccion_participante.reindex(resultado_real.index)
            seleccion_participante = seleccion_participante.apply(limpiar_nombre)

            aciertos_semana[participante] = (seleccion_participante == resultado_real).sum()

        acierto_semanal[semana_int] = pd.Series(aciertos_semana)

    acierto_semanal.fillna(0, inplace=True)
    acierto_semanal = acierto_semanal.astype(int)
    acierto_semanal['Total Aciertos'] = acierto_semanal.sum(axis=1)

    return acierto_semanal

# %% [markdown]
# # Generación de tabla Preliminar

# %%
# Llamar a la función para obtener los aciertos semanales por participante
aciertos_semanales = contar_aciertos(quinela, resultados_partidos)

# Ordenar el DataFrame por el total de aciertos en orden descendente
aciertos_semanales = aciertos_semanales.sort_values(by='Total Aciertos', 
                                                    ascending=False)

semana_actual = pd.DataFrame(aciertos_semanales[semana_numero].sort_values(ascending=False))
semana_actual.columns = ['Semana %i' % semana_numero]

# Aqui los números que restan es para escojer la columna a mostrar
marcador = quinela_semanal.shape[1] - 1
partidos = quinela_semanal.shape[1] - 2

partido_lunes = quinela_semanal.iloc[:, [partidos, marcador]]
partido_lunes.columns = ['Último juego','Puntos']
preliminar = pd.merge(semana_actual, 
                      partido_lunes, 
                      left_index=True, 
                      right_index=True)

columna_semana_actual = semana_actual.columns[0]

preliminar = preliminar.sort_values(by=[columna_semana_actual, 'Puntos'], ascending=False)

preliminar = pd.DataFrame(preliminar)
preliminar.index.name = 'Participante'

preliminar
# Out:
# Semana 0 no encontrada en resultados
#                                    Semana 13                    Último juego  \
# Participante
# Santos Vazquez Garza                      12  New England - Patriots (Local)
# Guiorguio Guitto Sánchez Muñoz            11  New England - Patriots (Local)
# Neima Dorely Meza Jáquez                  11  New England - Patriots (Local)
# Manuel Alejandro Escobar Aguilera         11  New England - Patriots (Local)
# Judith Fernández Franco                   10  New England - Patriots (Local)
# Kenia Estefanía Cruz García               10  New England - Patriots (Local)
# Magaly Teresa Ochoa Lugo                  10  New England - Patriots (Local)
# Luis Alberto López Mónge                  10  New England - Patriots (Local)
# Jerónimo Reyes Ibarra                     10               New York - Giants
# Erick Benavides Correa                    10  New England - Patriots (Local)
# Luis Mendoza Armendáriz                   10  New England - Patriots (Local)
# Alejandro Barragán Huerta                 10  New England - Patriots (Local)
# Gerardo Abraham Ayala Siqueiros           10  New England - Patriots (Local)
# Jaime Antonio García Morales              10  New England - Patriots (Local)
# Arelí Olivas Alcántar                      9  New England - Patriots (Local)
# José Eduardo López Acosta                  9  New England - Patriots (Local)
# Ana Alejandra Donati Lugo                  9  New England - Patriots (Local)
# Alberto Vargas Ortiz                       9  New England - Patriots (Local)
# Raúl Humberto García Robledo               9  New England - Patriots (Local)
# Ezequiel Chávez Gutierrez                  9  New England - Patriots (Local)
# José Carlos Salgado Gómez                  9  New England - Patriots (Local)
# Ilse Lozano Rodríguez                      9  New England - Patriots (Local)
# Andrea Bustamante Yapur                    9  New England - Patriots (Local)
# José Roberto González Hernández            9  New England - Patriots (Local)
# Derek Manuel Calderón Rubio                9  New England - Patriots (Local)
# Jaime Jesús Irigoyen Hernández             9  New England - Patriots (Local)
# Cynthia Jaqueline Peralta Sosa             8               New York - Giants
# Marisela Chacón Molina                     8  New England - Patriots (Local)
# Maribel Baeza Adame                        8  New England - Patriots (Local)
#
#                                    Puntos
# Participante
# Santos Vazquez Garza                   45
# Guiorguio Guitto Sánchez Muñoz         52
# Neima Dorely Meza Jáquez               41
# Manuel Alejandro Escobar Aguilera      39
# Judith Fernández Franco                52
# Kenia Estefanía Cruz García            49
# Magaly Teresa Ochoa Lugo               48
# Luis Alberto López Mónge               47
# Jerónimo Reyes Ibarra                  46
# Erick Benavides Correa                 46
# Luis Mendoza Armendáriz                43
# Alejandro Barragán Huerta              39
# Gerardo Abraham Ayala Siqueiros        36
# Jaime Antonio García Morales           35
# Arelí Olivas Alcántar                  53
# José Eduardo López Acosta              49
# Ana Alejandra Donati Lugo              48
# Alberto Vargas Ortiz                   47
# Raúl Humberto García Robledo           46
# Ezequiel Chávez Gutierrez              45
# José Carlos Salgado Gómez              45
# Ilse Lozano Rodríguez                  44
# Andrea Bustamante Yapur                43
# José Roberto González Hernández        42
# Derek Manuel Calderón Rubio            41
# Jaime Jesús Irigoyen Hernández         40
# Cynthia Jaqueline Peralta Sosa         58
# Marisela Chacón Molina                 49
# Maribel Baeza Adame                    40

# %% [markdown]
# # Envio de correo con resultados de quiniela semanal

# %%
# Lista de equipos ganadores
equipos_ganadores = resultados_partidos.loc[numero].dropna().tolist()

# Función para aplicar color solo a columnas específicas
def resaltar_ganadores(val):
    if val in equipos_ganadores:
        return 'background-color: #D5F5E3'  # verde claro
    else:
        return 'background-color: #FADBD8'  # rojo claro

# Excluir la última columna
columnas_a_formatear = quiniela_semana_actual.columns[1:-1]

quiniela_semana_actual = quiniela_semana_actual.set_index('Participante')
quiniela_semana_actual.index.name = 'Participante'
# Aplicar estilo solo a esas columnas
quiniela_final = quiniela_semana_actual.style.applymap(resaltar_ganadores, subset=columnas_a_formatear)


from premailer import transform
# ------------------------------
# TABLA PRELIMINAR
# ------------------------------
# Aplica gradiente + estilos de tabla
preliminar_estilada = (
    preliminar.style
    .background_gradient(
        cmap='RdYlGn',  # gradiente
        axis=0
    )
    .set_table_styles(
        [
            {"selector": "th", 
             "props": [
                 ("background-color", "#2E86C1"),
                 ("color", "white"),
                 ("text-align", "center"),
                 ("font-weight", "bold"),
                 ("padding", "8px")
             ]},
            {"selector": "td", 
             "props": [
                 ("text-align", "center"),
                 ("padding", "6px")
             ]},
            {"selector": "table",
             "props": [
                 ("border-collapse", "collapse"),
                 ("margin", "0 auto"),
                 ("font-family", "Arial, sans-serif"),
                 ("font-size", "14px")
             ]}
        ]
    )
)


preliminar_html = preliminar_estilada.to_html()
preliminar_html_inlined = transform(preliminar_html, remove_classes=True, strip_important=False)

# ------------------------------
# TABLA QUINIELA
# ------------------------------

quiniela_estilada = (
    quiniela_semana_actual.style
    .applymap(resaltar_ganadores, subset=columnas_a_formatear)
    .set_table_styles(
        [
            {"selector": "th", 
             "props": [
                 ("background-color", "#2E86C1"),
                 ("color", "white"),
                 ("text-align", "center"),
                 ("font-weight", "bold"),
                 ("padding", "8px")
             ]},
            {"selector": "td", 
             "props": [
                 ("text-align", "center"),
                 ("padding", "6px")
             ]},
            {"selector": "table",
             "props": [
                 ("border-collapse", "collapse"),
                 ("margin", "0 auto"),
                 ("font-family", "Arial, sans-serif"),
                 ("font-size", "14px")
             ]}
        ]
    )
)

quiniela_html = quiniela_estilada.to_html()
quiniela_html_inlined = transform(quiniela_html, remove_classes=True, strip_important=False)

import smtplib
from email.mime.multipart import MIMEMultipart
from email.mime.text import MIMEText
from email.mime.base import MIMEBase
from email import encoders
import pandas as pd

# Configuración del servidor y credenciales
smtp_server = 'smtp.office365.com'
smtp_port = 587
username = 'gaas@citlali.mx'
password = 'nashira1103'


asunto = f"🏈✨📣 Resultado final de Quiniela de la semana {numero}📣✨🏈"
nombre_archivo = f"resultado de la semana {numero}"

# Crear el mensaje
msg = MIMEMultipart()
msg['From'] = username
msg['To'] = username
msg['Subject'] = asunto
# Crear el cuerpo del mensaje con la tabla embebida
# Cuerpo del correo con la tabla en línea
body = f"""
<html>
<head><meta charset="UTF-8"></head>
<body style="font-family: Arial, sans-serif; color: #333;">
<p style="color: #2E86C1;"><strong>👋 ¡¡Hola buen día a todos!!</strong></p>

<p><strong style="color: #117A65;">El {nombre_archivo}</strong> 🏈:</p>

<h3 style="color:#2E86C1;">📊 Puntos finales</h3>
{preliminar_html_inlined}

<h3 style="color:#117A65;">🏆 Quiniela Final</h3>
{quiniela_html_inlined}

<p style="color: #28B463;"><strong>Favor de reportarse con el ganador 🎉 y enviar su comprobante 🧾💵💰 al grupo de WhatsApp</strong></p>

<p style="color: #566573;">Salu✌️,<br>📬 Equipo Citlali ⭐</p>
</body>
</html>
"""

msg.attach(MIMEText(body, 'html', 'utf-8'))


filename = nombre_archivo


part = MIMEBase('application', 'octet-stream')

part.add_header('Content-Disposition', f"attachment; filename= {filename}")



# Enviar el correo
try:
    server = smtplib.SMTP(smtp_server, smtp_port)
    server.starttls()
    server.login(username, password)
    text = msg.as_string()
    server.sendmail(username, [username], text)
    server.quit()
    print("Correo enviado exitosamente")
except Exception as e:
    print(f"Error al enviar el correo: {e}")
# Out:
# Correo enviado exitosamente

# %%
#Puntos de diferencia par desempate
jugador_1 = 48
jugador_2 = 42
valor = 24+21
diferencia_1 = jugador_1 - valor
diferencia_2 = valor - jugador_2
print(f'El partido terminó con un marcador de {valor}')
print(f'Jugador_1 tiene {jugador_1} su diferencia es de {diferencia_1}')
print(f'Jugador_2 tiene {jugador_2} su diferencia es de {diferencia_2}\n')
if diferencia_1 < diferencia_2:
    print(f'El jugador_1 gana con {diferencia_1} puntos de diferencia')
elif diferencia_1 > diferencia_2:
    print(f'El jugador_2 gana con {diferencia_2} puntos de diferencia')
else:
    print(f'El partido termina en empate con {diferencia_1} puntos de diferencia')
# Out:
# El partido terminó con un marcador de 45
# Jugador_1 tiene 48 su diferencia es de 3
# Jugador_2 tiene 42 su diferencia es de 3
#
# El partido termina en empate con 3 puntos de diferencia

# %%
semana_12 = len(inscritos_quiniela) - 5
print(f'La semana 12 re recaudará {semana_12 * 50} de {semana_12} inscritos + {200} de las personas que no se inscribieron\n'
      f'En total la semana 12 se recaudará {semana_12 * 50 + 200}\n'
      f'Entre los 3 ganadores, cada uno recibirá {(semana_12 * 50 + 200)/3}')
# Out:
# La semana 12 re recaudará 1200 de 24 inscritos + 200 de las personas que no se inscribieron
# En total la semana 12 se recaudará 1400
# Entre los 3 ganadores, cada uno recibirá 466.6666666666667
