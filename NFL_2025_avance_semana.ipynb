# %%
numero = 14

inscritos_quiniela = [ 
    'Gerardo Abraham Ayala Siqueiros',
    'Marisela Chacón Molina',
    'Arelí Olivas Alcántar',
    'Maribel Baeza Adame',
    'Santos Vazquez Garza',
    'Manuel Alejandro Escobar Aguilera',
    'José Carlos Salgado Gómez',
    'Alberto Vargas Ortiz',
    'Raúl Humberto García Robledo',
    'Alejandro Barragán Huerta',
    'Kenia Estefanía Cruz García',
    'Jaime Antonio García Morales',
    'Jerónimo Reyes Ibarra',
    'Guiorguio Guitto Sánchez Muñoz',
    'Neima Dorely Meza Jáquez',
    'Ezequiel Chávez Gutierrez',
    'Jaime Jesús Irigoyen Hernández',
    'Judith Fernández Franco',
    'Magaly Teresa Ochoa Lugo',
    'Ana Alejandra Donati Lugo',
    'Andrea Bustamante Yapur',
    "José Roberto González Hernández",
    "Ilse Lozano Rodríguez",
    'Erick Benavides Correa',
    'Cynthia Jaqueline Peralta Sosa',
    'Luis Mendoza Armendáriz',
    'José Eduardo López Acosta',
    'Derek Manuel Calderón Rubio', 
    'Luis Alberto López Mónge'   
    ]
inscritos_acumulado = [ 
    'Gerardo Abraham Ayala Siqueiros',
    'Arelí Olivas Alcántar',
    'Maribel Baeza Adame',
    'Santos Vazquez Garza',
    'Manuel Alejandro Escobar Aguilera',
    'José Carlos Salgado Gómez',
    'Alberto Vargas Ortiz',
    'Raúl Humberto García Robledo',
    'Alejandro Barragán Huerta',
    'Kenia Estefanía Cruz García',
    'Jerónimo Reyes Ibarra',
    'Guiorguio Guitto Sánchez Muñoz',
    'Ezequiel Chávez Gutierrez',
    'Jaime Jesús Irigoyen Hernández',
    'Judith Fernández Franco',
    'Ana Alejandra Donati Lugo',
    'Andrea Bustamante Yapur',
    "Ilse Lozano Rodríguez",
    'Luis Mendoza Armendáriz',
    'José Eduardo López Acosta',
    'Luis Alberto López Mónge'
    
    ]

bajas = []

diccionario_correos ={
    'mcm@citlali.mx':'Marisela Chacón Molina',
    'ggsm@citlali.mx':'Guiorguio Guitto Sánchez Muñoz',
    'avo@citlali.mx':'Alberto Vargas Ortiz',
    'jff@citlali.mx':'Judith Fernández Franco',
    'aby@citlali.mx':'Andrea Bustamante Yapur',
    'mba@citlali.mx':'Maribel Baeza Adame',
    'meg@citlali.mx':'Manuel Alejandro Escobar Aguilera',
    'gaas@citlali.mx':'Gerardo Abraham Ayala Siqueiros',
    'aoa@citlali.mx':'Arelí Olivas Alcántar',
    'jela@citlali.mx':'José Eduardo López Acosta',
    'rhgr@citlali.mx':'Raúl Humberto García Robledo',
    'kecg@citlali.mx':'Kenia Estefanía Cruz García',
    'jcsg@citlali.mx':'José Carlos Salgado Gómez',
    'ndmj@citlali.mx':'Neima Dorely Meza Jáquez',
    'jjih@citlali.mx':'Jaime Jesús Irigoyen Hernández',
    'lalm@citlali.mx':'Luis Alberto López Mónge',
    'jrgh@citlali.mx':'José Roberto González Hernández',
    'mtol@citlali.mx':'Magaly Teresa Ochoa Lugo',
    'svg@citlali.mx':'Santos Vazquez Garza',
    'jri@citlali.mx':'Jerónimo Reyes Ibarra',
    'ilr@citlali.mx':'Ilse Lozano Rodríguez',
    'abh@citlali.mx':'Alejandro Barragán Huerta',
    'dmcr@citlali.mx':'Derek Manuel Calderón Rubio',
    'lma@citlali.mx':'Luis Mendoza Armendáriz',
    'jagm@citlali.mx':'Jaime Antonio García Morales',
    'ecg@citlali.mx':'Ezequiel Chávez Gutierrez',
    'aadl@citlali.mx':'Ana Alejandra Donati Lugo',
    'ebc@citlali.mx':'Erick Benavides Correa',
    'cjps@citlali.mx':'Cynthia Jaqueline Peralta Sosa'

}


conteo = 0
total_quiniela = len(inscritos_quiniela)
total_acumulado = len(inscritos_acumulado)

print(f'En total, por toda la tempora se invertiran {50 *18}\n')
print(f'Se han inscrito a la quiniela {total_quiniela} personas.\nPor semana el ganador se llevará {total_quiniela * 50}. \nLos inscritos son:\n')
for i in inscritos_quiniela:
    conteo += 1
    print(f'{conteo}. {i}')
conteo = 0    

print(f'\nAl acumulado se han inscrito {total_acumulado} personas. \nLa bolsa acumulada es de {total_acumulado * 250}. \nLos inscritos son:\n')
for i in inscritos_acumulado:
    conteo += 1
    print(f'{conteo}. {i}')
conteo = 0

print('\nLos que se anotaron en quiniela, pero no en el acumulado son:\n')
for i in inscritos_quiniela:
    if i not in inscritos_acumulado:
        conteo += 1
        print(f'{conteo}. {i}')
# Out:
# En total, por toda la tempora se invertiran 900
#
# Se han inscrito a la quiniela 29 personas.
# Por semana el ganador se llevará 1450.
# Los inscritos son:
#
# 1. Gerardo Abraham Ayala Siqueiros
# 2. Marisela Chacón Molina
# 3. Arelí Olivas Alcántar
# 4. Maribel Baeza Adame
# 5. Santos Vazquez Garza
# 6. Manuel Alejandro Escobar Aguilera
# 7. José Carlos Salgado Gómez
# 8. Alberto Vargas Ortiz
# 9. Raúl Humberto García Robledo
# 10. Alejandro Barragán Huerta
# 11. Kenia Estefanía Cruz García
# 12. Jaime Antonio García Morales
# 13. Jerónimo Reyes Ibarra
# 14. Guiorguio Guitto Sánchez Muñoz
# 15. Neima Dorely Meza Jáquez
# 16. Ezequiel Chávez Gutierrez
# 17. Jaime Jesús Irigoyen Hernández
# 18. Judith Fernández Franco
# 19. Magaly Teresa Ochoa Lugo
# 20. Ana Alejandra Donati Lugo
# 21. Andrea Bustamante Yapur
# 22. José Roberto González Hernández
# 23. Ilse Lozano Rodríguez
# 24. Erick Benavides Correa
# 25. Cynthia Jaqueline Peralta Sosa
# 26. Luis Mendoza Armendáriz
# 27. José Eduardo López Acosta
# 28. Derek Manuel Calderón Rubio
# 29. Luis Alberto López Mónge
#
# Al acumulado se han inscrito 21 personas.
# La bolsa acumulada es de 5250.
# Los inscritos son:
#
# 1. Gerardo Abraham Ayala Siqueiros
# 2. Arelí Olivas Alcántar
# 3. Maribel Baeza Adame
# 4. Santos Vazquez Garza
# 5. Manuel Alejandro Escobar Aguilera
# 6. José Carlos Salgado Gómez
# 7. Alberto Vargas Ortiz
# 8. Raúl Humberto García Robledo
# 9. Alejandro Barragán Huerta
# 10. Kenia Estefanía Cruz García
# 11. Jerónimo Reyes Ibarra
# 12. Guiorguio Guitto Sánchez Muñoz
# 13. Ezequiel Chávez Gutierrez
# 14. Jaime Jesús Irigoyen Hernández
# 15. Judith Fernández Franco
# 16. Ana Alejandra Donati Lugo
# 17. Andrea Bustamante Yapur
# 18. Ilse Lozano Rodríguez
# 19. Luis Mendoza Armendáriz
# 20. José Eduardo López Acosta
# 21. Luis Alberto López Mónge
#
# Los que se anotaron en quiniela, pero no en el acumulado son:
#
# 1. Marisela Chacón Molina
# 2. Jaime Antonio García Morales
# 3. Neima Dorely Meza Jáquez
# 4. Magaly Teresa Ochoa Lugo
# 5. José Roberto González Hernández
# 6. Erick Benavides Correa
# 7. Cynthia Jaqueline Peralta Sosa
# 8. Derek Manuel Calderón Rubio

# %%
import pandas as pd
import os
import warnings



#onedrive_casa = os.chdir(r'C:\Users\Goyaro\OneDrive\Documentos\Proyectos\Proyectos_personales\NFL')
#onedrive_trabajo = os.chdir(r"C:\Users\gaas\OneDrive - SERVIFOR, S.C")
#nfl_2025_oficina = os.chdir(r'C:\Users\gaas\OneDrive - SERVIFOR, S.C\Personal\Proyectos_personales\NFL\2025')
#nfl_2025_oficina


archivo = f'Semana {numero} NFL 2025.xlsx'

fecha_inicio = pd.to_datetime('2025-09-01')

#onedrive_trabajo
#onedrive_casa

warnings.filterwarnings("ignore")
respuestas = pd.read_excel(archivo)

respuestas['fecha'] = respuestas['Completion time'].dt.date
respuestas['semana'] = (respuestas['Completion time'] - fecha_inicio).dt.days // 7 + 1

columnas = ['semana', 'fecha']
columnas_viejas = [col for col in respuestas.columns if col not in columnas]

respuestas = respuestas[columnas + columnas_viejas]
respuestas = respuestas.rename(columns={'Name':'Participante'})
respuestas['Participante'] = respuestas['Email'].map(diccionario_correos)

correos = respuestas['Email'].unique()

respuestas
# Out:
#     semana       fecha  Id          Start time     Completion time  \
# 0       14  2025-12-02   1 2025-12-02 08:49:33 2025-12-02 08:52:27
# 1       14  2025-12-02   2 2025-12-02 08:59:06 2025-12-02 09:01:53
# 2       14  2025-12-02   3 2025-12-02 09:13:42 2025-12-02 09:15:39
# 3       14  2025-12-02   4 2025-12-02 09:10:44 2025-12-02 09:17:02
# 4       14  2025-12-02   5 2025-12-02 10:51:11 2025-12-02 10:52:20
# 5       14  2025-12-02   6 2025-12-02 14:12:13 2025-12-02 14:41:55
# 6       14  2025-12-02   7 2025-12-02 15:43:11 2025-12-02 15:46:03
# 7       14  2025-12-02   8 2025-12-02 15:55:34 2025-12-02 15:58:20
# 8       14  2025-12-03   9 2025-12-03 13:19:29 2025-12-03 13:20:54
# 9       14  2025-12-03  10 2025-12-03 13:18:17 2025-12-03 13:29:44
# 10      14  2025-12-03  11 2025-12-03 16:06:47 2025-12-03 16:07:29
# 11      14  2025-12-03  12 2025-12-03 16:04:50 2025-12-03 16:11:15
# 12      14  2025-12-03  13 2025-12-03 16:25:00 2025-12-03 16:26:35
# 13      14  2025-12-03  14 2025-12-03 17:41:29 2025-12-03 17:46:30
# 27  mtol@citlali.mx           Magaly Teresa Ochoa Lugo       NaN
#
#                      Column                    Column1  ...  \
# 0   Detroit - Lions (Local)         Seattle - Seahawks  ...
# 1          Dallas - Cowboys         Seattle - Seahawks  ...
# 2          Dallas - Cowboys         Seattle - Seahawks  ...
# 3   Detroit - Lions (Local)         Seattle - Seahawks  ...
# 4          Dallas - Cowboys         Seattle - Seahawks  ...
# 5   Detroit - Lions (Local)         Seattle - Seahawks  ...
# 6   Detroit - Lions (Local)         Seattle - Seahawks  ...
# 7   Detroit - Lions (Local)         Seattle - Seahawks  ...
# 8          Dallas - Cowboys         Seattle - Seahawks  ...
# 9          Dallas - Cowboys         Seattle - Seahawks  ...
# 10         Dallas - Cowboys  Atlanta - Falcons (Local)  ...
# 11         Dallas - Cowboys  Atlanta - Falcons (Local)  ...
# 12  Detroit - Lions (Local)         Seattle - Seahawks  ...
# 13  Detroit - Lions (Local)         Seattle - Seahawks  ...
# 14         Dallas - Cowboys         Seattle - Seahawks  ...
# 15  Detroit - Lions (Local)         Seattle - Seahawks  ...
# 16  Detroit - Lions (Local)         Seattle - Seahawks  ...
# 17  Detroit - Lions (Local)         Seattle - Seahawks  ...
# 18  Detroit - Lions (Local)         Seattle - Seahawks  ...
# 19  Detroit - Lions (Local)         Seattle - Seahawks  ...
# 20         Dallas - Cowboys         Seattle - Seahawks  ...
# 21         Dallas - Cowboys         Seattle - Seahawks  ...
# 22  Detroit - Lions (Local)         Seattle - Seahawks  ...
# 23  Detroit - Lions (Local)         Seattle - Seahawks  ...
# 24         Dallas - Cowboys         Seattle - Seahawks  ...
# 25  Detroit - Lions (Local)         Seattle - Seahawks  ...
# 26  Detroit - Lions (Local)         Seattle - Seahawks  ...
# 27  Detroit - Lions (Local)         Seattle - Seahawks  ...
#
#                     Column5                         Column6  \
# 0          Miami - Dolphins  Tampa Bay - Buccaneers (Local)
# 1          Miami - Dolphins  Tampa Bay - Buccaneers (Local)
# 2          Miami - Dolphins  Tampa Bay - Buccaneers (Local)
# 3          Miami - Dolphins  Tampa Bay - Buccaneers (Local)
# 4          Miami - Dolphins  Tampa Bay - Buccaneers (Local)
# 5          Miami - Dolphins  Tampa Bay - Buccaneers (Local)
# 6          Miami - Dolphins  Tampa Bay - Buccaneers (Local)
# 7          Miami - Dolphins  Tampa Bay - Buccaneers (Local)
# 8          Miami - Dolphins  Tampa Bay - Buccaneers (Local)
# 9          Miami - Dolphins  Tampa Bay - Buccaneers (Local)
# 10  New York - Jets (Local)  Tampa Bay - Buccaneers (Local)
# 11         Miami - Dolphins            New Orleans - Saints
# 12  New York - Jets (Local)  Tampa Bay - Buccaneers (Local)
# 13  New York - Jets (Local)  Tampa Bay - Buccaneers (Local)
# 14         Miami - Dolphins  Tampa Bay - Buccaneers (Local)
# 15         Miami - Dolphins  Tampa Bay - Buccaneers (Local)
# 16         Miami - Dolphins  Tampa Bay - Buccaneers (Local)
# 17  New York - Jets (Local)  Tampa Bay - Buccaneers (Local)
# 18         Miami - Dolphins  Tampa Bay - Buccaneers (Local)
# 25  Kansas City - Chiefs (Local)           Philadelphia - Eagles
# 26  Kansas City - Chiefs (Local)           Philadelphia - Eagles
# 27  Kansas City - Chiefs (Local)           Philadelphia - Eagles
#
#    Puntos totales del juego entre Philadelphia y Los Angeles para desempate:
# 0                                                  48
# 1                                                  49
# 2                                                  40
# 3                                                  40
# 4                                                  49
# 5                                                  47
# 6                                                  45
# 7                                                  50
# 8                                                  45
# 9                                                  43
# 10                                                 46
# 11                                                 43
# 12                                                 52
# 13                                                 53
# 14                                                 36
# 15                                                 43
# 16                                                 44
# 17                                                 52
# 18                                                 45
# 19                                                 42
# 20                                                 51
# 21                                                 45
# 22                                                 45
# 23                                                 41
# 24                                                 48
# 25                                                 52
# 26                                                 46
# 27                                                 48
#
# [28 rows x 23 columns]

# %%
# https://citlali.sharepoint.com/:x:/s/NFL/EaXwy92A0W1OsnemeG7kHIAB223zQbz7YMn39IIp58sRDA?e=sXaaRb
# https://citlali-my.sharepoint.com/:x:/g/personal/gaas_citlali_mx/EayxvIkt2tVNvrBnAqi9-5oBhZ4QxwTzZ3WcoqM45o6Eyw?e=oGgFIK

# %%
quiniela_semana_actual = respuestas[respuestas['semana'] == numero]
quiniela_semana_actual = quiniela_semana_actual.drop(columns=['Start time', 
                                                              'Language',
                                                              'Completion time', 
                                                              'Email', 
                                                              'semana', 
                                                              'fecha',
                                                              'Id'])
faltaron = []
for i in inscritos_quiniela:
    if i not in quiniela_semana_actual['Participante'].values:
        faltaron.append(i)

#faltaron_html = faltaron.to_html()
#nfl_2025_oficina = os.chdir(r'C:\Users\gaas\OneDrive - SERVIFOR, S.C\Personal\Proyectos_personales\NFL\2025')
#nfl_2025_oficina

#nfl_2025_casa = os.chdir(r'C:\Users\Goyaro\OneDrive\Documentos\Proyectos\Proyectos_personales\NFL\2025')
#nfl_2025_casa
nombre_quiniela_semanal = f'Quiniela Semana {numero} NFL 2025.xlsx'
excel_quiniela_semanal = quiniela_semana_actual.to_excel(nombre_quiniela_semanal, 
                                                         index=False,
                                                         sheet_name=f'{numero}',
                                                         header=None)
quiniela_semana_actual.columns = [quiniela_semana_actual.columns[0]] + list(range(1, 
                                                                                  len(quiniela_semana_actual.columns)))

quiniela_semana_actual.columns = list(quiniela_semana_actual.columns[:-1]) + ['Desempate']
quiniela_semana_actual
# Out:
#                          Participante                        1  \
# 0                 Maribel Baeza Adame  Detroit - Lions (Local)
# 1              Marisela Chacón Molina         Dallas - Cowboys
# 2        Raúl Humberto García Robledo         Dallas - Cowboys
# 3                Alberto Vargas Ortiz  Detroit - Lions (Local)
# 4   Manuel Alejandro Escobar Aguilera         Dallas - Cowboys
# 5     Gerardo Abraham Ayala Siqueiros  Detroit - Lions (Local)
# 6        Jaime Antonio García Morales  Detroit - Lions (Local)
# 7             Judith Fernández Franco  Detroit - Lions (Local)
# 8                Santos Vazquez Garza         Dallas - Cowboys
# 9             Luis Mendoza Armendáriz         Dallas - Cowboys
# 10             Erick Benavides Correa         Dallas - Cowboys
# 11     Jaime Jesús Irigoyen Hernández         Dallas - Cowboys
# 12     Guiorguio Guitto Sánchez Muñoz  Detroit - Lions (Local)
# 13              Arelí Olivas Alcántar  Detroit - Lions (Local)
# 14        Derek Manuel Calderón Rubio         Dallas - Cowboys
# 15            Andrea Bustamante Yapur  Detroit - Lions (Local)
# 16              Ilse Lozano Rodríguez  Detroit - Lions (Local)
# 17           Neima Dorely Meza Jáquez  Detroit - Lions (Local)
# 18          José Carlos Salgado Gómez  Detroit - Lions (Local)
# 19    José Roberto González Hernández  Detroit - Lions (Local)
# 20           Luis Alberto López Mónge         Dallas - Cowboys
# 21        Kenia Estefanía Cruz García         Dallas - Cowboys
# 22          Alejandro Barragán Huerta  Detroit - Lions (Local)
# 23          Ezequiel Chávez Gutierrez  Detroit - Lions (Local)
# 24          José Eduardo López Acosta         Dallas - Cowboys
# 25     Cynthia Jaqueline Peralta Sosa  Detroit - Lions (Local)
# 26              Jerónimo Reyes Ibarra  Detroit - Lions (Local)
# 27           Magaly Teresa Ochoa Lugo  Detroit - Lions (Local)
#
#                             2                           3  \
# 0          Seattle - Seahawks          Tennessee - Titans
# 1          Seattle - Seahawks  Cleveland - Browns (Local)
# 2          Seattle - Seahawks  Cleveland - Browns (Local)
# 3          Seattle - Seahawks  Cleveland - Browns (Local)
# 4          Seattle - Seahawks  Cleveland - Browns (Local)
# 5          Seattle - Seahawks  Cleveland - Browns (Local)
# 6          Seattle - Seahawks  Cleveland - Browns (Local)
# 7          Seattle - Seahawks  Cleveland - Browns (Local)
# 8          Seattle - Seahawks  Cleveland - Browns (Local)
# 9          Seattle - Seahawks  Cleveland - Browns (Local)
# 10  Atlanta - Falcons (Local)  Cleveland - Browns (Local)
# 11  Atlanta - Falcons (Local)  Cleveland - Browns (Local)
# 12         Seattle - Seahawks  Cleveland - Browns (Local)
# 13         Seattle - Seahawks  Cleveland - Browns (Local)
# 14         Seattle - Seahawks  Cleveland - Browns (Local)
# 15         Seattle - Seahawks  Cleveland - Browns (Local)
# 16         Seattle - Seahawks  Cleveland - Browns (Local)
# 17         Seattle - Seahawks  Cleveland - Browns (Local)
# 18         Seattle - Seahawks  Cleveland - Browns (Local)
# 19         Seattle - Seahawks  Cleveland - Browns (Local)
# 20         Seattle - Seahawks  Cleveland - Browns (Local)
# 21         Seattle - Seahawks  Cleveland - Browns (Local)
# 22         Seattle - Seahawks  Cleveland - Browns (Local)
# 23         Seattle - Seahawks  Cleveland - Browns (Local)
# 24         Seattle - Seahawks  Cleveland - Browns (Local)
# 25         Seattle - Seahawks  Cleveland - Browns (Local)
# 26         Seattle - Seahawks  Cleveland - Browns (Local)
# 27         Seattle - Seahawks  Cleveland - Browns (Local)
#
#                               4                            5  \
# 0   Green Bay - Packers (Local)      Washington - Commanders
# 1   Green Bay - Packers (Local)      Washington - Commanders
# 2   Green Bay - Packers (Local)      Washington - Commanders
# 3   Green Bay - Packers (Local)      Washington - Commanders
# 4   Green Bay - Packers (Local)  Minnesota - Vikings (Local)
# 14             Denver - Broncos     Cincinnati - Bengals  Los Angeles - Rams
# 15             Denver - Broncos  Buffalo - Bills (Local)  Los Angeles - Rams
# 16             Denver - Broncos  Buffalo - Bills (Local)  Los Angeles - Rams
# 17             Denver - Broncos  Buffalo - Bills (Local)  Los Angeles - Rams
# 18             Denver - Broncos  Buffalo - Bills (Local)  Los Angeles - Rams
# 19             Denver - Broncos  Buffalo - Bills (Local)  Los Angeles - Rams
# 20             Denver - Broncos  Buffalo - Bills (Local)  Los Angeles - Rams
# 21             Denver - Broncos     Cincinnati - Bengals  Los Angeles - Rams
# 22             Denver - Broncos  Buffalo - Bills (Local)  Los Angeles - Rams
# 23             Denver - Broncos  Buffalo - Bills (Local)  Los Angeles - Rams
# 24             Denver - Broncos  Buffalo - Bills (Local)  Los Angeles - Rams
# 25             Denver - Broncos  Buffalo - Bills (Local)  Los Angeles - Rams
# 26             Denver - Broncos  Buffalo - Bills (Local)  Los Angeles - Rams
# 27             Denver - Broncos  Buffalo - Bills (Local)  Los Angeles - Rams
#
#                               13                              14  Desempate
# 0   Kansas City - Chiefs (Local)  Los Angeles - Chargers (Local)         48
# 1   Kansas City - Chiefs (Local)  Los Angeles - Chargers (Local)         49
# 2   Kansas City - Chiefs (Local)           Philadelphia - Eagles         40
# 3   Kansas City - Chiefs (Local)           Philadelphia - Eagles         40
# 4   Kansas City - Chiefs (Local)           Philadelphia - Eagles         49
# 5               Houston - Texans  Los Angeles - Chargers (Local)         47
# 6               Houston - Texans  Los Angeles - Chargers (Local)         45
# 7   Kansas City - Chiefs (Local)           Philadelphia - Eagles         50
# 8   Kansas City - Chiefs (Local)           Philadelphia - Eagles         45
# 9   Kansas City - Chiefs (Local)           Philadelphia - Eagles         43
# 10              Houston - Texans           Philadelphia - Eagles         46
# 11              Houston - Texans           Philadelphia - Eagles         43
# 12              Houston - Texans           Philadelphia - Eagles         52
# 13  Kansas City - Chiefs (Local)           Philadelphia - Eagles         53
# 14  Kansas City - Chiefs (Local)           Philadelphia - Eagles         36
# 15              Houston - Texans           Philadelphia - Eagles         43
# 16  Kansas City - Chiefs (Local)           Philadelphia - Eagles         44
# 17  Kansas City - Chiefs (Local)           Philadelphia - Eagles         52
# 18  Kansas City - Chiefs (Local)           Philadelphia - Eagles         45
# 19  Kansas City - Chiefs (Local)           Philadelphia - Eagles         42
# 20              Houston - Texans           Philadelphia - Eagles         51
# 21              Houston - Texans           Philadelphia - Eagles         45
# 22  Kansas City - Chiefs (Local)           Philadelphia - Eagles         45
# 23  Kansas City - Chiefs (Local)           Philadelphia - Eagles         41
# 24  Kansas City - Chiefs (Local)  Los Angeles - Chargers (Local)         48
# 25  Kansas City - Chiefs (Local)           Philadelphia - Eagles         52
# 26  Kansas City - Chiefs (Local)           Philadelphia - Eagles         46
# 27  Kansas City - Chiefs (Local)           Philadelphia - Eagles         48

# %%
import pandas as pd
from openpyxl import load_workbook

archivo_existente = 'NFL Quinela 2025.xlsx'
nombre_hoja = f'{numero}'

# Cargar el libro
book = load_workbook(archivo_existente)

# Eliminar la hoja si ya existe
if nombre_hoja in book.sheetnames:
    std = book[nombre_hoja]
    book.remove(std)
    book.save(archivo_existente)

# Escribir la nueva hoja
with pd.ExcelWriter(archivo_existente, engine='openpyxl', mode='a') as writer:
    quiniela_semana_actual.to_excel(writer, index=False, sheet_name=nombre_hoja,header=None)

quinela = pd.read_excel(archivo_existente, 
                        sheet_name = None, 
                        header = None, 
                        index_col=0)


quinela = {sheet: df[~df.index.isin(bajas)] for sheet, 
           df in quinela.items()}

semanas = [int(semana) for semana in quinela.keys()]
semana_numero = numero #int(max(semanas))
semana = str(semana_numero)


quinela_semanal = quinela[semana]

quinela_semanal.index.name = 'Participante'
quiniela_df = pd.DataFrame(quinela_semanal)
quiniela_df
# Out:
#                                                         1   \
# Participante
# Maribel Baeza Adame                Detroit - Lions (Local)
# Marisela Chacón Molina                    Dallas - Cowboys
# Raúl Humberto García Robledo              Dallas - Cowboys
# Alberto Vargas Ortiz               Detroit - Lions (Local)
# Manuel Alejandro Escobar Aguilera         Dallas - Cowboys
# Gerardo Abraham Ayala Siqueiros    Detroit - Lions (Local)
# Jaime Antonio García Morales       Detroit - Lions (Local)
# Judith Fernández Franco            Detroit - Lions (Local)
# Santos Vazquez Garza                      Dallas - Cowboys
# Luis Mendoza Armendáriz                   Dallas - Cowboys
# Erick Benavides Correa                    Dallas - Cowboys
# Jaime Jesús Irigoyen Hernández            Dallas - Cowboys
# Guiorguio Guitto Sánchez Muñoz     Detroit - Lions (Local)
# Arelí Olivas Alcántar              Detroit - Lions (Local)
# Derek Manuel Calderón Rubio               Dallas - Cowboys
# Andrea Bustamante Yapur            Detroit - Lions (Local)
# Ilse Lozano Rodríguez              Detroit - Lions (Local)
# Neima Dorely Meza Jáquez           Detroit - Lions (Local)
# José Carlos Salgado Gómez          Detroit - Lions (Local)
# José Roberto González Hernández    Detroit - Lions (Local)
# Luis Alberto López Mónge                  Dallas - Cowboys
# Kenia Estefanía Cruz García               Dallas - Cowboys
# Alejandro Barragán Huerta          Detroit - Lions (Local)
# Ezequiel Chávez Gutierrez          Detroit - Lions (Local)
# José Eduardo López Acosta                 Dallas - Cowboys
# Cynthia Jaqueline Peralta Sosa     Detroit - Lions (Local)
# Jerónimo Reyes Ibarra              Detroit - Lions (Local)
# Magaly Teresa Ochoa Lugo           Detroit - Lions (Local)
#
#                                                           2   \
# Participante
# Maribel Baeza Adame                       Seattle - Seahawks
# Marisela Chacón Molina                    Seattle - Seahawks
# Raúl Humberto García Robledo              Seattle - Seahawks
# Alberto Vargas Ortiz                      Seattle - Seahawks
# Manuel Alejandro Escobar Aguilera         Seattle - Seahawks
# Gerardo Abraham Ayala Siqueiros           Seattle - Seahawks
# Jaime Antonio García Morales              Seattle - Seahawks
# Judith Fernández Franco                   Seattle - Seahawks
# Santos Vazquez Garza                      Seattle - Seahawks
# Luis Mendoza Armendáriz                   Seattle - Seahawks
# Erick Benavides Correa             Atlanta - Falcons (Local)
# Jaime Jesús Irigoyen Hernández     Atlanta - Falcons (Local)
# Guiorguio Guitto Sánchez Muñoz            Seattle - Seahawks
# Arelí Olivas Alcántar                     Seattle - Seahawks
# Derek Manuel Calderón Rubio               Seattle - Seahawks
# Andrea Bustamante Yapur                   Seattle - Seahawks
# Ilse Lozano Rodríguez                     Seattle - Seahawks
# Neima Dorely Meza Jáquez                  Seattle - Seahawks
# José Carlos Salgado Gómez                 Seattle - Seahawks
# José Roberto González Hernández           Seattle - Seahawks
# Luis Alberto López Mónge                  Seattle - Seahawks
# Kenia Estefanía Cruz García               Seattle - Seahawks
# Alejandro Barragán Huerta                 Seattle - Seahawks
# Ezequiel Chávez Gutierrez                 Seattle - Seahawks
# José Eduardo López Acosta                 Seattle - Seahawks
# Cynthia Jaqueline Peralta Sosa            Seattle - Seahawks
# Jerónimo Reyes Ibarra                     Seattle - Seahawks
# Magaly Teresa Ochoa Lugo                  Seattle - Seahawks
#
#                                                            3   \
# Participante
# Maribel Baeza Adame                        Tennessee - Titans
# Marisela Chacón Molina             Cleveland - Browns (Local)
# Raúl Humberto García Robledo       Cleveland - Browns (Local)
# Alberto Vargas Ortiz               Cleveland - Browns (Local)
# Manuel Alejandro Escobar Aguilera  Cleveland - Browns (Local)
# Gerardo Abraham Ayala Siqueiros    Cleveland - Browns (Local)
# Jaime Antonio García Morales       Cleveland - Browns (Local)
# Judith Fernández Franco            Cleveland - Browns (Local)
# Santos Vazquez Garza               Cleveland - Browns (Local)
# Luis Mendoza Armendáriz            Cleveland - Browns (Local)
# Erick Benavides Correa             Cleveland - Browns (Local)
# Jaime Jesús Irigoyen Hernández     Cleveland - Browns (Local)
# Guiorguio Guitto Sánchez Muñoz     Cleveland - Browns (Local)
# Arelí Olivas Alcántar              Cleveland - Browns (Local)
# Derek Manuel Calderón Rubio        Cleveland - Browns (Local)
# Andrea Bustamante Yapur            Cleveland - Browns (Local)
# Ilse Lozano Rodríguez              Cleveland - Browns (Local)
# Neima Dorely Meza Jáquez           Cleveland - Browns (Local)
# José Carlos Salgado Gómez          Cleveland - Browns (Local)
# José Roberto González Hernández    Cleveland - Browns (Local)
# Luis Alberto López Mónge           Cleveland - Browns (Local)
# Kenia Estefanía Cruz García        Cleveland - Browns (Local)
# Alejandro Barragán Huerta          Cleveland - Browns (Local)
# Ezequiel Chávez Gutierrez          Cleveland - Browns (Local)
# José Eduardo López Acosta          Cleveland - Browns (Local)
# Cynthia Jaqueline Peralta Sosa     Cleveland - Browns (Local)
# Jerónimo Reyes Ibarra              Cleveland - Browns (Local)
# Magaly Teresa Ochoa Lugo           Cleveland - Browns (Local)
#
#                                                             4   \
# Participante
# Maribel Baeza Adame                Green Bay - Packers (Local)
# Marisela Chacón Molina             Green Bay - Packers (Local)
# Raúl Humberto García Robledo       Green Bay - Packers (Local)
# Alberto Vargas Ortiz               Green Bay - Packers (Local)
# Manuel Alejandro Escobar Aguilera  Green Bay - Packers (Local)
# Gerardo Abraham Ayala Siqueiros    Green Bay - Packers (Local)
# Arelí Olivas Alcántar              Kansas City - Chiefs (Local)
# Derek Manuel Calderón Rubio        Kansas City - Chiefs (Local)
# Andrea Bustamante Yapur                        Houston - Texans
# Ilse Lozano Rodríguez              Kansas City - Chiefs (Local)
# Neima Dorely Meza Jáquez           Kansas City - Chiefs (Local)
# José Carlos Salgado Gómez          Kansas City - Chiefs (Local)
# José Roberto González Hernández    Kansas City - Chiefs (Local)
# Luis Alberto López Mónge                       Houston - Texans
# Kenia Estefanía Cruz García                    Houston - Texans
# Alejandro Barragán Huerta          Kansas City - Chiefs (Local)
# Ezequiel Chávez Gutierrez          Kansas City - Chiefs (Local)
# José Eduardo López Acosta          Kansas City - Chiefs (Local)
# Cynthia Jaqueline Peralta Sosa     Kansas City - Chiefs (Local)
# Jerónimo Reyes Ibarra              Kansas City - Chiefs (Local)
# Magaly Teresa Ochoa Lugo           Kansas City - Chiefs (Local)
#
#                                                                14  15
# Participante
# Maribel Baeza Adame                Los Angeles - Chargers (Local)  48
# Marisela Chacón Molina             Los Angeles - Chargers (Local)  49
# Raúl Humberto García Robledo                Philadelphia - Eagles  40
# Alberto Vargas Ortiz                        Philadelphia - Eagles  40
# Manuel Alejandro Escobar Aguilera           Philadelphia - Eagles  49
# Gerardo Abraham Ayala Siqueiros    Los Angeles - Chargers (Local)  47
# Jaime Antonio García Morales       Los Angeles - Chargers (Local)  45
# Judith Fernández Franco                     Philadelphia - Eagles  50
# Santos Vazquez Garza                        Philadelphia - Eagles  45
# Luis Mendoza Armendáriz                     Philadelphia - Eagles  43
# Erick Benavides Correa                      Philadelphia - Eagles  46
# Jaime Jesús Irigoyen Hernández              Philadelphia - Eagles  43
# Guiorguio Guitto Sánchez Muñoz              Philadelphia - Eagles  52
# Arelí Olivas Alcántar                       Philadelphia - Eagles  53
# Derek Manuel Calderón Rubio                 Philadelphia - Eagles  36
# Andrea Bustamante Yapur                     Philadelphia - Eagles  43
# Ilse Lozano Rodríguez                       Philadelphia - Eagles  44
# Neima Dorely Meza Jáquez                    Philadelphia - Eagles  52
# José Carlos Salgado Gómez                   Philadelphia - Eagles  45
# José Roberto González Hernández             Philadelphia - Eagles  42
# Luis Alberto López Mónge                    Philadelphia - Eagles  51
# Kenia Estefanía Cruz García                 Philadelphia - Eagles  45
# Alejandro Barragán Huerta                   Philadelphia - Eagles  45
# Ezequiel Chávez Gutierrez                   Philadelphia - Eagles  41
# José Eduardo López Acosta          Los Angeles - Chargers (Local)  48
# Cynthia Jaqueline Peralta Sosa              Philadelphia - Eagles  52
# Jerónimo Reyes Ibarra                       Philadelphia - Eagles  46
# Magaly Teresa Ochoa Lugo                    Philadelphia - Eagles  48

# %%
faltaron_df = pd.DataFrame(faltaron, columns=['Participante']).reset_index(drop=True)
faltaron_df.index = range(1, len(faltaron_df) + 1)
faltaron_html = faltaron_df
faltaron_df
# Out:
#                 Participante
# 1  Ana Alejandra Donati Lugo

# %% [markdown]
# # Extración de resultados directamente de la pagina de ESPN

# %% [markdown]
# import requests
#
# equipos_nfl = {
#     'Arizona Cardinals' : 'Arizona - Cardinals',
#     'Atlanta Falcons' : 'Atlanta - Falcons',
#     'Baltimore Ravens' : 'Baltimore - Ravens',
#     'Buffalo Bills' : 'Buffalo - Bills',
#     'Carolina Panthers' : 'Carolina - Panthers',
#     'Chicago Bears' : 'Chicago - Bears',
#     'Cincinnati Bengals' : 'Cincinnati - Bengals',
#     'Cleveland Browns' : 'Cleveland - Browns',
#     'Dallas Cowboys' : 'Dallas - Cowboys',
#     'Denver Broncos' : 'Denver - Broncos',
#     'Detroit Lions' : 'Detroit - Lions',
#     'Green Bay Packers' : 'Green Bay - Packers',
#     'Houston Texans' : 'Houston - Texans',
#     'Indianapolis Colts' : 'Indianapolis - Colts',
#     'Jacksonville Jaguars' : 'Jacksonville - Jaguars',
#     'Kansas City Chiefs' : 'Kansas City - Chiefs',
#     'Las Vegas Raiders' : 'Las Vegas - Raiders',
#     'Los Angeles Chargers' : 'Los Angeles - Chargers',
#     'Los Angeles Rams' : 'Los Angeles - Rams',
#     'Miami Dolphins' : 'Miami - Dolphins',
#     'Minnesota Vikings' : 'Minnesota - Vikings',
#     'New England Patriots' : 'New England - Patriots',
#     'New Orleans Saints' : 'New Orleans - Saints',
#     'New York Giants' : 'New York - Giants',
#     'New York Jets' : 'New York - Jets',
#     'Philadelphia Eagles' : 'Philadelphia - Eagles',
#     'Pittsburgh Steelers' : 'Pittsburgh - Steelers',
#     'San Francisco 49ers' : 'San Francisco - 49ers',
#     'Seattle Seahawks' : 'Seattle - Seahawks',
#     'Tampa Bay Buccaneers' : 'Tampa Bay - Buccaneers',
#     'Tennessee Titans' : 'Tennessee - Titans',
#     'Washington Commanders' : 'Washington - Commanders'
#
# }
#
# estadios_nfl = {
#     "AT&T Stadium": "Dallas - Cowboys",
#     "Mercedes-Benz Stadium": "Atlanta - Falcons",
#     "M&T Bank Stadium": "Baltimore - Ravens",
#     "Highmark Stadium": "Buffalo - Bills",
#     "Bank of America Stadium": "Charlotte - Panthers",
#     "Soldier Field": "Chicago - Bears",
#     "Paycor Stadium": "Cincinnati - Bengals",
#     "Cleveland Browns Stadium": "Cleveland - Browns",
#     "Empower Field at Mile High": "Denver - Broncos",
#     "Ford Field": "Detroit - Lions",
#     "MetLife Stadium": "New York - Giants/Jets",
#     "Gillette Stadium": "New England - Patriots",
#     "Lambeau Field": "Green Bay - Packers",
#     "NRG Stadium": "Houston - Texans",
#     "Lucas Oil Stadium": "Indianapolis - Colts",
#     "SoFi Stadium": "Los Angeles - Rams/Chargers",
#     "EverBank Stadium": "Jacksonville - Jaguars",
#     "GEHA Field at Arrowhead Stadium": "Kansas City - Chiefs",
#     "Allegiant Stadium": "Las Vegas - Raiders",
#     "Hard Rock Stadium": "Miami - Dolphins",
#     "U.S. Bank Stadium": "Minnesota - Vikings",
#     "Nissan Stadium": "Tennessee - Titans",
#     "Caesars Superdome": "New Orleans - Saints",
#     "Lincoln Financial Field": "Philadelphia - Eagles",
#     "Acrisure Stadium": "Pittsburgh - Steelers",
#     "Levi's Stadium": "San Francisco - 49ers",
#     "Lumen Field": "Seattle - Seahawks",
#     "Raymond James Stadium": "Tampa Bay - Buccaneers",
#     "FedExField": "Washington - Commanders",
#     'Northwest Stadium': "Washington - Commanders",
#     'Huntington Bank Field': 'Cleveland - Browns'
# }
#
# locales_angeles_ny = {
#     'New York Jets - MetLife Stadium': 'New York Jets (Local)',
#     'New York Giants - MetLife Stadium': 'New York Giants (Local)',
#     'Los Angeles Rams - SoFi Stadium': 'Los Angeles Rams (Local)',
#     'Los Angeles Chargers - SoFi Stadium': 'Los Angeles Chargers (Local)'
# }
#
#
#
# temporada_regular = {}
# tipo_temporada = 2
# for semana in range(1, 19):
#     url = f"https://site.api.espn.com/apis/site/v2/sports/football/nfl/scoreboard?week={semana}&seasontype={tipo_temporada}"
#     response = requests.get(url)
#     data = response.json()
#
#     partidos = []
#     for event in data.get("events", []):
#         nombre_partido = event.get("name")
#         fecha = event.get("date")
#         competencia = event.get("competitions", [])[0]
#         equipos = [equipo["team"]["name"] for equipo in competencia.get("competitors", [])]
#         equipo_1 = nombre_partido.split(" at ")[0] if " at " in nombre_partido else None
#         equipo_2 = nombre_partido.split(" at ")[1] if " at " in nombre_partido else None
#         estadio = competencia.get("venue", {}).get("fullName", "Desconocido")
#         puntos_equipo_1 = competencia.get("competitors", [])[1].get("score", 0)
#         puntos_equipo_2 = competencia.get("competitors", [])[0].get("score", 0)
#
#         partidos.append({
#             "Partido": nombre_partido,
#             "Fecha": fecha,
#             "Equipo 1": equipo_1,
#             "Puntos Equipo 1": puntos_equipo_1,
#             "Equipo 2": equipo_2,
#             "Puntos Equipo 2": puntos_equipo_2,
#             "Estadio": estadio,
#         })
#
#     df = pd.DataFrame(partidos)
#     df['Equipo 1'] = df['Equipo 1'].map(equipos_nfl)
#     df['Equipo 2'] = df['Equipo 2'].map(equipos_nfl)
#     df['combinación'] = df['Equipo 2'] + ' - ' + df['Estadio']
#     df['Local'] = df['combinación'].map(locales_angeles_ny)
#     df['Local'] = df['Local'].fillna(df['Equipo 2'] + ' (Local)')
#     df['Ganador'] = df.apply(lambda row: row['Equipo 1'] if int(row['Puntos Equipo 1']) > int(row['Puntos Equipo 2']) else (row['Local'] if int(row['Puntos Equipo 2']) > int(row['Puntos Equipo 1']) else 'Empate'), axis=1)
#     df.sort_values(by='Fecha', inplace=True)
#
#     temporada_regular[semana] = df
#
# from openpyxl import load_workbook
# #os.chdir(r'C:\Users\gaas\OneDrive - SERVIFOR, S.C\Personal\Proyectos_personales\NFL\2025')
#
# marcador_2025 = pd.ExcelWriter("marcador_2025.xlsx", engine='xlsxwriter')
# for semana, df in temporada_regular.items():
#     df.to_excel(marcador_2025, index=False, sheet_name=f'{semana}')
# marcador_2025.close()
#
# import pandas as pd
# # Cargar el archivo Excel
# archivo = 'marcador_2025.xlsx'
#
# # Crear un diccionario para almacenar los ganadores por pestaña
# ganadores_por_hoja = {}
#
# # Iterar sobre las pestañas del 1 al 18
# for i in range(1, 19):
#     nombre_hoja = str(i)
#     df = pd.read_excel(archivo, sheet_name=nombre_hoja)
#
#     # Verificar si la columna 'Ganador' existe
#     if 'Ganador' in df.columns:
#         ganadores_por_hoja[nombre_hoja] = df['Ganador'].tolist()
#     else:
#         ganadores_por_hoja[nombre_hoja] = []
#
# # Crear un DataFrame con los resultados
# df_ganadores = pd.DataFrame.from_dict(ganadores_por_hoja, orient='index')
#
# # Mostrar el DataFrame
# df_ganadores = pd.DataFrame(df_ganadores)
# guardar = pd.ExcelWriter("NFL Resultados 2025 pruebas.xlsx", engine='xlsxwriter')
# df_ganadores.to_excel(guardar, sheet_name='1', index=int(True))
# guardar.close()

# %% [markdown]
# # Usar resultados de la semana actual para comparar con la quiniela

# %%
# Leer el archivo sin encabezado y usando la primera columna como índice
#resultados_partidos = pd.read_excel('NFL Resultados 2025 pruebas.xlsx', header=None, index_col=0)

resultados_partidos = pd.read_excel('NFL Resultados 2025.xlsx', header=None, index_col=0)


# Eliminar filas con índice nulo
resultados_partidos = resultados_partidos[resultados_partidos.index.notna()]

# Convertir el índice a entero
resultados_partidos.index = resultados_partidos.index.astype(int)

resultados_partidos.loc[numero]
# Out:
# 1            Detroit - Lions (Local)
# 2                 Seattle - Seahawks
# 3                 Tennessee - Titans
# 4        Green Bay - Packers (Local)
# 5        Minnesota - Vikings (Local)
# 6                   Miami - Dolphins
# 7               New Orleans - Saints
# 8     Jacksonville - Jaguars (Local)
# 9              Pittsburgh - Steelers
# 10                  Denver - Broncos
# 11           Buffalo - Bills (Local)
# 12                Los Angeles - Rams
# 13                  Houston - Texans
# 14                               NaN
# 15                               NaN
# 16                               NaN
# 17                               NaN
# Name: 14, dtype: object

# %% [markdown]
# # Definir aciertos semanales

# %%
def contar_aciertos(quiniela, resultados):
    import pandas as pd

    def limpiar_nombre(equipo):
        if isinstance(equipo, str):
            return equipo.replace("(Local)", "").strip().lower()
        return equipo
    acierto_semanal = pd.DataFrame()

    for semana, quiniela_semana_actual in quiniela.items():
        aciertos_semana = {}

        try:
            semana_int = int(semana)
        except ValueError:
            print(f"Semana '{semana}' no es un número válido.")
            continue

        if semana_int not in resultados.index:
            print(f"Semana {semana_int} no encontrada en resultados")
            continue

        resultado_real = resultados.loc[semana_int]
        resultado_real = resultado_real.apply(limpiar_nombre)

        for participante in quiniela_semana_actual.index:
            seleccion_participante = quiniela_semana_actual.loc[participante]
            seleccion_participante = seleccion_participante.reindex(resultado_real.index)
            seleccion_participante = seleccion_participante.apply(limpiar_nombre)

            aciertos_semana[participante] = (seleccion_participante == resultado_real).sum()

        acierto_semanal[semana_int] = pd.Series(aciertos_semana)

    acierto_semanal.fillna(0, inplace=True)
    acierto_semanal = acierto_semanal.astype(int)
    acierto_semanal['Total Aciertos'] = acierto_semanal.sum(axis=1)

    return acierto_semanal

# %% [markdown]
# # Generación de tabla Preliminar

# %%
# Llamar a la función para obtener los aciertos semanales por participante
aciertos_semanales = contar_aciertos(quinela, resultados_partidos)

# Ordenar el DataFrame por el total de aciertos en orden descendente
aciertos_semanales = aciertos_semanales.sort_values(by='Total Aciertos', 
                                                    ascending=False)

semana_actual = pd.DataFrame(aciertos_semanales[numero].sort_values(ascending=False))
semana_actual.columns = [f'Semana {numero}']

# Aqui los números que restan es para escojer la columna a mostrar
marcador = quinela_semanal.shape[1] - 1
partidos = quinela_semanal.shape[1] - 2
partidos_2 = quinela_semanal.shape[1] - 3

partido_lunes = quinela_semanal.iloc[:, [partidos, marcador]]
partido_lunes.columns = ['Último juego','Desempate']

#partido_lunes = quinela_semanal.iloc[:, [partidos_2, partidos, marcador]]
#partido_lunes.columns = ['Penúltimo juego','Último juego','Desempate']
preliminar = pd.merge(semana_actual, 
                      partido_lunes, 
                      left_index=True, 
                      right_index=True)

columna_semana_actual = semana_actual.columns[0]

preliminar = preliminar.sort_values(by=[columna_semana_actual, 'Desempate'], ascending=False)

preliminar = pd.DataFrame(preliminar)
preliminar.index.name = 'Participante'

preliminar
# Out:
# Semana 0 no encontrada en resultados
#                                    Semana 14                    Último juego  \
# Participante
# Gerardo Abraham Ayala Siqueiros           10  Los Angeles - Chargers (Local)
# Magaly Teresa Ochoa Lugo                   9           Philadelphia - Eagles
# Maribel Baeza Adame                        9  Los Angeles - Chargers (Local)
# Jaime Antonio García Morales               9  Los Angeles - Chargers (Local)
# Kenia Estefanía Cruz García                9           Philadelphia - Eagles
# Ilse Lozano Rodríguez                      9           Philadelphia - Eagles
# Andrea Bustamante Yapur                    9           Philadelphia - Eagles
# José Roberto González Hernández            9           Philadelphia - Eagles
# Ezequiel Chávez Gutierrez                  9           Philadelphia - Eagles
# Cynthia Jaqueline Peralta Sosa             8           Philadelphia - Eagles
# Luis Alberto López Mónge                   8           Philadelphia - Eagles
# Manuel Alejandro Escobar Aguilera          8           Philadelphia - Eagles
# José Carlos Salgado Gómez                  8           Philadelphia - Eagles
# Arelí Olivas Alcántar                      7           Philadelphia - Eagles
# Neima Dorely Meza Jáquez                   7           Philadelphia - Eagles
# Guiorguio Guitto Sánchez Muñoz             7           Philadelphia - Eagles
# Judith Fernández Franco                    7           Philadelphia - Eagles
# Marisela Chacón Molina                     7  Los Angeles - Chargers (Local)
# Jerónimo Reyes Ibarra                      7           Philadelphia - Eagles
# Erick Benavides Correa                     7           Philadelphia - Eagles
# Alejandro Barragán Huerta                  7           Philadelphia - Eagles
# Jaime Jesús Irigoyen Hernández             7           Philadelphia - Eagles
# Raúl Humberto García Robledo               7           Philadelphia - Eagles
# Alberto Vargas Ortiz                       7           Philadelphia - Eagles
# Luis Mendoza Armendáriz                    6           Philadelphia - Eagles
# Derek Manuel Calderón Rubio                6           Philadelphia - Eagles
# José Eduardo López Acosta                  5  Los Angeles - Chargers (Local)
# Santos Vazquez Garza                       5           Philadelphia - Eagles
#
#                                    Desempate
# Participante
# Gerardo Abraham Ayala Siqueiros           47
# Magaly Teresa Ochoa Lugo                  48
# Maribel Baeza Adame                       48
# Jaime Antonio García Morales              45
# Kenia Estefanía Cruz García               45
# Ilse Lozano Rodríguez                     44
# Andrea Bustamante Yapur                   43
# José Roberto González Hernández           42
# Ezequiel Chávez Gutierrez                 41
# Cynthia Jaqueline Peralta Sosa            52
# Luis Alberto López Mónge                  51
# Manuel Alejandro Escobar Aguilera         49
# José Carlos Salgado Gómez                 45
# Arelí Olivas Alcántar                     53
# Neima Dorely Meza Jáquez                  52
# Guiorguio Guitto Sánchez Muñoz            52
# Judith Fernández Franco                   50
# Marisela Chacón Molina                    49
# Jerónimo Reyes Ibarra                     46
# Erick Benavides Correa                    46
# Alejandro Barragán Huerta                 45
# Jaime Jesús Irigoyen Hernández            43
# Raúl Humberto García Robledo              40
# Alberto Vargas Ortiz                      40
# Luis Mendoza Armendáriz                   43
# Derek Manuel Calderón Rubio               36
# José Eduardo López Acosta                 48
# Santos Vazquez Garza                      45

# %%
#!pip install premailer
resultados_partidos
# Out:
#                                 1                             2   \
# 0
# 1    Philadelphia - Eagles (Local)        Los Angeles - Chargers
# 2      Green Bay - Packers (Local)  Cincinnati - Bengals (Local)
# 3                  Buffalo - Bills    Cleveland - Browns (Local)
# 4               Seattle - Seahawks         Pittsburgh - Steelers
# 5            San Francisco - 49ers           Minnesota - Vikings
# 6        New York - Giants (Local)              Denver - Broncos
# 7     Cincinnati - Bengals (Local)            Los Angeles - Rams
# 8   Los Angeles - Chargers (Local)              Miami - Dolphins
# 9               Baltimore - Ravens               Chicago - Bears
# 10        Denver - Broncos (Local)          Indianapolis - Colts
# 11  New England - Patriots (Local)              Miami - Dolphins
# 12        Houston - Texans (Local)       Chicago - Bears (Local)
# 13             Green Bay - Packers      Dallas - Cowboys (Local)
# 14         Detroit - Lions (Local)            Seattle - Seahawks
#
#                               3                               4   \
# 0
# 1         Tampa Bay - Buccaneers            Cincinnati - Bengals
# 2       Dallas - Cowboys (Local)         Detroit - Lions (Local)
# 3           Indianapolis - Colts     Minnesota - Vikings (Local)
# 4      Atlanta - Falcons (Local)         Buffalo - Bills (Local)
# 5   Indianapolis - Colts (Local)    New Orleans - Saints (Local)
# 6   Indianapolis - Colts (Local)          Los Angeles - Chargers
# 7        Chicago - Bears (Local)      Cleveland - Browns (Local)
# 8                New York - Jets  New England - Patriots (Local)
# 9            Minnesota - Vikings             Carolina - Panthers
# 10       Chicago - Bears (Local)        Miami - Dolphins (Local)
# 11           Carolina - Panthers         Buffalo - Bills (Local)
# 12        New England - Patriots         Detroit - Lions (Local)
# 13          Cincinnati - Bengals                 Chicago - Bears
# 14            Tennessee - Titans     Green Bay - Packers (Local)
#
#                                5                               6   \
# 0
# 1    Indianapolis - Colts (Local)             Las Vegas - Raiders
# 2              Los Angeles - Rams          New England - Patriots
# 3           Pittsburgh - Steelers   Philadelphia - Eagles (Local)
# 4         Detroit - Lions (Local)  New England - Patriots (Local)
# 5                Dallas - Cowboys                Denver - Broncos
# 6   Pittsburgh - Steelers (Local)  Tampa Bay - Buccaneers (Local)
# 7          New England - Patriots    Kansas City - Chiefs (Local)
# 8   Philadelphia - Eagles (Local)                 Buffalo - Bills
# 9          Los Angeles - Chargers  New England - Patriots (Local)
# 10             Baltimore - Ravens         New York - Jets (Local)
# 11               Houston - Texans                 Chicago - Bears
# 12    Green Bay - Packers (Local)              Seattle - Seahawks
# 13          San Francisco - 49ers          Jacksonville - Jaguars
# 14    Minnesota - Vikings (Local)                Miami - Dolphins
#
#                                 7                                8   \
# 0
# 1              Arizona - Cardinals            Pittsburgh - Steelers
# 2            San Francisco - 49ers                  Buffalo - Bills
# 3   Tampa Bay - Buccaneers (Local)  Washington - Commanders (Local)
# 4                New York - Giants            Philadelphia - Eagles
# 5      Carolina - Panthers (Local)                 Houston - Texans
# 6      Carolina - Panthers (Local)               Seattle - Seahawks
# 7            Philadelphia - Eagles              Carolina - Panthers
# 8       Baltimore - Ravens (Local)         Houston - Texans (Local)
# 9            San Francisco - 49ers    Pittsburgh - Steelers (Local)
# 10          New England - Patriots             New Orleans - Saints
# 11             Green Bay - Packers    Pittsburgh - Steelers (Local)
# 12    Kansas City - Chiefs (Local)       Baltimore - Ravens (Local)
# 13                Houston - Texans         Miami - Dolphins (Local)
# 14            New Orleans - Saints   Jacksonville - Jaguars (Local)
#
#                                  9                               10  \
# 0
# 1   Washington - Commanders (Local)  Jacksonville - Jaguars (Local)
# 2                Seattle - Seahawks      Baltimore - Ravens (Local)
# 3       Carolina - Panthers (Local)  Jacksonville - Jaguars (Local)
# 4          Houston - Texans (Local)      Los Angeles - Rams (Local)
# 5                Tennessee - Titans          Tampa Bay - Buccaneers
# 6                Los Angeles - Rams     Las Vegas - Raiders (Local)
# 7          Denver - Broncos (Local)            Indianapolis - Colts
# 8            Tampa Bay - Buccaneers        Denver - Broncos (Local)
# 9                  Denver - Broncos          Jacksonville - Jaguars
# 10         Houston - Texans (Local)      Seattle - Seahawks (Local)
# 11   Jacksonville - Jaguars (Local)      Los Angeles - Rams (Local)
# 12               Cleveland - Browns          Jacksonville - Jaguars
# 13          New York - Jets (Local)  Tampa Bay - Buccaneers (Local)
# 14            Pittsburgh - Steelers                Denver - Broncos
#
#                                 11                            12  \
# 0
# 1         Denver - Broncos (Local)         San Francisco - 49ers
# 2     Indianapolis - Colts (Local)   Arizona - Cardinals (Local)
# 3   Los Angeles - Chargers (Local)    Seattle - Seahawks (Local)
# 4           Jacksonville - Jaguars  Kansas City - Chiefs (Local)
# 5                  Detroit - Lions       Washington - Commanders
# 6      Green Bay - Packers (Local)        New England - Patriots
# 7         Dallas - Cowboys (Local)           Green Bay - Packers
# 8     Indianapolis - Colts (Local)           Green Bay - Packers
# 9       Los Angeles - Rams (Local)       Buffalo - Bills (Local)
# 10              Los Angeles - Rams               Detroit - Lions
# 11           San Francisco - 49ers            Baltimore - Ravens
# 12        Dallas - Cowboys (Local)             Atlanta - Falcons
# 13     Carolina - Panthers (Local)    Seattle - Seahawks (Local)
# 14         Buffalo - Bills (Local)            Los Angeles - Rams
#
#                                 13                              14  \
# 0
# 1      Green Bay - Packers (Local)      Los Angeles - Rams (Local)
# 2            Philadelphia - Eagles               Atlanta - Falcons
# 3          Chicago - Bears (Local)   San Francisco - 49ers (Local)
# 4                  Chicago - Bears                          Empate
# 5           New England - Patriots  Jacksonville - Jaguars (Local)
# 6     Kansas City - Chiefs (Local)       Atlanta - Falcons (Local)
# 7    San Francisco - 49ers (Local)         Detroit - Lions (Local)
# 8     Kansas City - Chiefs (Local)                             NaN
# 9               Seattle - Seahawks             Arizona - Cardinals
# 10  Los Angeles - Chargers (Local)           Philadelphia - Eagles
# 11        Denver - Broncos (Local)   Philadelphia - Eagles (Local)
# 12      Los Angeles - Rams (Local)   San Francisco - 49ers (Local)
# 13                 Buffalo - Bills  Los Angeles - Chargers (Local)
# 14                Houston - Texans                             NaN
#
#                             15                              16    17
# 0
# 1      Buffalo - Bills (Local)             Minnesota - Vikings  51.0
# 2       Tampa Bay - Buccaneers          Los Angeles - Chargers  55.0
# 3         Kansas City - Chiefs                 Detroit - Lions  68.0
# 4     Miami - Dolphins (Local)        Denver - Broncos (Local)  43.0
# 5                           59                             NaN   NaN
# 6              Chicago - Bears                             NaN   NaN
# 7   Seattle - Seahawks (Local)                              51   NaN
# 8                          NaN                             NaN   NaN
# 9                          NaN                             NaN   NaN
# 10                         NaN                             NaN   NaN
# 11            Dallas - Cowboys                             NaN   NaN
# 12                         NaN                             NaN   NaN
# 13            Denver - Broncos  New England - Patriots (Local)   NaN
# 14                         NaN                             NaN   NaN

# %% [markdown]
# # Envio correo con Avances de quiniela semanal

# %%
# Lista de equipos ganadores
equipos_ganadores = resultados_partidos.loc[numero].dropna().tolist()


# Función para aplicar color solo a columnas específicas
def resaltar_ganadores(val):
    if val in equipos_ganadores:
        return 'background-color: #D5F5E3'  # verde claro
    else:
        return 'background-color: #FADBD8'  # rojo claro

# Excluir la última columna
columnas_a_formatear = quiniela_semana_actual.columns[1:-2]

quiniela_semana_actual = quiniela_semana_actual.set_index('Participante')
quiniela_semana_actual.index.name = 'Participante'
# Aplicar estilo solo a esas columnas
quiniela_final = quiniela_semana_actual.style.applymap(resaltar_ganadores, subset=columnas_a_formatear)


from premailer import transform
# ------------------------------
# TABLA PRELIMINAR
# ------------------------------
# Aplica gradiente + estilos de tabla
preliminar_estilada = (
    preliminar.style
    .background_gradient(
        cmap='RdYlGn',  # gradiente
        axis=0
    )
    .set_table_styles(
        [
            {"selector": "th", 
             "props": [
                 ("background-color", "#2E86C1"),
                 ("color", "white"),
                 ("text-align", "center"),
                 ("font-weight", "bold"),
                 ("padding", "8px")
             ]},
            {"selector": "td", 
             "props": [
                 ("text-align", "center"),
                 ("padding", "6px")
             ]},
            {"selector": "table",
             "props": [
                 ("border-collapse", "collapse"),
                 ("margin", "0 auto"),
                 ("font-family", "Lora, sans-serif"),
                 ("font-size", "14px")
             ]}
        ]
    )
)


preliminar_html = preliminar_estilada.to_html()
preliminar_html_inlined = transform(preliminar_html, remove_classes=True, strip_important=False)

# ------------------------------
# TABLA QUINIELA
# ------------------------------

quiniela_estilada = (
    quiniela_semana_actual.style
    .applymap(resaltar_ganadores, subset=columnas_a_formatear)
    .set_table_styles(
        [
            {"selector": "th", 
             "props": [
                 ("background-color", "#2E86C1"),
                 ("color", "white"),
                 ("text-align", "center"),
                 ("font-weight", "bold"),
                 ("padding", "8px")
             ]},
            {"selector": "td", 
             "props": [
                 ("text-align", "center"),
                 ("padding", "6px")
             ]},
            {"selector": "table",
             "props": [
                 ("border-collapse", "collapse"),
                 ("margin", "0 auto"),
                 ("font-family", "Lora, sans-serif"),
                 ("font-size", "14px")
             ]}
        ]
    )
)

quiniela_html = quiniela_estilada.to_html()
quiniela_html_inlined = transform(quiniela_html, remove_classes=True, strip_important=False)

import smtplib
from email.mime.multipart import MIMEMultipart
from email.mime.text import MIMEText
from email.mime.base import MIMEBase
from email import encoders
import pandas as pd

# Configuración del servidor y credenciales
smtp_server = 'smtp.office365.com'
smtp_port = 587
username = 'gaas@citlali.mx'
password = 'nashira1103'


asunto = f"🏈✨📣 Avance de la quiniela semana {numero}📣✨🏈"
nombre_archivo = f"avance de la semana {numero}"

# Crear el mensaje
msg = MIMEMultipart()
msg['From'] = username
msg['To'] = username
msg['Subject'] = asunto
# Crear el cuerpo del mensaje con la tabla embebida
# Cuerpo del correo con la tabla en línea
body = f"""
<html>
<head><meta charset="UTF-8"></head>
<body style="font-family: Lora, sans-serif; color: #333;">
<p style="color: #2E86C1;"><strong>👋 ¡¡Hola buen día a todos!!</strong></p>

<p><strong style="color: #117A65;">Les comparto el {nombre_archivo}</strong> 🏈:</p>

<h3 style="color:#2E86C1;">📊</h3>
{preliminar_html_inlined}

<h3 style="color:#117A65;">🏆</h3>
{quiniela_html_inlined}

<p style="color: #28B463;"><strong>Mucho éxito.🍀</strong></p>

<p style="color: #566573;">Salu✌️<br></p>
</body>
</html>
"""

msg.attach(MIMEText(body, 'html', 'utf-8'))


filename = nombre_archivo


part = MIMEBase('application', 'octet-stream')

part.add_header('Content-Disposition', f"attachment; filename= {filename}")



# Enviar el correo
try:
    server = smtplib.SMTP(smtp_server, smtp_port)
    server.starttls()
    server.login(username, password)
    text = msg.as_string()
    server.sendmail(username, [username,'gerardoa.ayalas@gmail.com'], text)
    server.quit()
    print("Correo enviado exitosamente")
except Exception as e:
    print(f"Error al enviar el correo: {e}")
# Out:
# Correo enviado exitosamente

# %%
#Puntos de diferencia par desempate
jugador_1 = 50
jugador_2 = 39
valor = 24+25
diferencia_1 = jugador_1 - valor
diferencia_2 = valor - jugador_2
print(f'El partido terminó con un marcador de {valor}')
print(f'Jugador_1 tiene {jugador_1} su diferencia es de {diferencia_1}')
print(f'Jugador_2 tiene {jugador_2} su diferencia es de {diferencia_2}\n')
if diferencia_1 < diferencia_2:
    print(f'El jugador_1 gana con {diferencia_1} puntos de diferencia')
elif diferencia_1 > diferencia_2:
    print(f'El jugador_2 gana con {diferencia_2} puntos de diferencia')
else:
    print(f'El partido termina en empate con {diferencia_1} puntos de diferencia')
# Out:
# El partido terminó con un marcador de 49
# Jugador_1 tiene 50 su diferencia es de 1
# Jugador_2 tiene 39 su diferencia es de 10
#
# El jugador_1 gana con 1 puntos de diferencia
